# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import warnings
warnings.filterwarnings("ignore")

data_dir = os.path.join('..', 'data')

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ### 0: Check Variables

# %%
filename = os.path.join(data_dir, 'year_data', 'traffic_' + str(2007) + '.parquet')
df = pd.read_parquet(filename, engine = 'pyarrow')
df.columns
# Out:
# Index(['raw_row_number', 'date', 'time', 'location', 'lat', 'lng',
#        'county_name', 'district', 'precinct', 'region', 'subject_race',
#        'subject_sex', 'officer_id_hash', 'type', 'violation',
#        'citation_issued', 'warning_issued', 'outcome', 'contraband_found',
#        'contraband_drugs', 'contraband_weapons', 'search_conducted',
#        'search_vehicle', 'search_basis', 'vehicle_color', 'vehicle_make',
#        'vehicle_model', 'vehicle_type', 'vehicle_year', 'raw_HA_RACE_SEX',
#        'raw_HA_SEARCH_PC_boolean', 'raw_HA_SEARCH_CONCENT_boolean',
#        'raw_HA_INCIDTO_ARREST_boolean', 'raw_HA_VEHICLE_INVENT_boolean',
#        'year'],
#       dtype='object')

# %%
df.iloc[:10,:]['search_vehicle']
# Out:
# 2693894    False
# 2693895    False
# 2693896    False
# 2693897    False
# 2693898    False
# 2693899    False
# 2693900    False
# 2693901    False
# 2693902    False
# 2693903    False
# Name: search_vehicle, dtype: object

# %%
df.iloc[:10,:]['search_basis']
# Out:
# 2693894    NaN
# 2693895    NaN
# 2693896    NaN
# 2693897    NaN
# 2693898    NaN
# 2693899    NaN
# 2693900    NaN
# 2693901    NaN
# 2693902    NaN
# 2693903    NaN
# Name: search_basis, dtype: category
# Categories (5, object): ['k9', 'plain view', 'consent', 'probable cause', 'other']

# %% [markdown]
# ##### Preprocessing functions

# %%
def remove_duplicates(row):
  if row['speeding_only'] == 'speeding-repeated_entries':
    return row['all_violation'][0].strip()
  else:
    return row['violation']

def remove_white_spaces(vio_lst):
  vio_lst = [x.strip() for x in vio_lst]
  return vio_lst


def exclusive(vio_lst):
  count = 0
  for vio in vio_lst:
    # count number of violations containing 'speed'
    if 'speed' in vio:
      count += 1
  # if we have non-speeding violation
  if count < len(vio_lst):
    return 'speeding + others'
  # if we only have speeding violation
  elif count == len(vio_lst):
    # if one speeding vio type
    if count == 1:
      return 'speeding-1'
    # if we have more than one entries but only one type
    elif len(set(vio_lst)) == 1:
      return 'speeding-repeated_entries'
    # if we have more than one type
    else:
      return 'speeding-multiple'
  else:
    return 'undefined case'

# %%
def speeding_filter(df):
  print('Before speed filtering: ', len(df))
  df['violation'] = [s.lower() for s in df['violation']]
  # at least one violation is speeding-violated (could have other violations at the same time)
  df = df.loc[df['violation'].str.contains('speed', regex = False),:]
  df['violation'] = df['violation'].map(lambda x: x.replace('(#)',''))
  df['violation'] = df['violation'].map(lambda x: x.strip())

  # get a list of violations for each record, and apply self-defined func exclusive
  df['all_violation'] = df['violation'].str.split('|')
  df['all_violation'] = df['all_violation'].map(lambda x: remove_white_spaces(x))
  df['speeding_only'] = df['all_violation'].map(lambda x: exclusive(x))

  # filter out rows with violations other than speeding
  df = df.loc[df['speeding_only'].isin(['speeding-repeated_entries','speeding-1','speeding-multiple']),:]

  df['violation'] = df.apply(lambda row: remove_duplicates(row), axis = 1)

  df.drop(['all_violation','speeding_only'], axis = 1, inplace = True)
  print('Speeding only violation has records: ', len(df))
  return df

# %%
# # RUN THIS ONLY ONCE TO CREATE DATA FILES
# # Create speeding only parquet files
# year_start = 2006
# year_end = 2017
# years = list(range(year_start, year_end + 1))

# def speeding_filter_for_saving(df):
#   print('Before speed filtering: ', len(df))
#   df['violation'] = [s.lower() for s in df['violation']]
#   # at least one violation is speeding-violated (could have other violations at the same time)
#   df = df.loc[df['violation'].str.contains('speed', regex = False),:]
#   df['violation'] = df['violation'].map(lambda x: x.replace('(#)',''))
#   df['violation'] = df['violation'].map(lambda x: x.strip())

#   # get a list of violations for each record, and apply self-defined func exclusive
#   df['all_violation'] = df['violation'].str.split('|')
#   df['all_violation'] = df['all_violation'].map(lambda x: remove_white_spaces(x))
#   df['speeding_only'] = df['all_violation'].map(lambda x: exclusive(x))

#   # filter out rows with violations other than speeding
#   df = df.loc[df['speeding_only'].isin(['speeding-repeated_entries','speeding-1','speeding-multiple']),:]

#   df['violation'] = df.apply(lambda row: remove_duplicates(row), axis = 1)

#   df.drop(['all_violation'], axis = 1, inplace = True)
#   print('Speeding only violation has records: ', len(df))
#   return df
    
# for year in years:
#     print(year)
#     year_df = pd.read_parquet(os.path.join(data_dir, 'year_data', 'traffic_' + str(year) + '.parquet'))
#     year_df = speeding_filter_for_saving(year_df)
#     year_df.to_parquet(os.path.join(data_dir, 'year_data_speeding_only', 'traffic_' + str(year) + '.parquet'), engine='pyarrow')

# %%
# this function is called by preprocess
def remove_empty_rows(df, colName):
	df = df[df[colName] != 'unknown']
	df = df[df[colName].notna()]
	return(df)

# %%
# columns we need in the analysis
keep_col = [
            'county_name',
            'subject_race',
            'subject_sex',
            'violation',
            'citation_issued',
            ]

# delete rows with missing value in these columns
rm_na_col = ['county_name','violation','subject_race','subject_sex']

# %%
### this function used in run_year_analysis()
def preprocess(year, rm_na_col, analysis_type,
               violation_types=None, border_counties=None, county_type=None, speeding_only=False, serious_violations=True):
  """
  with_vio: if include vioation type variables: True, if not include, False
  violation_types: violation types to be included in the analysis
  """
  # read dataframe
  # CHANGED 2023/07/12, why file_path: '/content/drive/MyDrive/traffic_stop/year_data_daylight/'???
  filename = os.path.join(data_dir, 'year_data', 'traffic_' + str(year) + '.parquet')
  if violation_types:
    filename = os.path.join(data_dir, 'year_data_speeding_only', 'traffic_' + str(year) + '.parquet')
  df = pd.read_parquet(filename, engine = 'pyarrow')
  print('# of all traffic stops in year ', year, ': ', len(df))

  # invalid value (IF NOT TEXAS STATE DATA, DELETE THIS INVALID VALUE BLOCK)
  if year == 2013:
    df.drop(df.index[df['lat'] == 74.052879], inplace=True)

  # based on analysis types, decide which columns to keep
  if analysis_type == 'citation':
    keep_col = [
            'county_name',
            'subject_race',
            'subject_sex',
            'violation',
            'citation_issued',
            ]
  elif analysis_type == 'search':
    keep_col = [
            'county_name',
            'subject_race',
            'subject_sex',
            'violation',
            'search_conducted'
            ]
  elif analysis_type == 'contraband':
    keep_col = [
            'county_name',
            'subject_race',
            'subject_sex',
            'violation',
            'search_conducted',
            'contraband_found',
            ]

  # drop unrelated columns
  col_drop = [col for col in df.columns if col not in keep_col]
  df.drop(col_drop, axis = 1, inplace = True)

  # remove rows with missing values in rm_na_col
  for col in rm_na_col:
    df = remove_empty_rows(df, col)
    # newly added 2023/07/12
    print('# of traffic stops after preprocessing step 0 - drop na/unknown in COL [',col,']: ',len(df))

  # if we want to only include certain violation types:
  if violation_types:
    if serious_violations:
      print('Including only serious violations')
    else:
      print('Including only non-serious violations')
    #df['violation'] = df['violation'].map(lambda x: x.replace(' (#)', '').strip())
    df = df.loc[df['violation'].isin(violation_types),:]
    print(len(df))

  # filter rows if speeding_only
  if speeding_only:
    # filter: only speeding violation (no other violations)
    df = speeding_filter(df)

  ######### THIS WHOLE BLOACK NEEDS TO BE CHANGED, NEW METROPOLITAN FILES AND DIFFERENT DATA FORMAT #########

  # County names are converted to county type - metropolitan, micropolitan or non-core
  # For definitions, see US OMB website

  # read in county info csv
  county_df = pd.read_csv(os.path.join(data_dir, '2014-2018.csv'))
  county_df = county_df[county_df['State']=='Texas']
  county_df = county_df.filter(items=['Metropolitan Status', 'County Name'])

  # transform column
  df['county'] = [name[:-7] for name in df['county_name']]
  df['county'] = df['county'].replace('Dewitt','DeWitt')

  # if we want to include only border counties:
  if border_counties:
    print('Including only border counties')
    df = df.loc[df['county'].isin(border_counties),:]

  df = df.join(county_df.set_index('County Name'), on='county')
  df.drop('county', axis = 1, inplace=True)
  df.rename(columns={'Metropolitan Status':'county_type'}, inplace=True)

  if county_type:
    print('Including only a certain type of county')
    df = df.loc[df['county_type'] == county_type,:]
    df.drop(['county_type'], axis = 1, inplace = True)

  # newly added 2023/07/12
  print('# of traffic stops after preprocessing step 1(add county type): ', len(df))
  ###############################################################

  # COMMENT 2023/07/12: What is this????
  #county_df2 = pd.read_csv('/content/drive/MyDrive/traffic_stop/countyinfo.csv')
  #county_df2 = county_df2[county_df2['State']=='Texas']
  #county_df2 = county_df2.filter(items=['Region', 'County Name'])

  # transform column
  #df['county'] = [name[:-7] for name in df['county_name']]
  #df['county'] = df['county'].replace('Dewitt','DeWitt')
  #df = df.join(county_df2.set_index('County Name'), on='county')
  #df.drop('county', axis = 1, inplace=True)
  #df.rename(columns={'Region':'county_region'}, inplace=True)

  # newly added 2023/07/12
  #print('# of traffic stops after preprocessing step 1(add county region): ', len(df))

  ######### Metropolitan block ends here #########

  # if race is other/unknown, we delete the rows!
  df = df.loc[(df['subject_race'] != 'unknown') & (df['subject_race'] != 'other'),:]
  df['subject_race'] = df.subject_race.cat.remove_unused_categories()

  df.drop(['county_name','violation'], axis = 1, inplace = True)

  # I delete the block for with_vio, we never used that

  # based on analysis type, decide y
  if analysis_type == 'citation':
    # Convert 'citation issued' to integer
    df = df.astype({'citation_issued': 'int64'})
    y = df['citation_issued']
    df.drop(['citation_issued'], axis = 1, inplace = True)

  elif analysis_type == 'search':
    df["search_conducted"].fillna(False, inplace = True)
    df = df.astype({'search_conducted': 'int64'})
    y = df['search_conducted']
    df.drop(['search_conducted'], axis = 1, inplace = True)

  elif analysis_type == 'contraband':
    df= df[(df['search_conducted']==1)]
    df = df.reset_index(drop = True)
    df = df.astype({'contraband_found': 'int64'})
    y = df['contraband_found']
    df.drop(['contraband_found', 'search_conducted'], axis = 1, inplace = True)


  # other x variables get dummies
  df = pd.get_dummies(df)
  if not county_type:
    df.drop(['subject_race_white', 'county_type_Metropolitan', 'subject_sex_male'], axis = 1, inplace = True)
  else:
    df.drop(['subject_race_white', 'subject_sex_male'], axis = 1, inplace = True)

  df.reset_index(drop=True, inplace=True)
  y.reset_index(drop=True, inplace=True)

  print('# of traffic stops after preprocessing in year ', year, ': ', len(df))
  return (y, df)

# %%
### this function used in generate_outputs()
def run_year_analysis(analysis_type, rm_na_col, df_years,
                      violation_types=None, border_counties=None, county_type=None, speeding_only=False, serious_violations=True):
  """
  param:
  violation_types: violation types to be included in the analysis

  Output:
  A result dataframe
  """
  years = list(range(year_start, year_end+1))

  for year in years:
    # read in the data
    print('***********************************')
    print(year)

    # read in and preprocess data
    y, X = preprocess(year, rm_na_col, analysis_type, violation_types, border_counties, county_type, speeding_only, serious_violations)
    # added 2023/07/12
    print(X.columns)

    #adding constant to X
    X_with_constant = sm.add_constant(X)
    # building the model and fitting the data
    log_reg = sm.Logit(y, X_with_constant).fit()

    res_df = pd.DataFrame({'variable':list(log_reg.params.index), 'coef':list(log_reg.params.values),
                           'odds_ratio':list(np.exp(log_reg.params.values)),
                           'lower_CI':list(np.exp(log_reg.conf_int()[0].values)),
                           'upper_CI':list(np.exp(log_reg.conf_int()[1].values)),'pvalue':list(log_reg.pvalues)})

    df_years = df_years.merge(res_df, left_on = 'variable', right_on = 'variable', how = 'outer')
    df_years = df_years.rename(columns = {'coef': ('coef_' + str(year)),
                                          'odds_ratio': ('odds_ratio_' + str(year)),
                                          'lower_CI': ('OR_lower_CI_' + str(year)),
                                          'upper_CI': ('OR_upper_CI_' + str(year)),
                                          'pvalue': ('pvalue_' + str(year))})

    # append race coefs to result list for plotting
    black.append(np.exp(log_reg.params['subject_race_black']))
    hispanic.append(np.exp(log_reg.params['subject_race_hispanic']))
    asianpacific.append(np.exp(log_reg.params['subject_race_asian/pacific islander']))

    # lower CI
    black_low.append(np.exp(log_reg.conf_int()[0]['subject_race_black']))
    hispanic_low.append(np.exp(log_reg.conf_int()[0]['subject_race_hispanic']))
    asianpacific_low.append(np.exp(log_reg.conf_int()[0]['subject_race_asian/pacific islander']))

    # upper CI
    black_high.append(np.exp(log_reg.conf_int()[1]['subject_race_black']))
    hispanic_high.append(np.exp(log_reg.conf_int()[1]['subject_race_hispanic']))
    asianpacific_high.append(np.exp(log_reg.conf_int()[1]['subject_race_asian/pacific islander']))

  return df_years

# write result df to csv file

# %%
sns.set_theme()
sns.set_style("whitegrid")

# %%
def generate_outputs(folder_path, analysis_type, violation_types = None,
                     border_counties=None,
                     border_flag='border', # 'border' or 'non-border'
                     county_type=None, speeding_only = False, serious_violations=True):
  """
  function outputs a csv file, a jpg and an svg figure
  PARAMS:
  folder path: eg., '/gdrive/MyDrive/traffic_stop/output_0502/'
  """
  # columns to store
  var_lst_baseline = ['subject_race_black', 'subject_race_hispanic', 'subject_race_asian/pacific islander','subject_sex_female']

  df_years = pd.DataFrame({'variable':var_lst_baseline})


  res_df = run_year_analysis(analysis_type=analysis_type, rm_na_col=rm_na_col, df_years=df_years, violation_types=violation_types,
                    border_counties=border_counties, county_type=county_type, speeding_only=speeding_only)

  # save csv
  speeding = '_speeding' if speeding_only else ''
  if violation_types:
    if serious_violations:
      violation = '_SeriousVio' if violation_types else ''
    else:
      violation = '_NoNSeriousVio' if violation_types else ''
  else:
    violation = ''
  if border_flag == 'border':
    border = '_border' if border_counties else ''
  elif border_flag == 'non-border':
    border = '_non_border' if border_counties else ''
  county = '_' + county_type if county_type else ''

  file_name = analysis_type + speeding + violation + border + county + '.csv'

  # CHANGE THE PATH
  save_path = folder_path + file_name
  res_df.to_csv(save_path, index = False)

  years = list(range(year_start, year_end + 1))

  #sns.set_theme()
  #sns.set_style("white")
  sns.set(font_scale=1.25)
  plt.style.use('seaborn-v0_8-whitegrid')

  sns.lineplot(x = years, y = black, color = 'red', label="Black")
  sns.lineplot(x = years, y = hispanic, color = 'blue', label="Hispanic")
  sns.lineplot(x = years, y = asianpacific, color = 'green', label="Asian/Pacific Islander")

  sns.lineplot(x = years, y = black_low, color = 'red', linestyle='--')
  sns.lineplot(x = years, y = hispanic_low, color = 'blue', linestyle='--')
  sns.lineplot(x = years, y = asianpacific_low, color = 'green', linestyle='--')

  sns.lineplot(x = years, y = black_high, color = 'red', linestyle='--')
  sns.lineplot(x = years, y = hispanic_high, color = 'blue', linestyle='--')
  sns.lineplot(x = years, y = asianpacific_high, color = 'green', linestyle='--')

  # changed 08/04, same y axis scale
  plt.xlim(2006, 2017)
  plt.ylim(0.5, 3.5)

  plt.axhline(y=1, color='grey', alpha=0.8, linestyle='-')
  plt.xlabel('Year')
  plt.ylabel('Odds Ratio')
  plt.legend(bbox_to_anchor=(0.5, -0.36), loc='lower center', ncol = 3)



  # CHANGE THE PATH HERE
  figure_name1 = file_name.replace('csv', 'svg')
  figure_name2 = file_name.replace('csv', 'jpg')
  figure_name3 = file_name.replace('csv', 'pdf')
  plt.savefig((folder_path+figure_name1), format = 'svg', bbox_inches="tight")
  plt.savefig((folder_path+figure_name2), dpi = 200, bbox_inches="tight")
  plt.savefig((folder_path+figure_name3), format="pdf", bbox_inches="tight")

  plt.show()

# %% [markdown]
# ### 00 : Test the refactored code works

# %%
year_start = 2006
year_end = 2017

asianpacific = []
black = []
hispanic = []

asianpacific_low = []
black_low = []
hispanic_low = []

asianpacific_high = []
black_high = []
hispanic_high = []

folder_path ='/content/drive/MyDrive/traffic_stop/FINAL_OUTPUTS/'
#generate_outputs(folder_path = folder_path, with_vio = False, violation_types = None)
generate_outputs(folder_path=folder_path, analysis_type='citation', violation_types=None, border_counties=None, county_type=None, speeding_only=False)
# Out:
# ***********************************
# 2006
# # of all traffic stops in year  2006 :  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2673511
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2673511
# # of traffic stops after preprocessing step 1(add county type):  2673511
# # of traffic stops after preprocessing in year  2006 :  2671708
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.683415
#          Iterations 4
# ***********************************
# 2007
# # of all traffic stops in year  2007 :  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2405744
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2405744
# # of traffic stops after preprocessing step 1(add county type):  2405744
# # of traffic stops after preprocessing in year  2007 :  2404322
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.681823
#          Iterations 4
# ***********************************
# 2008
# # of all traffic stops in year  2008 :  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2434970
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2434970
# # of traffic stops after preprocessing step 1(add county type):  2434970
# # of traffic stops after preprocessing in year  2008 :  2432074
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.659788
#          Iterations 4
# ***********************************
# 2009
# # of all traffic stops in year  2009 :  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2370986
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2370986
# # of traffic stops after preprocessing step 1(add county type):  2370986
# # of traffic stops after preprocessing in year  2009 :  2368223
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.651569
#          Iterations 5
# ***********************************
# 2010
# # of all traffic stops in year  2010 :  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2452498
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2452498
# # of traffic stops after preprocessing step 1(add county type):  2452498
# # of traffic stops after preprocessing in year  2010 :  2449377
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.633692
#          Iterations 5
# ***********************************
# 2011
# # of all traffic stops in year  2011 :  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2511664
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2511664
# # of traffic stops after preprocessing step 1(add county type):  2511664
# # of traffic stops after preprocessing in year  2011 :  2508218
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.628745
#          Iterations 5
# ***********************************
# 2012
# # of all traffic stops in year  2012 :  2435812
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2368991
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2368990
# # of traffic stops after preprocessing step 1(add county type):  2368990
# # of traffic stops after preprocessing in year  2012 :  2364658
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.638596
#          Iterations 5
# ***********************************
# 2013
# # of all traffic stops in year  2013 :  2134936
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2076400
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2076396
# # of traffic stops after preprocessing step 1(add county type):  2076396
# # of traffic stops after preprocessing in year  2013 :  2071465
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.643136
#          Iterations 5
# ***********************************
# 2014
# # of all traffic stops in year  2014 :  1878488
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1820773
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1820763
# # of traffic stops after preprocessing step 1(add county type):  1820763
# # of traffic stops after preprocessing in year  2014 :  1816151
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.644490
#          Iterations 5
# ***********************************
# 2015
# # of all traffic stops in year  2015 :  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1683954
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1683940
# # of traffic stops after preprocessing step 1(add county type):  1683940
# # of traffic stops after preprocessing in year  2015 :  1678602
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.638991
#          Iterations 5
# ***********************************
# 2016
# # of all traffic stops in year  2016 :  1832207
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1832089
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1832072
# # of traffic stops after preprocessing step 1(add county type):  1832072
# # of traffic stops after preprocessing in year  2016 :  1830586
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.644337
#          Iterations 5
# ***********************************
# 2017
# # of all traffic stops in year  2017 :  2197382
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2197369
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2197369
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2197361
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2197356
# # of traffic stops after preprocessing step 1(add county type):  2197356
# # of traffic stops after preprocessing in year  2017 :  2195417
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.642497
#          Iterations 5
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[55], line 18
#      16 folder_path ='/content/drive/MyDrive/traffic_stop/FINAL_OUTPUTS/'
#      17 #generate_outputs(folder_path = folder_path, with_vio = False, violation_types = None)
# ---> 18 generate_outputs(folder_path=folder_path, analysis_type='citation', violation_types=None, border_counties=None, county_type=None, speeding_only=False)
#
# Cell In[54], line 27, in generate_outputs(folder_path, analysis_type, violation_types, border_counties, county_type, speeding_only, serious_violations)
#      24 border = '_non_border' if border_counties else ''
#      25 county = '_' + county_type if county_type else ''
# ---> 27 file_name = analysis_type + speeding + violation + border + county + '.csv'
#      29 # CHANGE THE PATH
#      30 save_path = folder_path + file_name
#
# UnboundLocalError: cannot access local variable 'violation' where it is not associated with a value

# %% [markdown]
# ### 1. Warning and Citation Rate

# %% [markdown]
# The plot included in the email is using the outcome variable. There are records with both citation_issued = 1 and warning_issued = 1, but in the outcome variable, it is classified as citation(citation / warning+citation);  warning(only warning), and nan.
#
# In the citation_issued variable, citation = 1 also means only citation or citation+warning.
#
# In the warning_issued variable, warning = 1 means only warning or citation+warning

# %%
year_start = 2006
year_end = 2017

years = list(range(year_start, year_end+1))
for year in years:
  filename = '/content/drive/MyDrive/traffic_stop/year_data/traffic_' + str(year) + '.parquet'
  df = pd.read_parquet(filename, engine = 'pyarrow')
  print(df['outcome'].value_counts(dropna = False))
  print('# of citation issued: ', sum(df['citation_issued']))
  print('# of warning issued: ', sum(df['warning_issued']))
  print('# of both citation and warning: ', len(df.loc[(df['citation_issued']==1) & (df['warning_issued']==1),:]))
  print('Check equation: ', len(df.loc[(df['citation_issued']==1) & (df['warning_issued']==1),:]) + df['outcome'].value_counts(dropna = False)['warning'] == sum(df['warning_issued']))
# Out:
# warning     1486673
# citation    1207142
# NaN              79
# summons           0
# arrest            0
# Name: outcome, dtype: int64
# # of citation issued:  1207142
# # of warning issued:  1895614
# # of both citation and warning:  408941
# Check equation:  True
# warning     1355355
# citation    1071775
# NaN             217
# summons           0
# arrest            0
# Name: outcome, dtype: int64
# # of citation issued:  1071775
# # of warning issued:  1717430
# # of both citation and warning:  362075
# Check equation:  True
# warning     1552946
# citation     973574
# NaN             263
# summons           0
# arrest            0
# Name: outcome, dtype: int64
# # of citation issued:  973574
# # of warning issued:  1900742
# # of both citation and warning:  347796
# Check equation:  True
# warning     1545015
# citation     896255
# NaN              36
# summons           0
# arrest            0
# Name: outcome, dtype: int64
# # of citation issued:  896255
# # of warning issued:  1873889
# # of both citation and warning:  328874
# Check equation:  True
# warning     1676477
# citation     848789
# NaN              30
# summons           0
# arrest            0
# Name: outcome, dtype: int64
# # of citation issued:  848789
# # of warning issued:  2011096
# # of both citation and warning:  334619
# Check equation:  True
# warning     1730200
# citation     857791
# NaN              13
# summons           0
# arrest            0
# Name: outcome, dtype: int64
# # of citation issued:  857791
# # of warning issued:  2081060
# # of both citation and warning:  350860
# Check equation:  True
# warning     1585007
# citation     850791
# NaN              14
# summons           0
# arrest            0
# Name: outcome, dtype: int64
# # of citation issued:  850791
# # of warning issued:  1925082
# # of both citation and warning:  340075
# Check equation:  True
# warning     1368468
# citation     765695
# NaN             773
# summons           0
# arrest            0
# Name: outcome, dtype: int64
# # of citation issued:  765695
# # of warning issued:  1669127
# # of both citation and warning:  300659
# Check equation:  True
# warning     1203109
# citation     675378
# NaN               1
# summons           0
# arrest            0
# Name: outcome, dtype: int64
# # of citation issued:  675378
# # of warning issued:  1469888
# # of both citation and warning:  266779
# Check equation:  True
# warning     1131898
# citation     613487
# summons           0
# arrest            0
# Name: outcome, dtype: int64
# # of citation issued:  613487
# # of warning issued:  1369325
# # of both citation and warning:  237427
# Check equation:  True
# warning     1163748
# citation     668265
# NaN             194
# summons           0
# arrest            0
# Name: outcome, dtype: int64
# # of citation issued:  668265
# # of warning issued:  1436648
# # of both citation and warning:  272900
# Check equation:  True
# warning     1398771
# citation     797874
# NaN             737
# summons           0
# arrest            0
# Name: outcome, dtype: int64
# # of citation issued:  797874
# # of warning issued:  1750214
# # of both citation and warning:  351443
# Check equation:  True

# %% [markdown]
# ### 2. Separate Models for Border Counties and Non-border Counties

# %% [markdown]
# See definition at: https://www.dshs.texas.gov/regional-local-health-operations/texas-border-health/map-dshs-border-area

# %%
county_df = pd.read_csv(os.path.join(data_dir, '2014-2018.csv'))
county_df = county_df[county_df['State']=='Texas']
county_df
# Out:
#                geoid County Name  State  metro code Metropolitan Status  \
# 2601  0500000US48001    Anderson  Texas         NaN        Micropolitan
# 2602  0500000US48003     Andrews  Texas         NaN        Micropolitan
# 2603  0500000US48005    Angelina  Texas         NaN        Micropolitan
# 2604  0500000US48007     Aransas  Texas         NaN        Metropolitan
# 2605  0500000US48009      Archer  Texas         NaN        Metropolitan
# ...              ...         ...    ...         ...                 ...
# 2850  0500000US48499        Wood  Texas         NaN            Non core
# 2851  0500000US48501      Yoakum  Texas         NaN            Non core
# 2852  0500000US48503       Young  Texas         NaN            Non core
# 2853  0500000US48505      Zapata  Texas         NaN        Micropolitan
# 2854  0500000US48507      Zavala  Texas         NaN            Non core
#
#       Total Population  Total population, MOE  Disabiltiy Population  \
# 2601             44367                    513                   5500
# 2602             17478                     45                   1662
# 2603             85494                    276                  16037
# 2604             24416                    150                   5075
# 2605              8725                     59                   1337
# ...                ...                    ...                    ...
# 2850             42388                    208                   9248
# 2851              8481                     19                    902
# 2852             17861                     78                   2656
# 2853             14378                     57                   2467
# 2854             11926                     53                   3205
#
#       Disability Population, MOE  Disabitiy Rate  ...  Disability Rate-Asian  \
# 2601                         453            12.4  ...                    0.0
# 2602                         246             9.5  ...                    0.0
# 2603                         782            18.8  ...                    9.5
# 2604                         565            20.8  ...                   21.0
# 2605                         154            15.3  ...                    0.0
# ...                          ...             ...  ...                    ...
# 2850                         604            21.8  ...                   32.4
# 2851                         174            10.6  ...                    0.0
# 2852                         367            14.9  ...                   46.7
# 2853                         367            17.2  ...                    0.0
# 2854                         414            26.9  ...                    NaN
#
#       Disability Rate-American Indian/Alaskan Native  \
# 2601                                            16.9
# 2602                                             0.0
# 2603                                             5.4
# 2604                                            79.8
# 2605                                            18.9
# ...                                              ...
# 2850                                            25.9
# 2851                                             0.0
# 2852                                            12.6
# 2853                                             NaN
# 2854                                           100.0
#
#       Disability Rate-Native Hawaiian Pacific Islander  \
# 2601                                               0.0
# 2602                                               0.0
# 2603                                               0.0
# 2604                                               NaN
# 2605                                               NaN
# ...                                                ...
# 2850                                               0.0
# 2851                                               NaN
# 2852                                               NaN
# 2853                                               NaN
# 2854                                               NaN
#
#       Disability Rate-Other race  Disability Rate-Two or more races  \
# 2601                         2.7                               22.2
# 2602                         2.0                               22.6
# 2603                        11.6                               16.7
# 2604                         9.9                               27.6
# 2605                         0.0                               22.9
# ...                          ...                                ...
# 2850                         4.0                               12.5
# 2851                        14.9                                0.0
# 2852                         4.9                                0.0
# 2853                        30.4                                NaN
# 2854                        14.1                               50.0
#
#       Disability Rate- Hispanic (of any race)  Unnamed: 32  Unnamed: 33  \
# 2601                                      4.8          NaN          NaN
# 2602                                      6.8          NaN          NaN
# 2603                                      8.7          NaN          NaN
# 2604                                     13.9          NaN          NaN
# 2605                                     13.8          NaN          NaN
# ...                                       ...          ...          ...
# 2850                                     11.7          NaN          NaN
# 2851                                      8.1          NaN          NaN
# 2852                                      3.7          NaN          NaN
# 2853                                     16.4          NaN          NaN
# 2854                                     26.7          NaN          NaN
#
#       Unnamed: 34  Unnamed: 35
# 2601          NaN          NaN
# 2602          NaN          NaN
# 2603          NaN          NaN
# 2604          NaN          NaN
# 2605          NaN          NaN
# ...           ...          ...
# 2850          NaN          NaN
# 2851          NaN          NaN
# 2852          NaN          NaN
# 2853          NaN          NaN
# 2854          NaN          NaN
#
# [254 rows x 36 columns]

# %%
border_counties = ['Brewster', 'La Salle',
'Brooks',	'Maverick',
'Cameron',	'McMullen',
'Crockett',	'Pecos',
'Culberson',	'Presidio',
'Dimmit',	'Real',
'Duval',	'Reeves',
'Edwards',	'Starr',
'El Paso',	'Sutton',
'Frio',	'Terrell',
'Hidalgo',	'Uvalde',
'Hudspeth',	'Val Verde',
'Jeff Davis',	'Webb',
'Jim Hogg',	'Willacy',
'Kenedy',	'Zapata',
'Kinney',	'Zavala']

intersection = 0
unfound = 0
for county in border_counties:
  if county in list(county_df['County Name']):
    intersection += 1
  else:
    unfound += 1
    print(county)

print('intersection: ', intersection)
print('unfound: ', unfound)
# Out:
# intersection:  32
# unfound:  0

# %% [markdown]
# #### Border Counties

# %% [markdown]
# ##### All stops, citation

# %%
year_start = 2006
year_end = 2017

asianpacific = []
black = []
hispanic = []

asianpacific_low = []
black_low = []
hispanic_low = []

asianpacific_high = []
black_high = []
hispanic_high = []

folder_path ='./'
#generate_outputs(folder_path = folder_path, with_vio = False, violation_types = None)
generate_outputs(folder_path=folder_path, analysis_type='citation', violation_types=None, border_counties=border_counties, county_type=None, speeding_only=False)
# Out:
# ***********************************
# 2006
# # of all traffic stops in year  2006 :  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2673511
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2673511
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  382756
# # of traffic stops after preprocessing in year  2006 :  382597
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.684419
#          Iterations 4
# ***********************************
# 2007
# # of all traffic stops in year  2007 :  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2405744
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2405744
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  364951
# # of traffic stops after preprocessing in year  2007 :  364731
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.675493
#          Iterations 4
# ***********************************
# 2008
# # of all traffic stops in year  2008 :  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2434970
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2434970
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  565951
# # of traffic stops after preprocessing in year  2008 :  565467
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.566623
#          Iterations 5
# ***********************************
# 2009
# # of all traffic stops in year  2009 :  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2370986
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2370986
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  397520
# # of traffic stops after preprocessing in year  2009 :  397328
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.635298
#          Iterations 5
# ***********************************
# 2010
# # of all traffic stops in year  2010 :  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2452498
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2452498
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  404630
# # of traffic stops after preprocessing in year  2010 :  404428
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.622645
#          Iterations 5
# ***********************************
# 2011
# # of all traffic stops in year  2011 :  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2511664
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2511664
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  374721
# # of traffic stops after preprocessing in year  2011 :  374542
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.624892
#          Iterations 5
# ***********************************
# 2012
# # of all traffic stops in year  2012 :  2435812
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2368991
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2368990
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  317037
# # of traffic stops after preprocessing in year  2012 :  316763
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.653932
#          Iterations 5
# ***********************************
# 2013
# # of all traffic stops in year  2013 :  2134936
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2076400
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2076396
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  298718
# # of traffic stops after preprocessing in year  2013 :  298348
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.656426
#          Iterations 5
# ***********************************
# 2014
# # of all traffic stops in year  2014 :  1878488
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1820773
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1820763
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  345610
# # of traffic stops after preprocessing in year  2014 :  345138
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.605978
#          Iterations 5
# ***********************************
# 2015
# # of all traffic stops in year  2015 :  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1683954
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1683940
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  407699
# # of traffic stops after preprocessing in year  2015 :  406913
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.586789
#          Iterations 5
# ***********************************
# 2016
# # of all traffic stops in year  2016 :  1832207
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1832089
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1832072
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  447159
# # of traffic stops after preprocessing in year  2016 :  446937
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.618057
#          Iterations 5
# ***********************************
# 2017
# # of all traffic stops in year  2017 :  2197382
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2197369
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2197369
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2197361
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2197356
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  571830
# # of traffic stops after preprocessing in year  2017 :  571531
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.618265
#          Iterations 5
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[58], line 18
#      16 folder_path ='./'
#      17 #generate_outputs(folder_path = folder_path, with_vio = False, violation_types = None)
# ---> 18 generate_outputs(folder_path=folder_path, analysis_type='citation', violation_types=None, border_counties=border_counties, county_type=None, speeding_only=False)
#
# Cell In[54], line 27, in generate_outputs(folder_path, analysis_type, violation_types, border_counties, county_type, speeding_only, serious_violations)
#      24 border = '_non_border' if border_counties else ''
#      25 county = '_' + county_type if county_type else ''
# ---> 27 file_name = analysis_type + speeding + violation + border + county + '.csv'
#      29 # CHANGE THE PATH
#      30 save_path = folder_path + file_name
#
# UnboundLocalError: cannot access local variable 'violation' where it is not associated with a value

# %% [markdown]
# ##### All stops, search

# %%
year_start = 2006
year_end = 2016

asianpacific = []
black = []
hispanic = []

asianpacific_low = []
black_low = []
hispanic_low = []

asianpacific_high = []
black_high = []
hispanic_high = []

folder_path ='/content/drive/MyDrive/traffic_stop/FINAL_OUTPUTS/'
#generate_outputs(folder_path = folder_path, with_vio = False, violation_types = None)
generate_outputs(folder_path=folder_path, analysis_type='search', violation_types=None, border_counties=border_counties, county_type=None, speeding_only=False)
# Out:
# ***********************************
# 2006
# # of all traffic stops in year  2006 :  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2673511
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2673511
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  382756
# # of traffic stops after preprocessing in year  2006 :  382597
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.139009
#          Iterations 8
# ***********************************
# 2007
# # of all traffic stops in year  2007 :  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2405744
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2405744
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  364951
# # of traffic stops after preprocessing in year  2007 :  364731
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.127278
#          Iterations 8
# ***********************************
# 2008
# # of all traffic stops in year  2008 :  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2434970
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2434970
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  565951
# # of traffic stops after preprocessing in year  2008 :  565467
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.106557
#          Iterations 9
# ***********************************
# 2009
# # of all traffic stops in year  2009 :  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2370986
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2370986
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  397520
# # of traffic stops after preprocessing in year  2009 :  397328
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.087650
#          Iterations 9
# ***********************************
# 2010
# # of all traffic stops in year  2010 :  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2452498
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2452498
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  404630
# # of traffic stops after preprocessing in year  2010 :  404428
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.092651
#          Iterations 9
# ***********************************
# 2011
# # of all traffic stops in year  2011 :  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2511664
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2511664
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  374721
# # of traffic stops after preprocessing in year  2011 :  374542
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.097906
#          Iterations 9
# ***********************************
# 2012
# # of all traffic stops in year  2012 :  2435812
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2368991
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2368990
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  317037
# # of traffic stops after preprocessing in year  2012 :  316763
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.081802
#          Iterations 9
# ***********************************
# 2013
# # of all traffic stops in year  2013 :  2134936
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2076400
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2076396
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  298718
# # of traffic stops after preprocessing in year  2013 :  298348
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.073779
#          Iterations 9
# ***********************************
# 2014
# # of all traffic stops in year  2014 :  1878488
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1820773
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1820763
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  345610
# # of traffic stops after preprocessing in year  2014 :  345138
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.070663
#          Iterations 9
# ***********************************
# 2015
# # of all traffic stops in year  2015 :  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1683954
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1683940
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  407699
# # of traffic stops after preprocessing in year  2015 :  406913
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.071951
#          Iterations 9
# ***********************************
# 2016
# # of all traffic stops in year  2016 :  1832207
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1832089
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1832072
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  447159
# # of traffic stops after preprocessing in year  2016 :  446937
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.069310
#          Iterations 9

# %% [markdown]
# ##### All stops, contraband_found

# %%
year_start = 2006
year_end = 2016

asianpacific = []
black = []
hispanic = []

asianpacific_low = []
black_low = []
hispanic_low = []

asianpacific_high = []
black_high = []
hispanic_high = []

folder_path ='/content/drive/MyDrive/traffic_stop/FINAL_OUTPUTS/'
#generate_outputs(folder_path = folder_path, with_vio = False, violation_types = None)
generate_outputs(folder_path=folder_path, analysis_type='contraband', violation_types=None, border_counties=border_counties, county_type=None, speeding_only=False)
# Out:
# ***********************************
# 2006
# # of all traffic stops in year  2006 :  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2673511
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2673511
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  382756
# # of traffic stops after preprocessing in year  2006 :  12181
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.380286
#          Iterations 6
# ***********************************
# 2007
# # of all traffic stops in year  2007 :  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2405744
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2405744
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  364951
# # of traffic stops after preprocessing in year  2007 :  10374
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.380196
#          Iterations 6
# ***********************************
# 2008
# # of all traffic stops in year  2008 :  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2434970
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2434970
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  565951
# # of traffic stops after preprocessing in year  2008 :  12791
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.348054
#          Iterations 6
# ***********************************
# 2009
# # of all traffic stops in year  2009 :  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2370986
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2370986
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  397520
# # of traffic stops after preprocessing in year  2009 :  7050
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.378848
#          Iterations 6
# ***********************************
# 2010
# # of all traffic stops in year  2010 :  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2452498
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2452498
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  404630
# # of traffic stops after preprocessing in year  2010 :  7689
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.350169
#          Iterations 6
# ***********************************
# 2011
# # of all traffic stops in year  2011 :  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2511664
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2511664
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  374721
# # of traffic stops after preprocessing in year  2011 :  7663
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.406630
#          Iterations 6
# ***********************************
# 2012
# # of all traffic stops in year  2012 :  2435812
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2368991
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2368990
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  317037
# # of traffic stops after preprocessing in year  2012 :  5154
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.491630
#          Iterations 6
# ***********************************
# 2013
# # of all traffic stops in year  2013 :  2134936
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2076400
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2076396
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  298718
# # of traffic stops after preprocessing in year  2013 :  4279
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.480728
#          Iterations 6
# ***********************************
# 2014
# # of all traffic stops in year  2014 :  1878488
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1820773
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1820763
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  345610
# # of traffic stops after preprocessing in year  2014 :  4686
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.440238
#          Iterations 6
# ***********************************
# 2015
# # of all traffic stops in year  2015 :  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1683954
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1683940
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  407699
# # of traffic stops after preprocessing in year  2015 :  5627
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.458414
#          Iterations 6
# ***********************************
# 2016
# # of all traffic stops in year  2016 :  1832207
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1832089
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1832072
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  447159
# # of traffic stops after preprocessing in year  2016 :  5912
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.522752
#          Iterations 6

# %% [markdown]
# ##### speeding_only, citation

# %%
year_start = 2006
year_end = 2017

asianpacific = []
black = []
hispanic = []

asianpacific_low = []
black_low = []
hispanic_low = []

asianpacific_high = []
black_high = []
hispanic_high = []

folder_path ='./'
#generate_outputs(folder_path = folder_path, with_vio = False, violation_types = None)
generate_outputs(folder_path=folder_path,
                 analysis_type='citation',
                 violation_types=None,
                 border_counties=border_counties,
                 border_flag='border',
                 county_type=None,
                 speeding_only=True)
# Out:
# ***********************************
# 2006
# # of all traffic stops in year  2006 :  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2673511
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2673511
# Before speed filtering:  2673511
# Speeding only violation has records:  1235103
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  167628
# # of traffic stops after preprocessing in year  2006 :  167541
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.679090
#          Iterations 4
# ***********************************
# 2007
# # of all traffic stops in year  2007 :  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2405744
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2405744
# Before speed filtering:  2405744
# Speeding only violation has records:  1110868
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  161090
# # of traffic stops after preprocessing in year  2007 :  160971
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.663995
#          Iterations 4
# ***********************************
# 2008
# # of all traffic stops in year  2008 :  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2434970
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2434970
# Before speed filtering:  2434970
# Speeding only violation has records:  1114925
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  242766
# # of traffic stops after preprocessing in year  2008 :  242563
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.502456
#          Iterations 6
# ***********************************
# 2009
# # of all traffic stops in year  2009 :  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2370986
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2370986
# Before speed filtering:  2370986
# Speeding only violation has records:  1093968
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  156403
# # of traffic stops after preprocessing in year  2009 :  156315
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.585415
#          Iterations 5
# ***********************************
# 2010
# # of all traffic stops in year  2010 :  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2452498
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2452498
# Before speed filtering:  2452498
# Speeding only violation has records:  1085945
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  140462
# # of traffic stops after preprocessing in year  2010 :  140369
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.577757
#          Iterations 5
# ***********************************
# 2011
# # of all traffic stops in year  2011 :  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2511664
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2511664
# Before speed filtering:  2511664
# Speeding only violation has records:  1085781
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  126988
# # of traffic stops after preprocessing in year  2011 :  126902
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.578002
#          Iterations 5
# ***********************************
# 2012
# # of all traffic stops in year  2012 :  2435812
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2368991
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2368990
# Before speed filtering:  2368990
# Speeding only violation has records:  1025815
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  106967
# # of traffic stops after preprocessing in year  2012 :  106847
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.625159
#          Iterations 5
# ***********************************
# 2013
# # of all traffic stops in year  2013 :  2134936
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2076400
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2076396
# Before speed filtering:  2076396
# Speeding only violation has records:  905817
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  103962
# # of traffic stops after preprocessing in year  2013 :  103803
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.629219
#          Iterations 5
# ***********************************
# 2014
# # of all traffic stops in year  2014 :  1878488
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1820773
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1820763
# Before speed filtering:  1820763
# Speeding only violation has records:  779279
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  119261
# # of traffic stops after preprocessing in year  2014 :  119074
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.566727
#          Iterations 6
# ***********************************
# 2015
# # of all traffic stops in year  2015 :  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1683954
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1683940
# Before speed filtering:  1683940
# Speeding only violation has records:  730702
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  137926
# # of traffic stops after preprocessing in year  2015 :  137626
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.534639
#          Iterations 6
# ***********************************
# 2016
# # of all traffic stops in year  2016 :  1832207
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1832089
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1832072
# Before speed filtering:  1832072
# Speeding only violation has records:  797329
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  154872
# # of traffic stops after preprocessing in year  2016 :  154778
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.559397
#          Iterations 6
# ***********************************
# 2017
# # of all traffic stops in year  2017 :  2197382
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2197369
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2197369
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2197361
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2197356
# Before speed filtering:  2197356
# Speeding only violation has records:  895256
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  183657
# # of traffic stops after preprocessing in year  2017 :  183530
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.550530
#          Iterations 6

# %% [markdown]
# ##### speeding_only, search

# %%
year_start = 2006
year_end = 2016

asianpacific = []
black = []
hispanic = []

asianpacific_low = []
black_low = []
hispanic_low = []

asianpacific_high = []
black_high = []
hispanic_high = []

folder_path ='/content/drive/MyDrive/traffic_stop/FINAL_OUTPUTS/'
#generate_outputs(folder_path = folder_path, with_vio = False, violation_types = None)
generate_outputs(folder_path=folder_path, analysis_type='search', violation_types=None, border_counties=border_counties, county_type=None, speeding_only=True)
# Out:
# ***********************************
# 2006
# # of all traffic stops in year  2006 :  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2673511
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2673511
# Before speed filtering:  2673511
# Speeding only violation has records:  1235103
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  167628
# # of traffic stops after preprocessing in year  2006 :  167541
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.058136
#          Iterations 9
# ***********************************
# 2007
# # of all traffic stops in year  2007 :  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2405744
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2405744
# Before speed filtering:  2405744
# Speeding only violation has records:  1110868
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  161090
# # of traffic stops after preprocessing in year  2007 :  160971
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.055211
#          Iterations 9
# ***********************************
# 2008
# # of all traffic stops in year  2008 :  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2434970
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2434970
# Before speed filtering:  2434970
# Speeding only violation has records:  1114925
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  242766
# # of traffic stops after preprocessing in year  2008 :  242563
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.054412
#          Iterations 9
# ***********************************
# 2009
# # of all traffic stops in year  2009 :  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2370986
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2370986
# Before speed filtering:  2370986
# Speeding only violation has records:  1093968
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  156403
# # of traffic stops after preprocessing in year  2009 :  156315
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.039749
#          Iterations 10
# ***********************************
# 2010
# # of all traffic stops in year  2010 :  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2452498
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2452498
# Before speed filtering:  2452498
# Speeding only violation has records:  1085945
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  140462
# # of traffic stops after preprocessing in year  2010 :  140369
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.042622
#          Iterations 10
# ***********************************
# 2011
# # of all traffic stops in year  2011 :  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2511664
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2511664
# Before speed filtering:  2511664
# Speeding only violation has records:  1085781
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  126988
# # of traffic stops after preprocessing in year  2011 :  126902
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.040639
#          Iterations 10
# ***********************************
# 2012
# # of all traffic stops in year  2012 :  2435812
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2368991
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2368990
# Before speed filtering:  2368990
# Speeding only violation has records:  1025815
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  106967
# # of traffic stops after preprocessing in year  2012 :  106847
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.028825
#          Iterations 10
# ***********************************
# 2013
# # of all traffic stops in year  2013 :  2134936
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2076400
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2076396
# Before speed filtering:  2076396
# Speeding only violation has records:  905817
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  103962
# # of traffic stops after preprocessing in year  2013 :  103803
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.028151
#          Iterations 11
# ***********************************
# 2014
# # of all traffic stops in year  2014 :  1878488
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1820773
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1820763
# Before speed filtering:  1820763
# Speeding only violation has records:  779279
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  119261
# # of traffic stops after preprocessing in year  2014 :  119074
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.030474
#          Iterations 11
# ***********************************
# 2015
# # of all traffic stops in year  2015 :  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1683954
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1683940
# Before speed filtering:  1683940
# Speeding only violation has records:  730702
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  137926
# # of traffic stops after preprocessing in year  2015 :  137626
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.028992
#          Iterations 10
# ***********************************
# 2016
# # of all traffic stops in year  2016 :  1832207
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1832089
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1832072
# Before speed filtering:  1832072
# Speeding only violation has records:  797329
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  154872
# # of traffic stops after preprocessing in year  2016 :  154778
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.027120
#          Iterations 10

# %% [markdown]
# ##### speeding_only, contraband_found
#
# (TOO FEW RECORDS, DID NOT CONVERGE)

# %%
year_start = 2006
year_end = 2016

asianpacific = []
black = []
hispanic = []

asianpacific_low = []
black_low = []
hispanic_low = []

asianpacific_high = []
black_high = []
hispanic_high = []

folder_path ='/content/drive/MyDrive/traffic_stop/FINAL_OUTPUTS/'
#generate_outputs(folder_path = folder_path, with_vio = False, violation_types = None)
generate_outputs(folder_path=folder_path, analysis_type='contraband', violation_types=None, border_counties=border_counties, county_type=None, speeding_only=True)
# Out:
# ***********************************
# 2006
# # of all traffic stops in year  2006 :  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2673511
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2673511
# Before speed filtering:  2673511
# Speeding only violation has records:  1235103
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  167628
# # of traffic stops after preprocessing in year  2006 :  1793
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.155212
#          Iterations: 35
# ***********************************
# 2007
# # of all traffic stops in year  2007 :  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2405744
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2405744
# Before speed filtering:  2405744
# Speeding only violation has records:  1110868
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  161090
# # of traffic stops after preprocessing in year  2007 :  1620
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.158973
#          Iterations 8
# ***********************************
# 2008
# # of all traffic stops in year  2008 :  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2434970
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2434970
# Before speed filtering:  2434970
# Speeding only violation has records:  1114925
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  242766
# # of traffic stops after preprocessing in year  2008 :  2396
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.093940
#          Iterations: 35
# ***********************************
# 2009
# # of all traffic stops in year  2009 :  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2370986
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2370986
# Before speed filtering:  2370986
# Speeding only violation has records:  1093968
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  156403
# # of traffic stops after preprocessing in year  2009 :  1054
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.115047
#          Iterations 8
# ***********************************
# 2010
# # of all traffic stops in year  2010 :  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2452498
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2452498
# Before speed filtering:  2452498
# Speeding only violation has records:  1085945
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  140462
# # of traffic stops after preprocessing in year  2010 :  1033
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.110699
#          Iterations: 35
# ***********************************
# 2011
# # of all traffic stops in year  2011 :  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2511664
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2511664
# Before speed filtering:  2511664
# Speeding only violation has records:  1085781
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  126988
# # of traffic stops after preprocessing in year  2011 :  899
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.095872
#          Iterations: 35
# ***********************************
# 2012
# # of all traffic stops in year  2012 :  2435812
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2368991
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2368990
# Before speed filtering:  2368990
# Speeding only violation has records:  1025815
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  106967
# # of traffic stops after preprocessing in year  2012 :  497
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.181032
#          Iterations: 35
# ***********************************
# 2013
# # of all traffic stops in year  2013 :  2134936
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2076400
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2076396
# Before speed filtering:  2076396
# Speeding only violation has records:  905817
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  103962
# # of traffic stops after preprocessing in year  2013 :  467
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.127919
#          Iterations: 35
# ***********************************
# 2014
# # of all traffic stops in year  2014 :  1878488
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1820773
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1820763
# Before speed filtering:  1820763
# Speeding only violation has records:  779279
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  119261
# # of traffic stops after preprocessing in year  2014 :  592
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.150120
#          Iterations: 35
# ***********************************
# 2015
# # of all traffic stops in year  2015 :  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1683954
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1683940
# Before speed filtering:  1683940
# Speeding only violation has records:  730702
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  137926
# # of traffic stops after preprocessing in year  2015 :  637
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.138974
#          Iterations 32
# ***********************************
# 2016
# # of all traffic stops in year  2016 :  1832207
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1832089
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1832072
# Before speed filtering:  1832072
# Speeding only violation has records:  797329
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  154872
# # of traffic stops after preprocessing in year  2016 :  663
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: inf
#          Iterations: 35
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-58-1a21b95eb794> in <cell line: 18>()
#      16 folder_path ='/content/drive/MyDrive/traffic_stop/FINAL_OUTPUTS/'
#      17 #generate_outputs(folder_path = folder_path, with_vio = False, violation_types = None)
# ---> 18 generate_outputs(folder_path=folder_path, analysis_type='contraband', violation_types=None, border_counties=border_counties, county_type=None, speeding_only=True)
#
# <ipython-input-44-cd5697b1d182> in generate_outputs(folder_path, analysis_type, violation_types, border_counties, county_type, speeding_only)
#      11
#      12
# ---> 13   res_df = run_year_analysis(analysis_type=analysis_type, rm_na_col=rm_na_col, df_years=df_years, violation_types=violation_types,
#      14                     border_counties=border_counties, county_type=county_type, speeding_only=speeding_only)
#      15
#
# <ipython-input-55-1ffd4bfb05d9> in run_year_analysis(analysis_type, rm_na_col, df_years, violation_types, border_counties, county_type, speeding_only)
#      24     X_with_constant = sm.add_constant(X)
#      25     # building the model and fitting the data
# ---> 26     log_reg = sm.Logit(y, X_with_constant).fit()
#      27
#      28     res_df = pd.DataFrame({'variable':list(log_reg.params.index), 'coef':list(log_reg.params.values),
#
# /usr/local/lib/python3.10/dist-packages/statsmodels/discrete/discrete_model.py in fit(self, start_params, method, maxiter, full_output, disp, callback, **kwargs)
#    1981     def fit(self, start_params=None, method='newton', maxiter=35,
#    1982             full_output=1, disp=1, callback=None, **kwargs):
# -> 1983         bnryfit = super().fit(start_params=start_params,
#    1984                               method=method,
#    1985                               maxiter=maxiter,
#
# /usr/local/lib/python3.10/dist-packages/statsmodels/discrete/discrete_model.py in fit(self, start_params, method, maxiter, full_output, disp, callback, **kwargs)
#     228             pass  # TODO: make a function factory to have multiple call-backs
#     229
# --> 230         mlefit = super().fit(start_params=start_params,
#     231                              method=method,
#     232                              maxiter=maxiter,
#
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py in fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     577             Hinv = cov_params_func(self, xopt, retvals)
#     578         elif method == 'newton' and full_output:
# --> 579             Hinv = np.linalg.inv(-retvals['Hessian']) / nobs
#     580         elif not skip_hessian:
#     581             H = -1 * self.hessian(xopt)
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/overrides.py in inv(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/numpy/linalg/linalg.py in inv(a)
#     543     signature = 'D->D' if isComplexType(t) else 'd->d'
#     544     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 545     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     546     return wrap(ainv.astype(result_t, copy=False))
#     547
#
# /usr/local/lib/python3.10/dist-packages/numpy/linalg/linalg.py in _raise_linalgerror_singular(err, flag)
#      86
#      87 def _raise_linalgerror_singular(err, flag):
# ---> 88     raise LinAlgError("Singular matrix")
#      89
#      90 def _raise_linalgerror_nonposdef(err, flag):
#
# LinAlgError: Singular matrix

# %% [markdown]
# #### Non-border Counties

# %% [markdown]
# ###### All stops, citation

# %%
year_start = 2006
year_end = 2017

asianpacific = []
black = []
hispanic = []

asianpacific_low = []
black_low = []
hispanic_low = []

asianpacific_high = []
black_high = []
hispanic_high = []

folder_path ='/content/drive/MyDrive/traffic_stop/FINAL_OUTPUTS/'
#generate_outputs(folder_path = folder_path, with_vio = False, violation_types = None)
non_border_counties = [county for county in list(county_df['County Name']) if county not in border_counties]
generate_outputs(folder_path=folder_path, analysis_type='citation', violation_types=None, border_counties=non_border_counties, county_type=None, speeding_only=False)
# Out:
# ***********************************
# 2006
# # of all traffic stops in year  2006 :  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2673511
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2673511
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  2290755
# # of traffic stops after preprocessing in year  2006 :  2289111
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.682552
#          Iterations 4
# ***********************************
# 2007
# # of all traffic stops in year  2007 :  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2405744
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2405744
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  2040793
# # of traffic stops after preprocessing in year  2007 :  2039591
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.682105
#          Iterations 4
# ***********************************
# 2008
# # of all traffic stops in year  2008 :  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2434970
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2434970
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  1869019
# # of traffic stops after preprocessing in year  2008 :  1866607
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.675623
#          Iterations 4
# ***********************************
# 2009
# # of all traffic stops in year  2009 :  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2370986
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2370986
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  1973466
# # of traffic stops after preprocessing in year  2009 :  1970895
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.653179
#          Iterations 5
# ***********************************
# 2010
# # of all traffic stops in year  2010 :  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2452498
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2452498
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  2047868
# # of traffic stops after preprocessing in year  2010 :  2044949
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.634208
#          Iterations 5
# ***********************************
# 2011
# # of all traffic stops in year  2011 :  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2511664
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2511664
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  2136943
# # of traffic stops after preprocessing in year  2011 :  2133676
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.628061
#          Iterations 5
# ***********************************
# 2012
# # of all traffic stops in year  2012 :  2435812
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2368991
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2368990
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  2051953
# # of traffic stops after preprocessing in year  2012 :  2047895
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.635575
#          Iterations 5
# ***********************************
# 2013
# # of all traffic stops in year  2013 :  2134936
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2076400
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2076396
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  1777678
# # of traffic stops after preprocessing in year  2013 :  1773117
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.640163
#          Iterations 5
# ***********************************
# 2014
# # of all traffic stops in year  2014 :  1878488
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1820773
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1820763
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  1475153
# # of traffic stops after preprocessing in year  2014 :  1471013
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.647254
#          Iterations 5
# ***********************************
# 2015
# # of all traffic stops in year  2015 :  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1683954
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1683940
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  1276241
# # of traffic stops after preprocessing in year  2015 :  1271689
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.646495
#          Iterations 5
# ***********************************
# 2016
# # of all traffic stops in year  2016 :  1832207
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1832089
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1832072
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  1384913
# # of traffic stops after preprocessing in year  2016 :  1383649
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.646931
#          Iterations 5
# ***********************************
# 2017
# # of all traffic stops in year  2017 :  2197382
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2197369
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2197369
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2197361
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2197356
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  1625526
# # of traffic stops after preprocessing in year  2017 :  1623886
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.645635
#          Iterations 5

# %% [markdown]
# ##### all stops, search

# %%
year_start = 2006
year_end = 2016

asianpacific = []
black = []
hispanic = []

asianpacific_low = []
black_low = []
hispanic_low = []

asianpacific_high = []
black_high = []
hispanic_high = []

folder_path ='/content/drive/MyDrive/traffic_stop/FINAL_OUTPUTS/'
#generate_outputs(folder_path = folder_path, with_vio = False, violation_types = None)
generate_outputs(folder_path=folder_path, analysis_type='search', violation_types=None, border_counties=non_border_counties, county_type=None, speeding_only=False)
# Out:
# ***********************************
# 2006
# # of all traffic stops in year  2006 :  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2673511
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2673511
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  2290755
# # of traffic stops after preprocessing in year  2006 :  2289111
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.136955
#          Iterations 8
# ***********************************
# 2007
# # of all traffic stops in year  2007 :  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2405744
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2405744
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  2040793
# # of traffic stops after preprocessing in year  2007 :  2039591
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.137941
#          Iterations 8
# ***********************************
# 2008
# # of all traffic stops in year  2008 :  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2434970
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2434970
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  1869019
# # of traffic stops after preprocessing in year  2008 :  1866607
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.117649
#          Iterations 8
# ***********************************
# 2009
# # of all traffic stops in year  2009 :  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2370986
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2370986
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  1973466
# # of traffic stops after preprocessing in year  2009 :  1970895
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.091790
#          Iterations 9
# ***********************************
# 2010
# # of all traffic stops in year  2010 :  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2452498
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2452498
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  2047868
# # of traffic stops after preprocessing in year  2010 :  2044949
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.096052
#          Iterations 9
# ***********************************
# 2011
# # of all traffic stops in year  2011 :  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2511664
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2511664
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  2136943
# # of traffic stops after preprocessing in year  2011 :  2133676
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.098427
#          Iterations 9
# ***********************************
# 2012
# # of all traffic stops in year  2012 :  2435812
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2368991
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2368990
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  2051953
# # of traffic stops after preprocessing in year  2012 :  2047895
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.094794
#          Iterations 9
# ***********************************
# 2013
# # of all traffic stops in year  2013 :  2134936
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2076400
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2076396
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  1777678
# # of traffic stops after preprocessing in year  2013 :  1773117
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.086649
#          Iterations 9
# ***********************************
# 2014
# # of all traffic stops in year  2014 :  1878488
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1820773
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1820763
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  1475153
# # of traffic stops after preprocessing in year  2014 :  1471013
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.083083
#          Iterations 9
# ***********************************
# 2015
# # of all traffic stops in year  2015 :  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1683954
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1683940
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  1276241
# # of traffic stops after preprocessing in year  2015 :  1271689
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.077053
#          Iterations 9
# ***********************************
# 2016
# # of all traffic stops in year  2016 :  1832207
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1832089
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1832072
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  1384913
# # of traffic stops after preprocessing in year  2016 :  1383649
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.087653
#          Iterations 9

# %% [markdown]
# ##### all stops, contraband_found

# %%
year_start = 2006
year_end = 2016

asianpacific = []
black = []
hispanic = []

asianpacific_low = []
black_low = []
hispanic_low = []

asianpacific_high = []
black_high = []
hispanic_high = []

folder_path ='/content/drive/MyDrive/traffic_stop/FINAL_OUTPUTS/'
#generate_outputs(folder_path = folder_path, with_vio = False, violation_types = None)
non_border_counties = [county for county in list(county_df['County Name']) if county not in border_counties]
generate_outputs(folder_path=folder_path, analysis_type='contraband', violation_types=None, border_counties=non_border_counties, county_type=None, speeding_only=False)
# Out:
# ***********************************
# 2006
# # of all traffic stops in year  2006 :  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2673511
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2673511
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  2290755
# # of traffic stops after preprocessing in year  2006 :  72221
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.600508
#          Iterations 6
# ***********************************
# 2007
# # of all traffic stops in year  2007 :  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2405744
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2405744
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  2040793
# # of traffic stops after preprocessing in year  2007 :  64598
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.596194
#          Iterations 5
# ***********************************
# 2008
# # of all traffic stops in year  2008 :  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2434970
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2434970
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  1869019
# # of traffic stops after preprocessing in year  2008 :  48226
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.589196
#          Iterations 5
# ***********************************
# 2009
# # of all traffic stops in year  2009 :  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2370986
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2370986
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  1973466
# # of traffic stops after preprocessing in year  2009 :  37391
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.595133
#          Iterations 5
# ***********************************
# 2010
# # of all traffic stops in year  2010 :  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2452498
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2452498
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  2047868
# # of traffic stops after preprocessing in year  2010 :  41187
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.606269
#          Iterations 5
# ***********************************
# 2011
# # of all traffic stops in year  2011 :  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2511664
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2511664
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  2136943
# # of traffic stops after preprocessing in year  2011 :  44205
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.636797
#          Iterations 5
# ***********************************
# 2012
# # of all traffic stops in year  2012 :  2435812
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2368991
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2368990
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  2051953
# # of traffic stops after preprocessing in year  2012 :  40361
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.653299
#          Iterations 5
# ***********************************
# 2013
# # of all traffic stops in year  2013 :  2134936
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2076400
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2076396
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  1777678
# # of traffic stops after preprocessing in year  2013 :  31108
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.671781
#          Iterations 4
# ***********************************
# 2014
# # of all traffic stops in year  2014 :  1878488
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1820773
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1820763
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  1475153
# # of traffic stops after preprocessing in year  2014 :  24444
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.678002
#          Iterations 4
# ***********************************
# 2015
# # of all traffic stops in year  2015 :  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1683954
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1683940
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  1276241
# # of traffic stops after preprocessing in year  2015 :  19246
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.685870
#          Iterations 4
# ***********************************
# 2016
# # of all traffic stops in year  2016 :  1832207
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1832089
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1832072
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  1384913
# # of traffic stops after preprocessing in year  2016 :  24644
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.691595
#          Iterations 4

# %% [markdown]
# ##### speeding-only, citation

# %%
year_start = 2006
year_end = 2017

asianpacific = []
black = []
hispanic = []

asianpacific_low = []
black_low = []
hispanic_low = []

asianpacific_high = []
black_high = []
hispanic_high = []

folder_path ='./'
#generate_outputs(folder_path = folder_path, with_vio = False, violation_types = None)
non_border_counties = [county for county in list(county_df['County Name']) if county not in border_counties]
generate_outputs(folder_path=folder_path,
                 analysis_type='citation',
                 violation_types=None,
                 border_counties=non_border_counties,
                 border_flag='non-border',
                 county_type=None,
                 speeding_only=True)
# Out:
# ***********************************
# 2006
# # of all traffic stops in year  2006 :  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2673511
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2673511
# Before speed filtering:  2673511
# Speeding only violation has records:  1235103
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  1067475
# # of traffic stops after preprocessing in year  2006 :  1066587
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.654837
#          Iterations 5
# ***********************************
# 2007
# # of all traffic stops in year  2007 :  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2405744
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2405744
# Before speed filtering:  2405744
# Speeding only violation has records:  1110868
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  949778
# # of traffic stops after preprocessing in year  2007 :  949154
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.653836
#          Iterations 4
# ***********************************
# 2008
# # of all traffic stops in year  2008 :  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2434970
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2434970
# Before speed filtering:  2434970
# Speeding only violation has records:  1114925
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  872159
# # of traffic stops after preprocessing in year  2008 :  870967
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.637281
#          Iterations 5
# ***********************************
# 2009
# # of all traffic stops in year  2009 :  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2370986
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2370986
# Before speed filtering:  2370986
# Speeding only violation has records:  1093968
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  937565
# # of traffic stops after preprocessing in year  2009 :  936283
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.608861
#          Iterations 5
# ***********************************
# 2010
# # of all traffic stops in year  2010 :  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2452498
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2452498
# Before speed filtering:  2452498
# Speeding only violation has records:  1085945
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  945483
# # of traffic stops after preprocessing in year  2010 :  944106
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.583096
#          Iterations 5
# ***********************************
# 2011
# # of all traffic stops in year  2011 :  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2511664
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2511664
# Before speed filtering:  2511664
# Speeding only violation has records:  1085781
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  958793
# # of traffic stops after preprocessing in year  2011 :  957277
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.572594
#          Iterations 5
# ***********************************
# 2012
# # of all traffic stops in year  2012 :  2435812
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2368991
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2368990
# Before speed filtering:  2368990
# Speeding only violation has records:  1025815
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  918848
# # of traffic stops after preprocessing in year  2012 :  916936
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.581521
#          Iterations 5
# ***********************************
# 2013
# # of all traffic stops in year  2013 :  2134936
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2076400
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2076396
# Before speed filtering:  2076396
# Speeding only violation has records:  905817
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  801855
# # of traffic stops after preprocessing in year  2013 :  799675
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.587963
#          Iterations 5
# ***********************************
# 2014
# # of all traffic stops in year  2014 :  1878488
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1820773
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1820763
# Before speed filtering:  1820763
# Speeding only violation has records:  779279
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  660018
# # of traffic stops after preprocessing in year  2014 :  658198
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.604092
#          Iterations 5
# ***********************************
# 2015
# # of all traffic stops in year  2015 :  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1683954
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1683940
# Before speed filtering:  1683940
# Speeding only violation has records:  730702
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  592776
# # of traffic stops after preprocessing in year  2015 :  590585
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.606378
#          Iterations 5
# ***********************************
# 2016
# # of all traffic stops in year  2016 :  1832207
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1832089
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1832072
# Before speed filtering:  1832072
# Speeding only violation has records:  797329
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  642457
# # of traffic stops after preprocessing in year  2016 :  641817
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.607035
#          Iterations 5
# ***********************************
# 2017
# # of all traffic stops in year  2017 :  2197382
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2197369
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2197369
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2197361
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2197356
# Before speed filtering:  2197356
# Speeding only violation has records:  895256
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  711599
# # of traffic stops after preprocessing in year  2017 :  710830
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.605133
#          Iterations 5

# %% [markdown]
# ##### speeding-only, search

# %%
year_start = 2006
year_end = 2016

asianpacific = []
black = []
hispanic = []

asianpacific_low = []
black_low = []
hispanic_low = []

asianpacific_high = []
black_high = []
hispanic_high = []

folder_path ='/content/drive/MyDrive/traffic_stop/FINAL_OUTPUTS/'
#generate_outputs(folder_path = folder_path, with_vio = False, violation_types = None)
generate_outputs(folder_path=folder_path, analysis_type='search', violation_types=None, border_counties=non_border_counties, county_type=None, speeding_only=True)
# Out:
# ***********************************
# 2006
# # of all traffic stops in year  2006 :  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2673511
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2673511
# Before speed filtering:  2673511
# Speeding only violation has records:  1235103
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  1067475
# # of traffic stops after preprocessing in year  2006 :  1066587
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.048621
#          Iterations 9
# ***********************************
# 2007
# # of all traffic stops in year  2007 :  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2405744
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2405744
# Before speed filtering:  2405744
# Speeding only violation has records:  1110868
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  949778
# # of traffic stops after preprocessing in year  2007 :  949154
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.049352
#          Iterations 9
# ***********************************
# 2008
# # of all traffic stops in year  2008 :  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2434970
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2434970
# Before speed filtering:  2434970
# Speeding only violation has records:  1114925
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  872159
# # of traffic stops after preprocessing in year  2008 :  870967
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.041211
#          Iterations 9
# ***********************************
# 2009
# # of all traffic stops in year  2009 :  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2370986
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2370986
# Before speed filtering:  2370986
# Speeding only violation has records:  1093968
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  937565
# # of traffic stops after preprocessing in year  2009 :  936283
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.034378
#          Iterations 10
# ***********************************
# 2010
# # of all traffic stops in year  2010 :  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2452498
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2452498
# Before speed filtering:  2452498
# Speeding only violation has records:  1085945
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  945483
# # of traffic stops after preprocessing in year  2010 :  944106
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.036098
#          Iterations 10
# ***********************************
# 2011
# # of all traffic stops in year  2011 :  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2511664
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2511664
# Before speed filtering:  2511664
# Speeding only violation has records:  1085781
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  958793
# # of traffic stops after preprocessing in year  2011 :  957277
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.034086
#          Iterations 10
# ***********************************
# 2012
# # of all traffic stops in year  2012 :  2435812
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2368991
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2368990
# Before speed filtering:  2368990
# Speeding only violation has records:  1025815
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  918848
# # of traffic stops after preprocessing in year  2012 :  916936
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.029531
#          Iterations 10
# ***********************************
# 2013
# # of all traffic stops in year  2013 :  2134936
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2076400
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2076396
# Before speed filtering:  2076396
# Speeding only violation has records:  905817
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  801855
# # of traffic stops after preprocessing in year  2013 :  799675
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.024605
#          Iterations 10
# ***********************************
# 2014
# # of all traffic stops in year  2014 :  1878488
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1820773
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1820763
# Before speed filtering:  1820763
# Speeding only violation has records:  779279
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  660018
# # of traffic stops after preprocessing in year  2014 :  658198
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.022731
#          Iterations 10
# ***********************************
# 2015
# # of all traffic stops in year  2015 :  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1683954
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1683940
# Before speed filtering:  1683940
# Speeding only violation has records:  730702
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  592776
# # of traffic stops after preprocessing in year  2015 :  590585
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.021104
#          Iterations 10
# ***********************************
# 2016
# # of all traffic stops in year  2016 :  1832207
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1832089
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1832072
# Before speed filtering:  1832072
# Speeding only violation has records:  797329
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  642457
# # of traffic stops after preprocessing in year  2016 :  641817
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.023570
#          Iterations 10

# %% [markdown]
# ##### speeding-only, contraband_found

# %%
year_start = 2006
year_end = 2016

asianpacific = []
black = []
hispanic = []

asianpacific_low = []
black_low = []
hispanic_low = []

asianpacific_high = []
black_high = []
hispanic_high = []

folder_path ='/content/drive/MyDrive/traffic_stop/FINAL_OUTPUTS/'
#generate_outputs(folder_path = folder_path, with_vio = False, violation_types = None)
non_border_counties = [county for county in list(county_df['County Name']) if county not in border_counties]
generate_outputs(folder_path=folder_path, analysis_type='contraband', violation_types=None, border_counties=non_border_counties, county_type=None, speeding_only=True)
# Out:
# ***********************************
# 2006
# # of all traffic stops in year  2006 :  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2673511
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2673511
# Before speed filtering:  2673511
# Speeding only violation has records:  1235103
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  1067475
# # of traffic stops after preprocessing in year  2006 :  9288
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.259804
#          Iterations 7
# ***********************************
# 2007
# # of all traffic stops in year  2007 :  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2405744
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2405744
# Before speed filtering:  2405744
# Speeding only violation has records:  1110868
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  949778
# # of traffic stops after preprocessing in year  2007 :  8353
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.247041
#          Iterations 7
# ***********************************
# 2008
# # of all traffic stops in year  2008 :  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2434970
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2434970
# Before speed filtering:  2434970
# Speeding only violation has records:  1114925
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  872159
# # of traffic stops after preprocessing in year  2008 :  6159
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.234623
#          Iterations 7
# ***********************************
# 2009
# # of all traffic stops in year  2009 :  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2370986
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2370986
# Before speed filtering:  2370986
# Speeding only violation has records:  1093968
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  937565
# # of traffic stops after preprocessing in year  2009 :  5382
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.261944
#          Iterations 7
# ***********************************
# 2010
# # of all traffic stops in year  2010 :  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2452498
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2452498
# Before speed filtering:  2452498
# Speeding only violation has records:  1085945
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  945483
# # of traffic stops after preprocessing in year  2010 :  5771
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.239042
#          Iterations 7
# ***********************************
# 2011
# # of all traffic stops in year  2011 :  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2511664
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2511664
# Before speed filtering:  2511664
# Speeding only violation has records:  1085781
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  958793
# # of traffic stops after preprocessing in year  2011 :  5459
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.270496
#          Iterations 7
# ***********************************
# 2012
# # of all traffic stops in year  2012 :  2435812
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2368991
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2368990
# Before speed filtering:  2368990
# Speeding only violation has records:  1025815
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  918848
# # of traffic stops after preprocessing in year  2012 :  4395
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.261078
#          Iterations 7
# ***********************************
# 2013
# # of all traffic stops in year  2013 :  2134936
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2076400
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2076396
# Before speed filtering:  2076396
# Speeding only violation has records:  905817
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  801855
# # of traffic stops after preprocessing in year  2013 :  3081
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.307167
#          Iterations 7
# ***********************************
# 2014
# # of all traffic stops in year  2014 :  1878488
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1820773
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1820763
# Before speed filtering:  1820763
# Speeding only violation has records:  779279
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  660018
# # of traffic stops after preprocessing in year  2014 :  2305
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.311148
#          Iterations 7
# ***********************************
# 2015
# # of all traffic stops in year  2015 :  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1683954
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1683940
# Before speed filtering:  1683940
# Speeding only violation has records:  730702
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  592776
# # of traffic stops after preprocessing in year  2015 :  1890
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.363210
#          Iterations 7
# ***********************************
# 2016
# # of all traffic stops in year  2016 :  1832207
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1832089
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1832072
# Before speed filtering:  1832072
# Speeding only violation has records:  797329
# Including only border counties
# # of traffic stops after preprocessing step 1(add county type):  642457
# # of traffic stops after preprocessing in year  2016 :  2333
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.388683
#          Iterations 6

# %% [markdown]
# ### 3. Model for Most Serious Speeding Offences

# %%
all_dict = {}
cite_dict = {}

for year in list(range(2006, 2018)):
  print(year)
  df = pd.read_parquet(os.path.join(data_dir, 'year_data_speeding_only', 'traffic_'+str(year)+'.parquet'), engine = 'pyarrow')
  df = df.loc[df['speeding_only'].isin(['speeding-repeated_entries','speeding-1', 'speeding_multiple'])]
  vio_lst = list(df['violation'].unique())

  for vio in vio_lst:
    df_temp = df.loc[df['violation'] == vio,:]
    if vio in list(all_dict.keys()):
      all_dict[vio] += len(df_temp)
      cite_dict[vio] += sum(df_temp['citation_issued'])
    else:
      all_dict[vio] = len(df_temp)
      cite_dict[vio] = sum(df_temp['citation_issued'])

vio_name = []
type_count = []
citation_prop = []

for vio in list(all_dict.keys()):
  vio_name.append(vio)
  type_count.append(all_dict[vio])
  citation_prop.append((cite_dict[vio]/all_dict[vio]))

citation_prop = ['{:.4f}'.format(x) for x in citation_prop]
ticket_df = pd.DataFrame({'violation': vio_name, 'count':type_count,'citation_prop': citation_prop})
ticket_df = ticket_df.sort_values(by = 'citation_prop', ascending=False)
# Out:
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017

# %%
ticket_df
# Out:
#                                             violation    count citation_prop
# 17  speeding-15 mph and over posted speed limit-cm...        1        1.0000
# 4                               fail to control speed    90206        0.9834
# 2                                        unsafe speed    80936        0.9803
# 0             speeding-10% or more above posted speed  3610311        0.9765
# 5              speeding cmv 15 mph or more over limit     3133        0.9240
# 8   fail to stop/reduce speed or shifted gears at ...        3        0.6667
# 13  vehicle hauling explosives or flammable materi...        5        0.6000
# 6                                speeding-school zone    19839        0.5351
# 10  speeding (over 35 mph) motor driven cycle (eff...      188        0.4734
# 3   speeding - zoned (inclement weather, signs pos...    16954        0.2129
# 12                          any speedometer violation       93        0.1398
# 7                                 speed under minimum      713        0.1234
# 11               increase speed while being overtaken      601        0.1032
# 9   fail to reduce speed or shifted gears at rr cr...       87        0.0690
# 1                                 speeding over limit  8332493        0.0027
# 14  schedule run necessitating driver to exceed sp...        2        0.0000
# 15  fail to stop/reduce speed or shifted gears at ...        5        0.0000
# 16    excessive tire load-operate at speed over 50mph        9        0.0000
# 18  speeding-zoned (posted below 55) (do not use o...        2        0.0000

# %%
ticket_df['violation'].to_list()
# Out:
# ['speeding-15 mph and over posted speed limit-cmv only   (do not use on arrests after 12/31/1999)',
#  'fail to control speed',
#  'unsafe speed',
#  'speeding-10% or more above posted speed',
#  'speeding cmv 15 mph or more over limit',
#  'fail to stop/reduce speed or shifted gears at rr crossing-chlorine',
#  'vehicle hauling explosives or flammable materials failed to reduce speed at rr crossing',
#  'speeding-school zone',
#  'speeding (over 35 mph) motor driven cycle (effective 1/1/2000 for arrests issued after 1/1/2000)',
#  'speeding - zoned (inclement weather, signs posted, military zone, beach)',
#  'any speedometer violation',
#  'speed under minimum',
#  'increase speed while being overtaken',
#  'fail to reduce speed or shifted gears at rr crossing-any placard',
#  'speeding over limit',
#  'schedule run necessitating driver to exceed speed limits',
#  'fail to stop/reduce speed or shifted gears at rr crossing-cargo tank',
#  'excessive tire load-operate at speed over 50mph',
#  'speeding-zoned (posted below 55) (do not use on arrests after 12/31/1999)']

# %%
serious_speeding_violations = ['fail to control speed',
                               'unsafe speed',
                               'speeding-10% or more above posted speed',
                               'speeding cmv 15 mph or more over limit', 
                               'speeding-school zone',
                               'speeding-15 mph and over posted speed limit-cmv only   (do not use on arrests after 12/31/1999)']

# %% [markdown]
# ##### citation

# %%
year_start = 2006
year_end = 2017

asianpacific = []
black = []
hispanic = []

asianpacific_low = []
black_low = []
hispanic_low = []

asianpacific_high = []
black_high = []
hispanic_high = []

folder_path ='./'
#generate_outputs(folder_path = folder_path, with_vio = False, violation_types = None)
# non_border_counties = [county for county in list(county_df['County Name']) if county not in border_counties]
generate_outputs(folder_path=folder_path, analysis_type='citation', violation_types=serious_speeding_violations, border_counties=None, county_type=None, speeding_only=False)
# Out:
# ***********************************
# 2006
# # of all traffic stops in year  2006 :  1245297
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1245297
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1245297
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1235103
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1235103
# Including only serious violations
# 468008
# # of traffic stops after preprocessing step 1(add county type):  468008
# # of traffic stops after preprocessing in year  2006 :  467513
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.034246
#          Iterations 10
# ***********************************
# 2007
# # of all traffic stops in year  2007 :  1121421
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1121421
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1121421
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1110868
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1110868
# Including only serious violations
# 413338
# # of traffic stops after preprocessing step 1(add county type):  413338
# # of traffic stops after preprocessing in year  2007 :  412990
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.029066
#          Iterations 10
# ***********************************
# 2008
# # of all traffic stops in year  2008 :  1161377
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1161377
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1161377
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1114925
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1114925
# Including only serious violations
# 350988
# # of traffic stops after preprocessing step 1(add county type):  350988
# # of traffic stops after preprocessing in year  2008 :  350531
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.073272
#          Iterations 9
# ***********************************
# 2009
# # of all traffic stops in year  2009 :  1131414
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1131414
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1131414
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1093968
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1093968
# Including only serious violations
# 336209
# # of traffic stops after preprocessing step 1(add county type):  336209
# # of traffic stops after preprocessing in year  2009 :  335753
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.110346
#          Iterations 8
# ***********************************
# 2010
# # of all traffic stops in year  2010 :  1123382
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1123382
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1123382
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1085945
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1085945
# Including only serious violations
# 305204
# # of traffic stops after preprocessing step 1(add county type):  305204
# # of traffic stops after preprocessing in year  2010 :  304750
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.128646
#          Iterations 8
# ***********************************
# 2011
# # of all traffic stops in year  2011 :  1123841
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1123841
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1123841
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1085781
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1085781
# Including only serious violations
# 296560
# # of traffic stops after preprocessing step 1(add county type):  296560
# # of traffic stops after preprocessing in year  2011 :  296099
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.133414
#          Iterations 8
# ***********************************
# 2012
# # of all traffic stops in year  2012 :  1058106
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1058082
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1058082
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1025815
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1025815
# Including only serious violations
# 293990
# # of traffic stops after preprocessing step 1(add county type):  293990
# # of traffic stops after preprocessing in year  2012 :  293370
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.159858
#          Iterations 8
# ***********************************
# 2013
# # of all traffic stops in year  2013 :  933982
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  933962
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  933962
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  905818
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  905817
# Including only serious violations
# 266630
# # of traffic stops after preprocessing step 1(add county type):  266630
# # of traffic stops after preprocessing in year  2013 :  265865
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.164296
#          Iterations 8
# ***********************************
# 2014
# # of all traffic stops in year  2014 :  807645
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  807645
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  807645
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  779281
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  779279
# Including only serious violations
# 238507
# # of traffic stops after preprocessing step 1(add county type):  238507
# # of traffic stops after preprocessing in year  2014 :  237797
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.167485
#          Iterations 8
# ***********************************
# 2015
# # of all traffic stops in year  2015 :  761763
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  761763
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  761763
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  730703
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  730702
# Including only serious violations
# 221322
# # of traffic stops after preprocessing step 1(add county type):  221322
# # of traffic stops after preprocessing in year  2015 :  220433
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.167200
#          Iterations 8
# ***********************************
# 2016
# # of all traffic stops in year  2016 :  797336
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  797335
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  797335
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  797331
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  797329
# Including only serious violations
# 243792
# # of traffic stops after preprocessing step 1(add county type):  243792
# # of traffic stops after preprocessing in year  2016 :  243535
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.154560
#          Iterations 8
# ***********************************
# 2017
# # of all traffic stops in year  2017 :  895262
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  895261
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  895261
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  895258
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  895256
# Including only serious violations
# 273267
# # of traffic stops after preprocessing step 1(add county type):  273267
# # of traffic stops after preprocessing in year  2017 :  272950
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.175130
#          Iterations 8

# %%
# Non-serious speeding violation
year_start = 2006
year_end = 2017

asianpacific = []
black = []
hispanic = []

asianpacific_low = []
black_low = []
hispanic_low = []

asianpacific_high = []
black_high = []
hispanic_high = []

folder_path ='./'
non_serious_speeding_violations = list(set(ticket_df['violation'].to_list()) - set(serious_speeding_violations))
print(non_serious_speeding_violations)

generate_outputs(folder_path=folder_path, analysis_type='citation', violation_types=non_serious_speeding_violations, border_counties=None, county_type=None, speeding_only=False, serious_violations=False)
# Out:
# ['speeding (over 35 mph) motor driven cycle (effective 1/1/2000 for arrests issued after 1/1/2000)', 'speeding-zoned (posted below 55) (do not use on arrests after 12/31/1999)', 'speed under minimum', 'excessive tire load-operate at speed over 50mph', 'schedule run necessitating driver to exceed speed limits', 'any speedometer violation', 'speeding - zoned (inclement weather, signs posted, military zone, beach)', 'fail to stop/reduce speed or shifted gears at rr crossing-chlorine', 'speeding over limit', 'fail to reduce speed or shifted gears at rr crossing-any placard', 'fail to stop/reduce speed or shifted gears at rr crossing-cargo tank', 'increase speed while being overtaken', 'vehicle hauling explosives or flammable materials failed to reduce speed at rr crossing']
# ***********************************
# 2006
# # of all traffic stops in year  2006 :  1245297
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1245297
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1245297
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1235103
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1235103
# Including only serious violations
# 766861
# # of traffic stops after preprocessing step 1(add county type):  766861
# # of traffic stops after preprocessing in year  2006 :  766381
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.021117
#          Iterations 10
# ***********************************
# 2007
# # of all traffic stops in year  2007 :  1121421
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1121421
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1121421
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1110868
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1110868
# Including only serious violations
# 697270
# # of traffic stops after preprocessing step 1(add county type):  697270
# # of traffic stops after preprocessing in year  2007 :  696875
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.018106
#          Iterations 10
# ***********************************
# 2008
# # of all traffic stops in year  2008 :  1161377
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1161377
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1161377
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1114925
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1114925
# Including only serious violations
# 763553
# # of traffic stops after preprocessing step 1(add county type):  763553
# # of traffic stops after preprocessing in year  2008 :  762616
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.017348
#          Iterations 10
# ***********************************
# 2009
# # of all traffic stops in year  2009 :  1131414
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1131414
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1131414
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1093968
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1093968
# Including only serious violations
# 756988
# # of traffic stops after preprocessing step 1(add county type):  756988
# # of traffic stops after preprocessing in year  2009 :  756074
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.012224
#          Iterations 11
# ***********************************
# 2010
# # of all traffic stops in year  2010 :  1123382
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1123382
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1123382
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1085945
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1085945
# Including only serious violations
# 779901
# # of traffic stops after preprocessing step 1(add county type):  779901
# # of traffic stops after preprocessing in year  2010 :  778886
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.009321
#          Iterations 11
# ***********************************
# 2011
# # of all traffic stops in year  2011 :  1123841
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1123841
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1123841
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1085781
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1085781
# Including only serious violations
# 788392
# # of traffic stops after preprocessing step 1(add county type):  788392
# # of traffic stops after preprocessing in year  2011 :  787251
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.010955
#          Iterations 11
# ***********************************
# 2012
# # of all traffic stops in year  2012 :  1058106
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1058082
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1058082
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1025815
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1025815
# Including only serious violations
# 731092
# # of traffic stops after preprocessing step 1(add county type):  731092
# # of traffic stops after preprocessing in year  2012 :  729680
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.034818
#          Iterations 10
# ***********************************
# 2013
# # of all traffic stops in year  2013 :  933982
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  933962
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  933962
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  905818
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  905817
# Including only serious violations
# 638643
# # of traffic stops after preprocessing step 1(add county type):  638643
# # of traffic stops after preprocessing in year  2013 :  637069
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.038034
#          Iterations 10
# ***********************************
# 2014
# # of all traffic stops in year  2014 :  807645
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  807645
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  807645
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  779281
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  779279
# Including only serious violations
# 540592
# # of traffic stops after preprocessing step 1(add county type):  540592
# # of traffic stops after preprocessing in year  2014 :  539296
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.032954
#          Iterations 10
# ***********************************
# 2015
# # of all traffic stops in year  2015 :  761763
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  761763
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  761763
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  730703
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  730702
# Including only serious violations
# 509243
# # of traffic stops after preprocessing step 1(add county type):  509243
# # of traffic stops after preprocessing in year  2015 :  507641
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.023482
#          Iterations 10
# ***********************************
# 2016
# # of all traffic stops in year  2016 :  797336
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  797335
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  797335
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  797331
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  797329
# Including only serious violations
# 553429
# # of traffic stops after preprocessing step 1(add county type):  553429
# # of traffic stops after preprocessing in year  2016 :  552952
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.017512
#          Iterations 10
# ***********************************
# 2017
# # of all traffic stops in year  2017 :  895262
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  895261
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  895261
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  895258
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  895256
# Including only serious violations
# 621885
# # of traffic stops after preprocessing step 1(add county type):  621885
# # of traffic stops after preprocessing in year  2017 :  621306
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.014570
#          Iterations 10

# %%
# Serious speeding violations - pooled over all years

# Combine dataset for all years
y = pd.Series()
X = pd.DataFrame()
for year in np.arange(2006,2018):
    y_year, X_year = preprocess(year,
                                rm_na_col,
                                analysis_type='citation',
                                violation_types=serious_speeding_violations, 
                                speeding_only=True, 
                                serious_violations=True)
    y = pd.concat([y, y_year])
    X = pd.concat([X, X_year])
print('Total # of traffic stops:', len(X.index))

#adding constant to X
X_with_constant = sm.add_constant(X)
# building the model and fitting the data
log_reg = sm.Logit(y, X_with_constant).fit()

res_df = pd.DataFrame({'variable':list(log_reg.params.index), 'coef':list(log_reg.params.values),
                       'odds_ratio':list(np.exp(log_reg.params.values)),
                       'lower_CI':list(np.exp(log_reg.conf_int()[0].values)),
                       'upper_CI':list(np.exp(log_reg.conf_int()[1].values)),'pvalue':list(log_reg.pvalues)})

res_df
# Out:
# # of all traffic stops in year  2006 :  1245297
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1245297
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1245297
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1235103
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1235103
# Including only serious violations
# 468008
# Before speed filtering:  468008
# Speeding only violation has records:  468008
# # of traffic stops after preprocessing step 1(add county type):  468008
# # of traffic stops after preprocessing in year  2006 :  467513
# # of all traffic stops in year  2007 :  1121421
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1121421
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1121421
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1110868
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1110868
# Including only serious violations
# 413338
# Before speed filtering:  413338
# Speeding only violation has records:  413338
# # of traffic stops after preprocessing step 1(add county type):  413338
# # of traffic stops after preprocessing in year  2007 :  412990
# # of all traffic stops in year  2008 :  1161377
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1161377
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1161377
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1114925
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1114925
# Including only serious violations
# 350988
# Before speed filtering:  350988
# Speeding only violation has records:  350988
# # of traffic stops after preprocessing step 1(add county type):  350988
# # of traffic stops after preprocessing in year  2008 :  350531
# # of all traffic stops in year  2009 :  1131414
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1131414
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1131414
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1093968
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1093968
# Including only serious violations
# 336209
# Before speed filtering:  336209
# Speeding only violation has records:  336209
# # of traffic stops after preprocessing step 1(add county type):  336209
# # of traffic stops after preprocessing in year  2009 :  335753
# # of all traffic stops in year  2010 :  1123382
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1123382
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1123382
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1085945
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1085945
# Including only serious violations
# 305204
# Before speed filtering:  305204
# Speeding only violation has records:  305204
# # of traffic stops after preprocessing step 1(add county type):  305204
# # of traffic stops after preprocessing in year  2010 :  304750
# # of all traffic stops in year  2011 :  1123841
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1123841
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1123841
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1085781
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1085781
# Including only serious violations
# 296560
# Before speed filtering:  296560
# Speeding only violation has records:  296560
# # of traffic stops after preprocessing step 1(add county type):  296560
# # of traffic stops after preprocessing in year  2011 :  296099
# # of all traffic stops in year  2012 :  1058106
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1058082
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1058082
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1025815
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1025815
# Including only serious violations
# 293990
# Before speed filtering:  293990
# Speeding only violation has records:  293990
# # of traffic stops after preprocessing step 1(add county type):  293990
# # of traffic stops after preprocessing in year  2012 :  293370
# # of all traffic stops in year  2013 :  933982
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  933962
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  933962
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  905818
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  905817
# Including only serious violations
# 266630
# Before speed filtering:  266630
# Speeding only violation has records:  266630
# # of traffic stops after preprocessing step 1(add county type):  266630
# # of traffic stops after preprocessing in year  2013 :  265865
# # of all traffic stops in year  2014 :  807645
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  807645
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  807645
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  779281
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  779279
# Including only serious violations
# 238507
# Before speed filtering:  238507
# Speeding only violation has records:  238507
# # of traffic stops after preprocessing step 1(add county type):  238507
# # of traffic stops after preprocessing in year  2014 :  237797
# # of all traffic stops in year  2015 :  761763
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  761763
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  761763
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  730703
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  730702
# Including only serious violations
# 221322
# Before speed filtering:  221322
# Speeding only violation has records:  221322
# # of traffic stops after preprocessing step 1(add county type):  221322
# # of traffic stops after preprocessing in year  2015 :  220433
# # of all traffic stops in year  2016 :  797336
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  797335
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  797335
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  797331
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  797329
# Including only serious violations
# 243792
# Before speed filtering:  243792
# Speeding only violation has records:  243792
# # of traffic stops after preprocessing step 1(add county type):  243792
# # of traffic stops after preprocessing in year  2016 :  243535
# # of all traffic stops in year  2017 :  895262
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  895261
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  895261
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  895258
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  895256
# Including only serious violations
# 273267
# Before speed filtering:  273267
# Speeding only violation has records:  273267
# # of traffic stops after preprocessing step 1(add county type):  273267
# # of traffic stops after preprocessing in year  2017 :  272950
# Total # of traffic stops: 3701586
# Optimization terminated successfully.
#          Current function value: 0.119195
#          Iterations 8
#                               variable      coef  odds_ratio   lower_CI  \
# 0                                const  3.688348   39.978756  39.526483
# 1  subject_race_asian/pacific islander  0.468013    1.596818   1.517339
# 2                   subject_race_black  0.198133    1.219125   1.189735
# 3                subject_race_hispanic -0.188569    0.828143   0.816460
# 4                   subject_sex_female -0.089255    0.914613   0.902433
# 5             county_type_Micropolitan -0.179052    0.836062   0.821750
# 6                 county_type_Non core  0.137532    1.147438   1.129700
#
#     upper_CI         pvalue
# 0  40.436204   0.000000e+00
# 1   1.680460   3.547913e-72
# 2   1.249240   5.097505e-57
# 3   0.839994  3.588103e-149
# 4   0.926956   6.417075e-39
# 5   0.850624   7.889749e-92
# 6   1.165455   4.579275e-67

# %%
# Plotting probabilities of getting a citation by race - Serious speeding violations - pooled over all years

y_pred_asian_mean = log_reg.predict(X_with_constant.loc[X_with_constant['subject_race_asian/pacific islander'] == 1]).mean()
y_pred_black_mean = log_reg.predict(X_with_constant.loc[X_with_constant['subject_race_black'] == 1]).mean()
y_pred_hispanic_mean = log_reg.predict(X_with_constant.loc[X_with_constant['subject_race_hispanic'] == 1]).mean()
y_pred_white_mean = log_reg.predict(X_with_constant.loc[(X_with_constant['subject_race_asian/pacific islander'] == 0) &
                                                        (X_with_constant['subject_race_black'] == 0) &
                                                        (X_with_constant['subject_race_hispanic'] == 0)]).mean()

# The following yield the same results
# y.loc[X_with_constant['subject_race_asian/pacific islander'] == 1].mean()
# y.loc[X_with_constant['subject_race_black'] == 1].mean()
# y.loc[X_with_constant['subject_race_hispanic'] == 1].mean()
# y.loc[(X_with_constant['subject_race_asian/pacific islander'] == 0) &
#       (X_with_constant['subject_race_black'] == 0) &
#       (X_with_constant['subject_race_hispanic'] == 0)].mean()

serious_prob_df = pd.DataFrame({'race': ['white',
                                         'black',
                                         'hispanic',
                                         'asian/pacific islander'],
                               'probabilities':[y_pred_white_mean,
                                                y_pred_black_mean,
                                                y_pred_hispanic_mean,
                                                y_pred_asian_mean]})

sns.set(font_scale=1.25)
plt.style.use('seaborn-v0_8-whitegrid')

ax = sns.barplot(serious_prob_df, x='race', y='probabilities');
plt.ylabel('Probability of receiving citation', fontsize=12);
plt.xlabel('Race', fontsize=12);
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
ax.bar_label(ax.containers[0], fmt='%.3f', fontsize=12);
plt.ylim([0.95,1]);
# ax.tick_params(axis='both', which='major', labelsize=12)
plt.savefig('serious_speeding_citation_percent_by_race.png')
plt.savefig('serious_speeding_citation_percent_by_race.pdf')

# %%
# plotting odds ratios - Serious speeding violations - pooled over all years
sns.set(font_scale=1.25)
plt.style.use('seaborn-v0_8-whitegrid')
or_black = np.exp(log_reg.params['subject_race_black'])
or_hispanic = np.exp(log_reg.params['subject_race_hispanic'])
or_asian = np.exp(log_reg.params['subject_race_asian/pacific islander'])

serious_or_df = pd.DataFrame({'race': ['black',
                                         'hispanic',
                                         'asian/pacific islander'],
                               'or':[or_black,
                                     or_hispanic,
                                     or_asian]})

ax = sns.barplot(serious_or_df, x='race', y='or');
plt.ylabel('Odds Ratio', fontsize=12);
plt.xlabel('Race', fontsize=12);
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
ax.bar_label(ax.containers[0], fmt='%.3f', fontsize=12);

# %%
# Non-serious speeding violations - pooled over all years

# Combine dataset for all years
y = pd.Series()
X = pd.DataFrame()
for year in np.arange(2006,2018):
    y_year, X_year = preprocess(year,
                                rm_na_col,
                                analysis_type='citation',
                                violation_types=non_serious_speeding_violations, 
                                speeding_only=True, 
                                serious_violations=False)
    y = pd.concat([y, y_year])
    X = pd.concat([X, X_year])
print('Total # of traffic stops:', len(X.index))

#adding constant to X
X_with_constant = sm.add_constant(X)
# building the model and fitting the data
log_reg = sm.Logit(y, X_with_constant).fit()

res_df = pd.DataFrame({'variable':list(log_reg.params.index), 'coef':list(log_reg.params.values),
                       'odds_ratio':list(np.exp(log_reg.params.values)),
                       'lower_CI':list(np.exp(log_reg.conf_int()[0].values)),
                       'upper_CI':list(np.exp(log_reg.conf_int()[1].values)),'pvalue':list(log_reg.pvalues)})

res_df
# Out:
# # of all traffic stops in year  2006 :  1245297
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1245297
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1245297
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1235103
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1235103
# Including only non-serious violations
# 766861
# Before speed filtering:  766861
# Speeding only violation has records:  766861
# # of traffic stops after preprocessing step 1(add county type):  766861
# # of traffic stops after preprocessing in year  2006 :  766381
# # of all traffic stops in year  2007 :  1121421
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1121421
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1121421
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1110868
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1110868
# Including only non-serious violations
# 697270
# Before speed filtering:  697270
# Speeding only violation has records:  697270
# # of traffic stops after preprocessing step 1(add county type):  697270
# # of traffic stops after preprocessing in year  2007 :  696875
# # of all traffic stops in year  2008 :  1161377
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1161377
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1161377
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1114925
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1114925
# Including only non-serious violations
# 763553
# Before speed filtering:  763553
# Speeding only violation has records:  763553
# # of traffic stops after preprocessing step 1(add county type):  763553
# # of traffic stops after preprocessing in year  2008 :  762616
# # of all traffic stops in year  2009 :  1131414
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1131414
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1131414
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1093968
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1093968
# Including only non-serious violations
# 756988
# Before speed filtering:  756988
# Speeding only violation has records:  756988
# # of traffic stops after preprocessing step 1(add county type):  756988
# # of traffic stops after preprocessing in year  2009 :  756074
# # of all traffic stops in year  2010 :  1123382
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1123382
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1123382
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1085945
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1085945
# Including only non-serious violations
# 779901
# Before speed filtering:  779901
# Speeding only violation has records:  779901
# # of traffic stops after preprocessing step 1(add county type):  779901
# # of traffic stops after preprocessing in year  2010 :  778886
# # of all traffic stops in year  2011 :  1123841
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1123841
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1123841
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1085781
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1085781
# Including only non-serious violations
# 788392
# Before speed filtering:  788392
# Speeding only violation has records:  788392
# # of traffic stops after preprocessing step 1(add county type):  788392
# # of traffic stops after preprocessing in year  2011 :  787251
# # of all traffic stops in year  2012 :  1058106
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1058082
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1058082
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1025815
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1025815
# Including only non-serious violations
# 731092
# Before speed filtering:  731092
# Speeding only violation has records:  731092
# # of traffic stops after preprocessing step 1(add county type):  731092
# # of traffic stops after preprocessing in year  2012 :  729680
# # of all traffic stops in year  2013 :  933982
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  933962
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  933962
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  905818
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  905817
# Including only non-serious violations
# 638643
# Before speed filtering:  638643
# Speeding only violation has records:  638643
# # of traffic stops after preprocessing step 1(add county type):  638643
# # of traffic stops after preprocessing in year  2013 :  637069
# # of all traffic stops in year  2014 :  807645
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  807645
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  807645
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  779281
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  779279
# Including only non-serious violations
# 540592
# Before speed filtering:  540592
# Speeding only violation has records:  540592
# # of traffic stops after preprocessing step 1(add county type):  540592
# # of traffic stops after preprocessing in year  2014 :  539296
# # of all traffic stops in year  2015 :  761763
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  761763
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  761763
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  730703
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  730702
# Including only non-serious violations
# 509243
# Before speed filtering:  509243
# Speeding only violation has records:  509243
# # of traffic stops after preprocessing step 1(add county type):  509243
# # of traffic stops after preprocessing in year  2015 :  507641
# # of all traffic stops in year  2016 :  797336
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  797335
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  797335
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  797331
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  797329
# Including only non-serious violations
# 553429
# Before speed filtering:  553429
# Speeding only violation has records:  553429
# # of traffic stops after preprocessing step 1(add county type):  553429
# # of traffic stops after preprocessing in year  2016 :  552952
# # of all traffic stops in year  2017 :  895262
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  895261
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  895261
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  895258
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  895256
# Including only non-serious violations
# 621885
# Before speed filtering:  621885
# Speeding only violation has records:  621885
# # of traffic stops after preprocessing step 1(add county type):  621885
# # of traffic stops after preprocessing in year  2017 :  621306
# Total # of traffic stops: 8136027
# Optimization terminated successfully.
#          Current function value: 0.020844
#          Iterations 10
#                               variable      coef  odds_ratio  lower_CI  \
# 0                                const -5.951396    0.002602  0.002542
# 1  subject_race_asian/pacific islander  0.548709    1.731018  1.590833
# 2                   subject_race_black -0.040721    0.960097  0.914637
# 3                subject_race_hispanic  0.333607    1.395995  1.357729
# 4                   subject_sex_female -0.244679    0.782955  0.761827
# 5             county_type_Micropolitan  0.092148    1.096527  1.059880
# 6                 county_type_Non core  0.415155    1.514606  1.473307
#
#    upper_CI         pvalue
# 0  0.002664   0.000000e+00
# 1  1.883556   3.803995e-37
# 2  1.007816   9.989438e-02
# 3  1.435339  2.243266e-122
# 4  0.804670   8.391032e-69
# 5  1.134441   1.077063e-07
# 6  1.557063  2.097996e-190

# %%
# Plotting probabilities of getting a citation by race - Non-serious speeding violations - pooled over all years

y_pred_asian_mean = log_reg.predict(X_with_constant.loc[X_with_constant['subject_race_asian/pacific islander'] == 1]).mean()
y_pred_black_mean = log_reg.predict(X_with_constant.loc[X_with_constant['subject_race_black'] == 1]).mean()
y_pred_hispanic_mean = log_reg.predict(X_with_constant.loc[X_with_constant['subject_race_hispanic'] == 1]).mean()
y_pred_white_mean = log_reg.predict(X_with_constant.loc[(X_with_constant['subject_race_asian/pacific islander'] == 0) &
                                                        (X_with_constant['subject_race_black'] == 0) &
                                                        (X_with_constant['subject_race_hispanic'] == 0)]).mean()

# The following yield the same results
# y.loc[X_with_constant['subject_race_asian/pacific islander'] == 1].mean()
# y.loc[X_with_constant['subject_race_black'] == 1].mean()
# y.loc[X_with_constant['subject_race_hispanic'] == 1].mean()
# y.loc[(X_with_constant['subject_race_asian/pacific islander'] == 0) &
#       (X_with_constant['subject_race_black'] == 0) &
#       (X_with_constant['subject_race_hispanic'] == 0)].mean()

serious_prob_df = pd.DataFrame({'race': ['white',
                                         'black',
                                         'hispanic',
                                         'asian/pacific islander'],
                               'probabilities':[y_pred_white_mean,
                                                y_pred_black_mean,
                                                y_pred_hispanic_mean,
                                                y_pred_asian_mean]})

sns.set(font_scale=1.25)
plt.style.use('seaborn-v0_8-whitegrid')

ax = sns.barplot(serious_prob_df, x='race', y='probabilities');
plt.ylabel('Probability of receiving citation', fontsize=12);
plt.xlabel('Race', fontsize=12);
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
ax.bar_label(ax.containers[0], fmt='%.4f', fontsize=12);
plt.ylim([0,0.01]);
# ax.tick_params(axis='both', which='major', labelsize=12)
plt.savefig('Nonserious_speeding_citation_percent_by_race.png')
plt.savefig('Nonserious_speeding_citation_percent_by_race.pdf')

# %%
# plotting odds ratios - Non-serious speeding violations - pooled over all years
sns.set(font_scale=1.25)
plt.style.use('seaborn-v0_8-whitegrid')
or_black = np.exp(log_reg.params['subject_race_black'])
or_hispanic = np.exp(log_reg.params['subject_race_hispanic'])
or_asian = np.exp(log_reg.params['subject_race_asian/pacific islander'])

serious_or_df = pd.DataFrame({'race': ['black',
                                         'hispanic',
                                         'asian/pacific islander'],
                               'or':[or_black,
                                     or_hispanic,
                                     or_asian]})

ax = sns.barplot(serious_or_df, x='race', y='or');
plt.ylabel('Odds Ratio', fontsize=12);
plt.xlabel('Race', fontsize=12);
ax.bar_label(ax.containers[0], fmt='%.3f');

# %% [markdown]
# ##### search

# %%
year_start = 2006
year_end = 2016

asianpacific = []
black = []
hispanic = []

asianpacific_low = []
black_low = []
hispanic_low = []

asianpacific_high = []
black_high = []
hispanic_high = []

folder_path ='/content/drive/MyDrive/traffic_stop/FINAL_OUTPUTS/'
#generate_outputs(folder_path = folder_path, with_vio = False, violation_types = None)
non_border_counties = [county for county in list(county_df['County Name']) if county not in border_counties]
generate_outputs(folder_path=folder_path, analysis_type='search', violation_types=serious_speeding_violations, border_counties=None, county_type=None, speeding_only=False)
# Out:
# ***********************************
# 2006
# # of all traffic stops in year  2006 :  1234128
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1234128
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1234128
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1234128
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1234128
# Including only serious violations
# 466848
# # of traffic stops after preprocessing step 1(add county type):  466848
# # of traffic stops after preprocessing in year  2006 :  466848
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.069441
#          Iterations 9
# ***********************************
# 2007
# # of all traffic stops in year  2007 :  1110125
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1110125
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1110125
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1110125
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1110125
# Including only serious violations
# 412467
# # of traffic stops after preprocessing step 1(add county type):  412467
# # of traffic stops after preprocessing in year  2007 :  412467
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.075443
#          Iterations 9
# ***********************************
# 2008
# # of all traffic stops in year  2008 :  1113530
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1113530
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1113530
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1113530
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1113530
# Including only serious violations
# 349934
# # of traffic stops after preprocessing step 1(add county type):  349934
# # of traffic stops after preprocessing in year  2008 :  349934
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.062644
#          Iterations 9
# ***********************************
# 2009
# # of all traffic stops in year  2009 :  1092598
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1092598
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1092598
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1092598
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1092598
# Including only serious violations
# 334568
# # of traffic stops after preprocessing step 1(add county type):  334568
# # of traffic stops after preprocessing in year  2009 :  334568
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.041880
#          Iterations 10
# ***********************************
# 2010
# # of all traffic stops in year  2010 :  1084475
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1084475
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1084475
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1084475
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1084475
# Including only serious violations
# 303204
# # of traffic stops after preprocessing step 1(add county type):  303204
# # of traffic stops after preprocessing in year  2010 :  303204
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.043158
#          Iterations 10
# ***********************************
# 2011
# # of all traffic stops in year  2011 :  1084179
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1084179
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1084179
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1084179
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1084179
# Including only serious violations
# 294041
# # of traffic stops after preprocessing step 1(add county type):  294041
# # of traffic stops after preprocessing in year  2011 :  294041
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.039741
#          Iterations 10
# ***********************************
# 2012
# # of all traffic stops in year  2012 :  1023783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1023783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1023783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1023783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1023783
# Including only serious violations
# 291091
# # of traffic stops after preprocessing step 1(add county type):  291091
# # of traffic stops after preprocessing in year  2012 :  291091
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.035061
#          Iterations 10
# ***********************************
# 2013
# # of all traffic stops in year  2013 :  903478
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  903478
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  903478
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  903478
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  903478
# Including only serious violations
# 264261
# # of traffic stops after preprocessing step 1(add county type):  264261
# # of traffic stops after preprocessing in year  2013 :  264261
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.032884
#          Iterations 10
# ***********************************
# 2014
# # of all traffic stops in year  2014 :  777272
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  777272
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  777272
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  777272
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  777272
# Including only serious violations
# 237549
# # of traffic stops after preprocessing step 1(add county type):  237549
# # of traffic stops after preprocessing in year  2014 :  237549
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.030237
#          Iterations 10
# ***********************************
# 2015
# # of all traffic stops in year  2015 :  728211
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  728211
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  728211
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  728211
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  728211
# Including only serious violations
# 217926
# # of traffic stops after preprocessing step 1(add county type):  217926
# # of traffic stops after preprocessing in year  2015 :  217926
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.030585
#          Iterations 10
# ***********************************
# 2016
# # of all traffic stops in year  2016 :  796595
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  796595
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  796595
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  796595
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  796595
# Including only serious violations
# 240779
# # of traffic stops after preprocessing step 1(add county type):  240779
# # of traffic stops after preprocessing in year  2016 :  240779
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.033257
#          Iterations 10

# %% [markdown]
# ##### contraband

# %%
year_start = 2006
year_end = 2016

asianpacific = []
black = []
hispanic = []

asianpacific_low = []
black_low = []
hispanic_low = []

asianpacific_high = []
black_high = []
hispanic_high = []

folder_path ='/content/drive/MyDrive/traffic_stop/FINAL_OUTPUTS/'
#generate_outputs(folder_path = folder_path, with_vio = False, violation_types = None)
non_border_counties = [county for county in list(county_df['County Name']) if county not in border_counties]
generate_outputs(folder_path=folder_path, analysis_type='contraband', violation_types=serious_speeding_violations, border_counties=None, county_type=None, speeding_only=False)
# Out:
# ***********************************
# 2006
# # of all traffic stops in year  2006 :  1234128
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1234128
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1234128
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1234128
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1234128
# Including only serious violations
# 466848
# # of traffic stops after preprocessing step 1(add county type):  466848
# # of traffic stops after preprocessing in year  2006 :  6189
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.271215
#          Iterations 8
# ***********************************
# 2007
# # of all traffic stops in year  2007 :  1110125
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1110125
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1110125
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1110125
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1110125
# Including only serious violations
# 412467
# # of traffic stops after preprocessing step 1(add county type):  412467
# # of traffic stops after preprocessing in year  2007 :  6020
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.250322
#          Iterations 8
# ***********************************
# 2008
# # of all traffic stops in year  2008 :  1113530
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1113530
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1113530
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1113530
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1113530
# Including only serious violations
# 349934
# # of traffic stops after preprocessing step 1(add county type):  349934
# # of traffic stops after preprocessing in year  2008 :  4050
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.204476
#          Iterations 7
# ***********************************
# 2009
# # of all traffic stops in year  2009 :  1092598
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1092598
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1092598
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1092598
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1092598
# Including only serious violations
# 334568
# # of traffic stops after preprocessing step 1(add county type):  334568
# # of traffic stops after preprocessing in year  2009 :  2379
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.291143
#          Iterations 7
# ***********************************
# 2010
# # of all traffic stops in year  2010 :  1084475
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1084475
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1084475
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1084475
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1084475
# Including only serious violations
# 303204
# # of traffic stops after preprocessing step 1(add county type):  303204
# # of traffic stops after preprocessing in year  2010 :  2239
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.269351
#          Iterations 7
# ***********************************
# 2011
# # of all traffic stops in year  2011 :  1084179
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1084179
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1084179
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1084179
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1084179
# Including only serious violations
# 294041
# # of traffic stops after preprocessing step 1(add county type):  294041
# # of traffic stops after preprocessing in year  2011 :  1967
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.275461
#          Iterations 7
# ***********************************
# 2012
# # of all traffic stops in year  2012 :  1023783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1023783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1023783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1023783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1023783
# Including only serious violations
# 291091
# # of traffic stops after preprocessing step 1(add county type):  291091
# # of traffic stops after preprocessing in year  2012 :  1676
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.284179
#          Iterations 6
# ***********************************
# 2013
# # of all traffic stops in year  2013 :  903478
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  903478
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  903478
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  903478
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  903478
# Including only serious violations
# 264261
# # of traffic stops after preprocessing step 1(add county type):  264261
# # of traffic stops after preprocessing in year  2013 :  1415
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.320502
#          Iterations 7
# ***********************************
# 2014
# # of all traffic stops in year  2014 :  777272
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  777272
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  777272
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  777272
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  777272
# Including only serious violations
# 237549
# # of traffic stops after preprocessing step 1(add county type):  237549
# # of traffic stops after preprocessing in year  2014 :  1151
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.304348
#          Iterations: 35
# ***********************************
# 2015
# # of all traffic stops in year  2015 :  728211
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  728211
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  728211
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  728211
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  728211
# Including only serious violations
# 217926
# # of traffic stops after preprocessing step 1(add county type):  217926
# # of traffic stops after preprocessing in year  2015 :  1070
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.372455
#          Iterations 6
# ***********************************
# 2016
# # of all traffic stops in year  2016 :  796595
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  796595
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  796595
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  796595
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  796595
# Including only serious violations
# 240779
# # of traffic stops after preprocessing step 1(add county type):  240779
# # of traffic stops after preprocessing in year  2016 :  1302
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.396621
#          Iterations 6

# %% [markdown]
# ### 4. Descriptive Stats of the Demographics from the Stops Data

# %%
males = []
females = []

white = []
hispanic = []
black = []
asian = []

total_records = []

for year in years:
  filename = '/content/drive/MyDrive/traffic_stop/year_data/traffic_' + str(year) + '.parquet'
  df = pd.read_parquet(filename, engine = 'pyarrow')
  males.append(df['subject_sex'].value_counts(dropna = False)['male']/len(df))
  females.append(df['subject_sex'].value_counts(dropna = False)['female']/len(df))
  #unknown_gender.append(int(df['subject_sex'].isna().sum())/len(df))

  white.append(df['subject_race'].value_counts(dropna = False)['white']/len(df))
  hispanic.append(df['subject_race'].value_counts(dropna = False)['hispanic']/len(df))
  black.append(df['subject_race'].value_counts(dropna = False)['black']/len(df))
  asian.append(df['subject_race'].value_counts(dropna = False)['asian/pacific islander']/len(df))
  #unknown_race.append(int(df['subject_race'].isna().sum())/len(df))

  total_records.append(len(df))

result_df = pd.DataFrame({'years':years, 'female':females, 'male':males, 'white':white, 'hispanic':hispanic, 'black':black, 'asian':asian})

result_df_gender = result_df[['years','female','male']]
result_df_gender['unknown'] = 1-result_df_gender['female']-result_df_gender['male']
result_df_race = result_df[['years','white','hispanic','black', 'asian']]
result_df_race['unknown'] = 1-result_df_race['white']--result_df_race['hispanic']--result_df_race['black']--result_df_race['asian']

# %%
result_df_gender
# Out:
#     years    female      male   unknown
# 0    2006  0.303428  0.696572  0.000000
# 1    2007  0.299796  0.700204  0.000000
# 2    2008  0.295731  0.704269  0.000000
# 3    2009  0.311744  0.688256  0.000000
# 4    2010  0.317156  0.682844  0.000000
# 5    2011  0.321596  0.678400  0.000003
# 6    2012  0.323267  0.676711  0.000022
# 7    2013  0.327030  0.672882  0.000089
# 8    2014  0.325900  0.674088  0.000012
# 9    2015  0.330434  0.669552  0.000014
# 10   2016  0.333662  0.666276  0.000062
# 11   2017  0.337052  0.662937  0.000011

# %%
result_df_race.plot(
    x = 'years',
    kind = 'barh',
    stacked = True,
    title = 'Stacked Bar Graph',
    mark_right = True)
# Out:
# <Axes: title={'center': 'Stacked Bar Graph'}, ylabel='years'>

# %%
result_df_gender.plot(
    x = 'years',
    kind = 'barh',
    stacked = True,
    title = 'Stacked Bar Graph',
    mark_right = True)
# Out:
# <Axes: title={'center': 'Stacked Bar Graph'}, ylabel='years'>

# %% [markdown]
# ### 5. (speeding-only) Separate Logistic Regression Models and Odds Ratio Plots for Metropolitan, Micropolitan, and Non-core

# %% [markdown]
# ##### speeding-only, metro

# %% [markdown]
# ###### citation

# %%
year_start = 2006
year_end = 2017

asianpacific = []
black = []
hispanic = []

asianpacific_low = []
black_low = []
hispanic_low = []

asianpacific_high = []
black_high = []
hispanic_high = []

folder_path ='/content/drive/MyDrive/traffic_stop/FINAL_OUTPUTS/'
#generate_outputs(folder_path = folder_path, with_vio = False, violation_types = None)
generate_outputs(folder_path='/content/', analysis_type='citation', violation_types=None, border_counties=None, county_type='Metropolitan', speeding_only=True)
# Out:
# ***********************************
# 2006
# # of all traffic stops in year  2006 :  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2673511
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2673511
# Before speed filtering:  2673511
# Speeding only violation has records:  1235103
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  637232
# # of traffic stops after preprocessing in year  2006 :  636818
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.674121
#          Iterations 4
# ***********************************
# 2007
# # of all traffic stops in year  2007 :  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2405744
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2405744
# Before speed filtering:  2405744
# Speeding only violation has records:  1110868
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  569406
# # of traffic stops after preprocessing in year  2007 :  569062
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.670757
#          Iterations 4
# ***********************************
# 2008
# # of all traffic stops in year  2008 :  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2434970
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2434970
# Before speed filtering:  2434970
# Speeding only violation has records:  1114925
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  547901
# # of traffic stops after preprocessing in year  2008 :  547190
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.649874
#          Iterations 4
# ***********************************
# 2009
# # of all traffic stops in year  2009 :  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2370986
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2370986
# Before speed filtering:  2370986
# Speeding only violation has records:  1093968
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  573271
# # of traffic stops after preprocessing in year  2009 :  572496
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.632025
#          Iterations 5
# ***********************************
# 2010
# # of all traffic stops in year  2010 :  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2452498
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2452498
# Before speed filtering:  2452498
# Speeding only violation has records:  1085945
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  568841
# # of traffic stops after preprocessing in year  2010 :  568013
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.600783
#          Iterations 5
# ***********************************
# 2011
# # of all traffic stops in year  2011 :  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2511664
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2511664
# Before speed filtering:  2511664
# Speeding only violation has records:  1085781
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  582487
# # of traffic stops after preprocessing in year  2011 :  581624
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.597733
#          Iterations 5
# ***********************************
# 2012
# # of all traffic stops in year  2012 :  2435812
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2368991
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2368990
# Before speed filtering:  2368990
# Speeding only violation has records:  1025815
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  551410
# # of traffic stops after preprocessing in year  2012 :  550314
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.604892
#          Iterations 5
# ***********************************
# 2013
# # of all traffic stops in year  2013 :  2134936
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2076400
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2076396
# Before speed filtering:  2076396
# Speeding only violation has records:  905817
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  486460
# # of traffic stops after preprocessing in year  2013 :  485220
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.612727
#          Iterations 5
# ***********************************
# 2014
# # of all traffic stops in year  2014 :  1878488
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1820773
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1820763
# Before speed filtering:  1820763
# Speeding only violation has records:  779279
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  407157
# # of traffic stops after preprocessing in year  2014 :  406101
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.632381
#          Iterations 5
# ***********************************
# 2015
# # of all traffic stops in year  2015 :  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1683954
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1683940
# Before speed filtering:  1683940
# Speeding only violation has records:  730702
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  381125
# # of traffic stops after preprocessing in year  2015 :  379837
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.627339
#          Iterations 5
# ***********************************
# 2016
# # of all traffic stops in year  2016 :  1832207
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1832089
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1832072
# Before speed filtering:  1832072
# Speeding only violation has records:  797329
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  399260
# # of traffic stops after preprocessing in year  2016 :  398899
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.632907
#          Iterations 5
# ***********************************
# 2017
# # of all traffic stops in year  2017 :  2197382
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2197369
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2197369
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2197361
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2197356
# Before speed filtering:  2197356
# Speeding only violation has records:  895256
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  463555
# # of traffic stops after preprocessing in year  2017 :  463085
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.635801
#          Iterations 5

# %% [markdown]
# ###### search

# %%
year_start = 2006
year_end = 2016

asianpacific = []
black = []
hispanic = []

asianpacific_low = []
black_low = []
hispanic_low = []

asianpacific_high = []
black_high = []
hispanic_high = []

folder_path ='/content/drive/MyDrive/traffic_stop/FINAL_OUTPUTS/'
#generate_outputs(folder_path = folder_path, with_vio = False, violation_types = None)
generate_outputs(folder_path=folder_path, analysis_type='search', violation_types=None, border_counties=None, county_type='Metropolitan', speeding_only=True)
# Out:
# ***********************************
# 2006
# # of all traffic stops in year  2006 :  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2673511
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2673511
# Before speed filtering:  2673511
# Speeding only violation has records:  1235103
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  637232
# # of traffic stops after preprocessing in year  2006 :  636818
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.048278
#          Iterations 9
# ***********************************
# 2007
# # of all traffic stops in year  2007 :  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2405744
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2405744
# Before speed filtering:  2405744
# Speeding only violation has records:  1110868
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  569406
# # of traffic stops after preprocessing in year  2007 :  569062
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.050151
#          Iterations 9
# ***********************************
# 2008
# # of all traffic stops in year  2008 :  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2434970
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2434970
# Before speed filtering:  2434970
# Speeding only violation has records:  1114925
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  547901
# # of traffic stops after preprocessing in year  2008 :  547190
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.042444
#          Iterations 10
# ***********************************
# 2009
# # of all traffic stops in year  2009 :  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2370986
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2370986
# Before speed filtering:  2370986
# Speeding only violation has records:  1093968
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  573271
# # of traffic stops after preprocessing in year  2009 :  572496
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.036381
#          Iterations 10
# ***********************************
# 2010
# # of all traffic stops in year  2010 :  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2452498
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2452498
# Before speed filtering:  2452498
# Speeding only violation has records:  1085945
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  568841
# # of traffic stops after preprocessing in year  2010 :  568013
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.037679
#          Iterations 10
# ***********************************
# 2011
# # of all traffic stops in year  2011 :  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2511664
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2511664
# Before speed filtering:  2511664
# Speeding only violation has records:  1085781
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  582487
# # of traffic stops after preprocessing in year  2011 :  581624
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.035291
#          Iterations 10
# ***********************************
# 2012
# # of all traffic stops in year  2012 :  2435812
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2368991
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2368990
# Before speed filtering:  2368990
# Speeding only violation has records:  1025815
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  551410
# # of traffic stops after preprocessing in year  2012 :  550314
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.030186
#          Iterations 10
# ***********************************
# 2013
# # of all traffic stops in year  2013 :  2134936
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2076400
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2076396
# Before speed filtering:  2076396
# Speeding only violation has records:  905817
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  486460
# # of traffic stops after preprocessing in year  2013 :  485220
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.025068
#          Iterations 10
# ***********************************
# 2014
# # of all traffic stops in year  2014 :  1878488
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1820773
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1820763
# Before speed filtering:  1820763
# Speeding only violation has records:  779279
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  407157
# # of traffic stops after preprocessing in year  2014 :  406101
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.024437
#          Iterations 10
# ***********************************
# 2015
# # of all traffic stops in year  2015 :  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1683954
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1683940
# Before speed filtering:  1683940
# Speeding only violation has records:  730702
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  381125
# # of traffic stops after preprocessing in year  2015 :  379837
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.023407
#          Iterations 10
# ***********************************
# 2016
# # of all traffic stops in year  2016 :  1832207
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1832089
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1832072
# Before speed filtering:  1832072
# Speeding only violation has records:  797329
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  399260
# # of traffic stops after preprocessing in year  2016 :  398899
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.025970
#          Iterations 10

# %% [markdown]
# ###### contraband

# %%
year_start = 2006
year_end = 2016

asianpacific = []
black = []
hispanic = []

asianpacific_low = []
black_low = []
hispanic_low = []

asianpacific_high = []
black_high = []
hispanic_high = []

folder_path ='/content/drive/MyDrive/traffic_stop/FINAL_OUTPUTS/'
#generate_outputs(folder_path = folder_path, with_vio = False, violation_types = None)
generate_outputs(folder_path=folder_path, analysis_type='contraband', violation_types=None, border_counties=None, county_type='Metropolitan', speeding_only=True)
# Out:
# ***********************************
# 2006
# # of all traffic stops in year  2006 :  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2673511
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2673511
# Before speed filtering:  2673511
# Speeding only violation has records:  1235103
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  637232
# # of traffic stops after preprocessing in year  2006 :  5462
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.249847
#          Iterations 7
# ***********************************
# 2007
# # of all traffic stops in year  2007 :  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2405744
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2405744
# Before speed filtering:  2405744
# Speeding only violation has records:  1110868
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  569406
# # of traffic stops after preprocessing in year  2007 :  5091
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.248622
#          Iterations 7
# ***********************************
# 2008
# # of all traffic stops in year  2008 :  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2434970
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2434970
# Before speed filtering:  2434970
# Speeding only violation has records:  1114925
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  547901
# # of traffic stops after preprocessing in year  2008 :  3998
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.219111
#          Iterations 7
# ***********************************
# 2009
# # of all traffic stops in year  2009 :  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2370986
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2370986
# Before speed filtering:  2370986
# Speeding only violation has records:  1093968
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  573271
# # of traffic stops after preprocessing in year  2009 :  3510
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.250245
#          Iterations 7
# ***********************************
# 2010
# # of all traffic stops in year  2010 :  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2452498
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2452498
# Before speed filtering:  2452498
# Speeding only violation has records:  1085945
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  568841
# # of traffic stops after preprocessing in year  2010 :  3632
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.231151
#          Iterations 7
# ***********************************
# 2011
# # of all traffic stops in year  2011 :  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2511664
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2511664
# Before speed filtering:  2511664
# Speeding only violation has records:  1085781
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  582487
# # of traffic stops after preprocessing in year  2011 :  3435
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.261923
#          Iterations 8
# ***********************************
# 2012
# # of all traffic stops in year  2012 :  2435812
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2368991
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2368990
# Before speed filtering:  2368990
# Speeding only violation has records:  1025815
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  551410
# # of traffic stops after preprocessing in year  2012 :  2690
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.260470
#          Iterations 7
# ***********************************
# 2013
# # of all traffic stops in year  2013 :  2134936
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2076400
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2076396
# Before speed filtering:  2076396
# Speeding only violation has records:  905817
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  486460
# # of traffic stops after preprocessing in year  2013 :  1905
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.279439
#          Iterations 8
# ***********************************
# 2014
# # of all traffic stops in year  2014 :  1878488
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1820773
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1820763
# Before speed filtering:  1820763
# Speeding only violation has records:  779279
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  407157
# # of traffic stops after preprocessing in year  2014 :  1549
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.299721
#          Iterations: 35
# ***********************************
# 2015
# # of all traffic stops in year  2015 :  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1683954
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1683940
# Before speed filtering:  1683940
# Speeding only violation has records:  730702
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  381125
# # of traffic stops after preprocessing in year  2015 :  1371
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.328040
#          Iterations 7
# ***********************************
# 2016
# # of all traffic stops in year  2016 :  1832207
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1832089
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1832072
# Before speed filtering:  1832072
# Speeding only violation has records:  797329
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  399260
# # of traffic stops after preprocessing in year  2016 :  1616
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.351157
#          Iterations 6

# %% [markdown]
# ##### speeding-only, micro

# %% [markdown]
# ###### citation

# %%
year_start = 2006
year_end = 2017

asianpacific = []
black = []
hispanic = []

asianpacific_low = []
black_low = []
hispanic_low = []

asianpacific_high = []
black_high = []
hispanic_high = []

folder_path ='/content/drive/MyDrive/traffic_stop/FINAL_OUTPUTS/'
#generate_outputs(folder_path = folder_path, with_vio = False, violation_types = None)
generate_outputs(folder_path='/content/', analysis_type='citation', violation_types=None, border_counties=None, county_type='Micropolitan', speeding_only=True)
# Out:
# ***********************************
# 2006
# # of all traffic stops in year  2006 :  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2673511
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2673511
# Before speed filtering:  2673511
# Speeding only violation has records:  1235103
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  226486
# # of traffic stops after preprocessing in year  2006 :  226270
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.625337
#          Iterations 5
# ***********************************
# 2007
# # of all traffic stops in year  2007 :  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2405744
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2405744
# Before speed filtering:  2405744
# Speeding only violation has records:  1110868
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  206560
# # of traffic stops after preprocessing in year  2007 :  206431
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.628308
#          Iterations 5
# ***********************************
# 2008
# # of all traffic stops in year  2008 :  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2434970
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2434970
# Before speed filtering:  2434970
# Speeding only violation has records:  1114925
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  212180
# # of traffic stops after preprocessing in year  2008 :  211916
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.563742
#          Iterations 5
# ***********************************
# 2009
# # of all traffic stops in year  2009 :  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2370986
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2370986
# Before speed filtering:  2370986
# Speeding only violation has records:  1093968
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  199034
# # of traffic stops after preprocessing in year  2009 :  198818
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.556116
#          Iterations 5
# ***********************************
# 2010
# # of all traffic stops in year  2010 :  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2452498
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2452498
# Before speed filtering:  2452498
# Speeding only violation has records:  1085945
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  196356
# # of traffic stops after preprocessing in year  2010 :  196118
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.545401
#          Iterations 5
# ***********************************
# 2011
# # of all traffic stops in year  2011 :  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2511664
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2511664
# Before speed filtering:  2511664
# Speeding only violation has records:  1085781
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  197040
# # of traffic stops after preprocessing in year  2011 :  196754
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.518606
#          Iterations 5
# ***********************************
# 2012
# # of all traffic stops in year  2012 :  2435812
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2368991
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2368990
# Before speed filtering:  2368990
# Speeding only violation has records:  1025815
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  191256
# # of traffic stops after preprocessing in year  2012 :  190900
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.535884
#          Iterations 5
# ***********************************
# 2013
# # of all traffic stops in year  2013 :  2134936
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2076400
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2076396
# Before speed filtering:  2076396
# Speeding only violation has records:  905817
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  170307
# # of traffic stops after preprocessing in year  2013 :  169920
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.542489
#          Iterations 5
# ***********************************
# 2014
# # of all traffic stops in year  2014 :  1878488
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1820773
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1820763
# Before speed filtering:  1820763
# Speeding only violation has records:  779279
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  152507
# # of traffic stops after preprocessing in year  2014 :  152170
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.528006
#          Iterations 5
# ***********************************
# 2015
# # of all traffic stops in year  2015 :  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1683954
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1683940
# Before speed filtering:  1683940
# Speeding only violation has records:  730702
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  145601
# # of traffic stops after preprocessing in year  2015 :  145143
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.513465
#          Iterations 5
# ***********************************
# 2016
# # of all traffic stops in year  2016 :  1832207
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1832089
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1832072
# Before speed filtering:  1832072
# Speeding only violation has records:  797329
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  167626
# # of traffic stops after preprocessing in year  2016 :  167502
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.532354
#          Iterations 5
# ***********************************
# 2017
# # of all traffic stops in year  2017 :  2197382
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2197369
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2197369
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2197361
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2197356
# Before speed filtering:  2197356
# Speeding only violation has records:  895256
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  177435
# # of traffic stops after preprocessing in year  2017 :  177299
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.524344
#          Iterations 5

# %% [markdown]
# ###### search

# %%
year_start = 2006
year_end = 2016

asianpacific = []
black = []
hispanic = []

asianpacific_low = []
black_low = []
hispanic_low = []

asianpacific_high = []
black_high = []
hispanic_high = []

folder_path ='/content/drive/MyDrive/traffic_stop/FINAL_OUTPUTS/'
#generate_outputs(folder_path = folder_path, with_vio = False, violation_types = None)
generate_outputs(folder_path=folder_path, analysis_type='search', violation_types=None, border_counties=None, county_type='Micropolitan', speeding_only=True)
# Out:
# ***********************************
# 2006
# # of all traffic stops in year  2006 :  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2673511
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2673511
# Before speed filtering:  2673511
# Speeding only violation has records:  1235103
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  226486
# # of traffic stops after preprocessing in year  2006 :  226270
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.053905
#          Iterations 9
# ***********************************
# 2007
# # of all traffic stops in year  2007 :  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2405744
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2405744
# Before speed filtering:  2405744
# Speeding only violation has records:  1110868
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  206560
# # of traffic stops after preprocessing in year  2007 :  206431
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.052318
#          Iterations 9
# ***********************************
# 2008
# # of all traffic stops in year  2008 :  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2434970
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2434970
# Before speed filtering:  2434970
# Speeding only violation has records:  1114925
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  212180
# # of traffic stops after preprocessing in year  2008 :  211916
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.048582
#          Iterations 9
# ***********************************
# 2009
# # of all traffic stops in year  2009 :  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2370986
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2370986
# Before speed filtering:  2370986
# Speeding only violation has records:  1093968
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  199034
# # of traffic stops after preprocessing in year  2009 :  198818
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.039444
#          Iterations 10
# ***********************************
# 2010
# # of all traffic stops in year  2010 :  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2452498
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2452498
# Before speed filtering:  2452498
# Speeding only violation has records:  1085945
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  196356
# # of traffic stops after preprocessing in year  2010 :  196118
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.045336
#          Iterations 10
# ***********************************
# 2011
# # of all traffic stops in year  2011 :  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2511664
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2511664
# Before speed filtering:  2511664
# Speeding only violation has records:  1085781
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  197040
# # of traffic stops after preprocessing in year  2011 :  196754
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.042970
#          Iterations 10
# ***********************************
# 2012
# # of all traffic stops in year  2012 :  2435812
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2368991
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2368990
# Before speed filtering:  2368990
# Speeding only violation has records:  1025815
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  191256
# # of traffic stops after preprocessing in year  2012 :  190900
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.033408
#          Iterations 10
# ***********************************
# 2013
# # of all traffic stops in year  2013 :  2134936
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2076400
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2076396
# Before speed filtering:  2076396
# Speeding only violation has records:  905817
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  170307
# # of traffic stops after preprocessing in year  2013 :  169920
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.028748
#          Iterations 10
# ***********************************
# 2014
# # of all traffic stops in year  2014 :  1878488
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1820773
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1820763
# Before speed filtering:  1820763
# Speeding only violation has records:  779279
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  152507
# # of traffic stops after preprocessing in year  2014 :  152170
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.029443
#          Iterations 10
# ***********************************
# 2015
# # of all traffic stops in year  2015 :  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1683954
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1683940
# Before speed filtering:  1683940
# Speeding only violation has records:  730702
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  145601
# # of traffic stops after preprocessing in year  2015 :  145143
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.022871
#          Iterations 10
# ***********************************
# 2016
# # of all traffic stops in year  2016 :  1832207
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1832089
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1832072
# Before speed filtering:  1832072
# Speeding only violation has records:  797329
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  167626
# # of traffic stops after preprocessing in year  2016 :  167502
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.023484
#          Iterations 10

# %% [markdown]
# ###### contraband

# %%
year_start = 2006
year_end = 2016

asianpacific = []
black = []
hispanic = []

asianpacific_low = []
black_low = []
hispanic_low = []

asianpacific_high = []
black_high = []
hispanic_high = []

folder_path ='/content/drive/MyDrive/traffic_stop/FINAL_OUTPUTS/'
#generate_outputs(folder_path = folder_path, with_vio = False, violation_types = None)
generate_outputs(folder_path=folder_path, analysis_type='contraband', violation_types=None, border_counties=None, county_type='Micropolitan', speeding_only=True)
# Out:
# ***********************************
# 2006
# # of all traffic stops in year  2006 :  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2673511
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2673511
# Before speed filtering:  2673511
# Speeding only violation has records:  1235103
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  226486
# # of traffic stops after preprocessing in year  2006 :  2236
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.227794
#          Iterations 7
# ***********************************
# 2007
# # of all traffic stops in year  2007 :  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2405744
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2405744
# Before speed filtering:  2405744
# Speeding only violation has records:  1110868
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  206560
# # of traffic stops after preprocessing in year  2007 :  1950
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.200812
#          Iterations: 35
# ***********************************
# 2008
# # of all traffic stops in year  2008 :  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2434970
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2434970
# Before speed filtering:  2434970
# Speeding only violation has records:  1114925
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  212180
# # of traffic stops after preprocessing in year  2008 :  1828
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.184004
#          Iterations 8
# ***********************************
# 2009
# # of all traffic stops in year  2009 :  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2370986
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2370986
# Before speed filtering:  2370986
# Speeding only violation has records:  1093968
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  199034
# # of traffic stops after preprocessing in year  2009 :  1340
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.212707
#          Iterations 7
# ***********************************
# 2010
# # of all traffic stops in year  2010 :  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2452498
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2452498
# Before speed filtering:  2452498
# Speeding only violation has records:  1085945
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  196356
# # of traffic stops after preprocessing in year  2010 :  1573
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.202096
#          Iterations: 35
# ***********************************
# 2011
# # of all traffic stops in year  2011 :  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2511664
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2511664
# Before speed filtering:  2511664
# Speeding only violation has records:  1085781
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  197040
# # of traffic stops after preprocessing in year  2011 :  1501
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.192954
#          Iterations 7
# ***********************************
# 2012
# # of all traffic stops in year  2012 :  2435812
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2368991
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2368990
# Before speed filtering:  2368990
# Speeding only violation has records:  1025815
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  191256
# # of traffic stops after preprocessing in year  2012 :  1067
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.210550
#          Iterations: 35
# ***********************************
# 2013
# # of all traffic stops in year  2013 :  2134936
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2076400
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2076396
# Before speed filtering:  2076396
# Speeding only violation has records:  905817
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  170307
# # of traffic stops after preprocessing in year  2013 :  785
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.276969
#          Iterations: 35
# ***********************************
# 2014
# # of all traffic stops in year  2014 :  1878488
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1820773
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1820763
# Before speed filtering:  1820763
# Speeding only violation has records:  779279
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  152507
# # of traffic stops after preprocessing in year  2014 :  723
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.230115
#          Iterations 7
# ***********************************
# 2015
# # of all traffic stops in year  2015 :  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1683954
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1683940
# Before speed filtering:  1683940
# Speeding only violation has records:  730702
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  145601
# # of traffic stops after preprocessing in year  2015 :  512
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.193017
#          Iterations: 35
# ***********************************
# 2016
# # of all traffic stops in year  2016 :  1832207
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1832089
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1832072
# Before speed filtering:  1832072
# Speeding only violation has records:  797329
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  167626
# # of traffic stops after preprocessing in year  2016 :  611
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.269054
#          Iterations: 35

# %% [markdown]
# ##### speeding-only, non-core

# %% [markdown]
# ###### citation

# %%
year_start = 2006
year_end = 2017

asianpacific = []
black = []
hispanic = []

asianpacific_low = []
black_low = []
hispanic_low = []

asianpacific_high = []
black_high = []
hispanic_high = []

folder_path ='/content/drive/MyDrive/traffic_stop/FINAL_OUTPUTS/'
#generate_outputs(folder_path = folder_path, with_vio = False, violation_types = None)
generate_outputs(folder_path='/content/', analysis_type='citation', violation_types=None, border_counties=None, county_type='Non core', speeding_only=True)
# Out:
# ***********************************
# 2006
# # of all traffic stops in year  2006 :  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2673511
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2673511
# Before speed filtering:  2673511
# Speeding only violation has records:  1235103
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  371385
# # of traffic stops after preprocessing in year  2006 :  371040
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.652559
#          Iterations 4
# ***********************************
# 2007
# # of all traffic stops in year  2007 :  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2405744
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2405744
# Before speed filtering:  2405744
# Speeding only violation has records:  1110868
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  334902
# # of traffic stops after preprocessing in year  2007 :  334632
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.647094
#          Iterations 4
# ***********************************
# 2008
# # of all traffic stops in year  2008 :  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2434970
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2434970
# Before speed filtering:  2434970
# Speeding only violation has records:  1114925
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  354844
# # of traffic stops after preprocessing in year  2008 :  354424
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.590761
#          Iterations 5
# ***********************************
# 2009
# # of all traffic stops in year  2009 :  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2370986
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2370986
# Before speed filtering:  2370986
# Speeding only violation has records:  1093968
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  321663
# # of traffic stops after preprocessing in year  2009 :  321284
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.590395
#          Iterations 5
# ***********************************
# 2010
# # of all traffic stops in year  2010 :  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2452498
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2452498
# Before speed filtering:  2452498
# Speeding only violation has records:  1085945
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  320748
# # of traffic stops after preprocessing in year  2010 :  320344
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.573530
#          Iterations 5
# ***********************************
# 2011
# # of all traffic stops in year  2011 :  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2511664
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2511664
# Before speed filtering:  2511664
# Speeding only violation has records:  1085781
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  306254
# # of traffic stops after preprocessing in year  2011 :  305801
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.563111
#          Iterations 5
# ***********************************
# 2012
# # of all traffic stops in year  2012 :  2435812
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2368991
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2368990
# Before speed filtering:  2368990
# Speeding only violation has records:  1025815
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  283149
# # of traffic stops after preprocessing in year  2012 :  282569
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.584241
#          Iterations 5
# ***********************************
# 2013
# # of all traffic stops in year  2013 :  2134936
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2076400
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2076396
# Before speed filtering:  2076396
# Speeding only violation has records:  905817
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  249050
# # of traffic stops after preprocessing in year  2013 :  248338
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.588563
#          Iterations 5
# ***********************************
# 2014
# # of all traffic stops in year  2014 :  1878488
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1820773
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1820763
# Before speed filtering:  1820763
# Speeding only violation has records:  779279
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  219615
# # of traffic stops after preprocessing in year  2014 :  219001
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.590869
#          Iterations 5
# ***********************************
# 2015
# # of all traffic stops in year  2015 :  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1683954
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1683940
# Before speed filtering:  1683940
# Speeding only violation has records:  730702
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  203976
# # of traffic stops after preprocessing in year  2015 :  203231
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.597744
#          Iterations 5
# ***********************************
# 2016
# # of all traffic stops in year  2016 :  1832207
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1832089
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1832072
# Before speed filtering:  1832072
# Speeding only violation has records:  797329
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  230443
# # of traffic stops after preprocessing in year  2016 :  230194
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.593053
#          Iterations 5
# ***********************************
# 2017
# # of all traffic stops in year  2017 :  2197382
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2197369
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2197369
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2197361
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2197356
# Before speed filtering:  2197356
# Speeding only violation has records:  895256
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  254266
# # of traffic stops after preprocessing in year  2017 :  253976
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.576244
#          Iterations 5

# %% [markdown]
# ###### search

# %%
year_start = 2006
year_end = 2016

asianpacific = []
black = []
hispanic = []

asianpacific_low = []
black_low = []
hispanic_low = []

asianpacific_high = []
black_high = []
hispanic_high = []

folder_path ='/content/drive/MyDrive/traffic_stop/FINAL_OUTPUTS/'
#generate_outputs(folder_path = folder_path, with_vio = False, violation_types = None)
generate_outputs(folder_path=folder_path, analysis_type='search', violation_types=None, border_counties=None, county_type='Non core', speeding_only=True)
# Out:
# ***********************************
# 2006
# # of all traffic stops in year  2006 :  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2673511
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2673511
# Before speed filtering:  2673511
# Speeding only violation has records:  1235103
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  371385
# # of traffic stops after preprocessing in year  2006 :  371040
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.050288
#          Iterations 10
# ***********************************
# 2007
# # of all traffic stops in year  2007 :  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2405744
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2405744
# Before speed filtering:  2405744
# Speeding only violation has records:  1110868
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  334902
# # of traffic stops after preprocessing in year  2007 :  334632
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.049036
#          Iterations 9
# ***********************************
# 2008
# # of all traffic stops in year  2008 :  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2434970
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2434970
# Before speed filtering:  2434970
# Speeding only violation has records:  1114925
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  354844
# # of traffic stops after preprocessing in year  2008 :  354424
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.044212
#          Iterations 9
# ***********************************
# 2009
# # of all traffic stops in year  2009 :  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2370986
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2370986
# Before speed filtering:  2370986
# Speeding only violation has records:  1093968
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  321663
# # of traffic stops after preprocessing in year  2009 :  321284
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.030312
#          Iterations 10
# ***********************************
# 2010
# # of all traffic stops in year  2010 :  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2452498
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2452498
# Before speed filtering:  2452498
# Speeding only violation has records:  1085945
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  320748
# # of traffic stops after preprocessing in year  2010 :  320344
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.030569
#          Iterations 10
# ***********************************
# 2011
# # of all traffic stops in year  2011 :  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2511664
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2511664
# Before speed filtering:  2511664
# Speeding only violation has records:  1085781
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  306254
# # of traffic stops after preprocessing in year  2011 :  305801
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.028841
#          Iterations 10
# ***********************************
# 2012
# # of all traffic stops in year  2012 :  2435812
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2368991
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2368990
# Before speed filtering:  2368990
# Speeding only violation has records:  1025815
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  283149
# # of traffic stops after preprocessing in year  2012 :  282569
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.025516
#          Iterations 10
# ***********************************
# 2013
# # of all traffic stops in year  2013 :  2134936
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2076400
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2076396
# Before speed filtering:  2076396
# Speeding only violation has records:  905817
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  249050
# # of traffic stops after preprocessing in year  2013 :  248338
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.022432
#          Iterations 10
# ***********************************
# 2014
# # of all traffic stops in year  2014 :  1878488
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1820773
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1820763
# Before speed filtering:  1820763
# Speeding only violation has records:  779279
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  219615
# # of traffic stops after preprocessing in year  2014 :  219001
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.019173
#          Iterations 11
# ***********************************
# 2015
# # of all traffic stops in year  2015 :  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1683954
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1683940
# Before speed filtering:  1683940
# Speeding only violation has records:  730702
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  203976
# # of traffic stops after preprocessing in year  2015 :  203231
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.020807
#          Iterations 10
# ***********************************
# 2016
# # of all traffic stops in year  2016 :  1832207
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1832089
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1832072
# Before speed filtering:  1832072
# Speeding only violation has records:  797329
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  230443
# # of traffic stops after preprocessing in year  2016 :  230194
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.021851
#          Iterations 10

# %% [markdown]
# ###### contraband

# %%
year_start = 2006
year_end = 2016

asianpacific = []
black = []
hispanic = []

asianpacific_low = []
black_low = []
hispanic_low = []

asianpacific_high = []
black_high = []
hispanic_high = []

folder_path ='/content/drive/MyDrive/traffic_stop/FINAL_OUTPUTS/'
#generate_outputs(folder_path = folder_path, with_vio = False, violation_types = None)
generate_outputs(folder_path=folder_path, analysis_type='contraband', violation_types=None, border_counties=None, county_type='Non core', speeding_only=True)
# Out:
# ***********************************
# 2006
# # of all traffic stops in year  2006 :  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2673511
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2673511
# Before speed filtering:  2673511
# Speeding only violation has records:  1235103
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  371385
# # of traffic stops after preprocessing in year  2006 :  3383
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.243371
#          Iterations: 35
# ***********************************
# 2007
# # of all traffic stops in year  2007 :  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2405744
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2405744
# Before speed filtering:  2405744
# Speeding only violation has records:  1110868
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  334902
# # of traffic stops after preprocessing in year  2007 :  2932
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.228388
#          Iterations 7
# ***********************************
# 2008
# # of all traffic stops in year  2008 :  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2434970
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2434970
# Before speed filtering:  2434970
# Speeding only violation has records:  1114925
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  354844
# # of traffic stops after preprocessing in year  2008 :  2729
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.176210
#          Iterations 27
# ***********************************
# 2009
# # of all traffic stops in year  2009 :  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2370986
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2370986
# Before speed filtering:  2370986
# Speeding only violation has records:  1093968
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  321663
# # of traffic stops after preprocessing in year  2009 :  1586
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.237407
#          Iterations 7
# ***********************************
# 2010
# # of all traffic stops in year  2010 :  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2452498
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2452498
# Before speed filtering:  2452498
# Speeding only violation has records:  1085945
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  320748
# # of traffic stops after preprocessing in year  2010 :  1599
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.211452
#          Iterations 8
# ***********************************
# 2011
# # of all traffic stops in year  2011 :  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2511664
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2511664
# Before speed filtering:  2511664
# Speeding only violation has records:  1085781
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  306254
# # of traffic stops after preprocessing in year  2011 :  1422
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.270794
#          Iterations: 35
# ***********************************
# 2012
# # of all traffic stops in year  2012 :  2435812
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2368991
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2368990
# Before speed filtering:  2368990
# Speeding only violation has records:  1025815
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  283149
# # of traffic stops after preprocessing in year  2012 :  1135
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.272384
#          Iterations 7
# ***********************************
# 2013
# # of all traffic stops in year  2013 :  2134936
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2076400
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2076396
# Before speed filtering:  2076396
# Speeding only violation has records:  905817
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  249050
# # of traffic stops after preprocessing in year  2013 :  858
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.308865
#          Iterations 7
# ***********************************
# 2014
# # of all traffic stops in year  2014 :  1878488
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1820773
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1820763
# Before speed filtering:  1820763
# Speeding only violation has records:  779279
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  219615
# # of traffic stops after preprocessing in year  2014 :  625
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.278134
#          Iterations 7
# ***********************************
# 2015
# # of all traffic stops in year  2015 :  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1683954
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1683940
# Before speed filtering:  1683940
# Speeding only violation has records:  730702
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  203976
# # of traffic stops after preprocessing in year  2015 :  644
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.369793
#          Iterations 6
# ***********************************
# 2016
# # of all traffic stops in year  2016 :  1832207
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1832089
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1832072
# Before speed filtering:  1832072
# Speeding only violation has records:  797329
# Including only a certain type of county
# # of traffic stops after preprocessing step 1(add county type):  230443
# # of traffic stops after preprocessing in year  2016 :  769
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.387277
#          Iterations 6

# %% [markdown]
# ### 6. COLLECT INFO: Demographics Stats of *all* drivers (find this info from some government/ACS website)

# %% [markdown]
# demographic info of all drivers: https://www.zippia.com/driver-jobs/demographics/

# %% [markdown]
# race and gender

# %%
filename = '/content/drive/MyDrive/traffic_stop/year_data/traffic_' + str(2006) + '.parquet'
df = pd.read_parquet(filename, engine = 'pyarrow')
df_demo = pd.DataFrame(columns = ['year', 'male', 'female', 'white', 'hispanic', 'black', 'asian'])

for year in list(range(2007, 2018)):
  print(year)
  df = pd.read_parquet(('/content/drive/MyDrive/traffic_stop/year_data/traffic_'+str(year)+'.parquet'), engine = 'pyarrow')
  df_gender = df['subject_sex'].value_counts()
  df_race = df['subject_race'].value_counts()
  # exclude unknown/other races from the analysis
  df_demo.loc[len(df.index)] = [year, int(df_gender.loc['male']), int(df_gender.loc['female']),
                                int(df_race.loc['white']), int(df_race.loc['hispanic']), int(df_race.loc['black']), int(df_race.loc['asian/pacific islander'])]
df_demo
# Out:
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
#          year     male  female    white  hispanic   black  asian
# 2427347  2007  1699637  727710  1610647    529916  237865  25894
# 2526783  2008  1779536  747247  1765640    413522  223244  29668
# 2441306  2009  1680243  761063  1347251    748485  236026  36461
# 2525296  2010  1724383  800913  1377987    780653  251410  39327
# 2588004  2011  1755702  832293  1407655    793816  262052  44695
# 2435812  2012  1648341  787418  1340746    726378  253645  43894
# 2134936  2013  1436559  698188  1159206    658188  215565  38511
# 1878488  2014  1266266  612199   946045    655358  181853  32904
# 1745385  2015  1168626  576735   801762    676307  169820  30725
# 1832207  2016  1220756  611338   863280    751113  188002  28232
# 2197382  2017  1456726  740631   975968    949150  234564  35741

# %%
df_demo['male_percentage'] = df_demo.apply(lambda x: x['male']/(x['male']+x['female']), axis = 1)
df_demo['female_percentage'] = df_demo.apply(lambda x: x['female']/(x['male']+x['female']), axis = 1)
df_demo['white_percentage'] = df_demo.apply(lambda x: x['white']/(x['white']+x['hispanic']+x['black']+x['asian']), axis = 1)
df_demo['black_percentage'] = df_demo.apply(lambda x: x['black']/(x['white']+x['hispanic']+x['black']+x['asian']), axis = 1)
df_demo['hispanic_percentage'] = df_demo.apply(lambda x: x['hispanic']/(x['white']+x['hispanic']+x['black']+x['asian']), axis = 1)
df_demo['asian_percentage'] = df_demo.apply(lambda x: x['asian']/(x['white']+x['hispanic']+x['black']+x['asian']), axis = 1)

# %%
df_demo
# Out:
#          year     male  female    white  hispanic   black  asian  \
# 2427347  2007  1699637  727710  1610647    529916  237865  25894
# 2526783  2008  1779536  747247  1765640    413522  223244  29668
# 2441306  2009  1680243  761063  1347251    748485  236026  36461
# 2525296  2010  1724383  800913  1377987    780653  251410  39327
# 2588004  2011  1755702  832293  1407655    793816  262052  44695
# 2435812  2012  1648341  787418  1340746    726378  253645  43894
# 2134936  2013  1436559  698188  1159206    658188  215565  38511
# 1878488  2014  1266266  612199   946045    655358  181853  32904
# 1745385  2015  1168626  576735   801762    676307  169820  30725
# 1832207  2016  1220756  611338   863280    751113  188002  28232
# 2197382  2017  1456726  740631   975968    949150  234564  35741
#
#          male_percentage  female_percentage  white_percentage  \
# 2427347         0.700204           0.299796          0.669897
# 2526783         0.704269           0.295731          0.725981
# 2441306         0.688256           0.311744          0.568887
# 2525296         0.682844           0.317156          0.562587
# 2588004         0.678402           0.321598          0.561217
# 2435812         0.676726           0.323274          0.566992
# 2134936         0.672941           0.327059          0.559605
# 1878488         0.674096           0.325904          0.520904
# 1745385         0.669561           0.330439          0.477633
# 1832207         0.666317           0.333683          0.471576
# 2197382         0.662945           0.337055          0.444547
#
#          black_percentage  hispanic_percentage  asian_percentage
# 2427347          0.098932             0.220401          0.010770
# 2526783          0.091792             0.170029          0.012199
# 2441306          0.099664             0.316053          0.015396
# 2525296          0.102642             0.318715          0.016056
# 2588004          0.104477             0.316486          0.017819
# 2435812          0.107265             0.307180          0.018562
# 2134936          0.104064             0.317740          0.018591
# 1878488          0.100130             0.360848          0.018117
# 1745385          0.101167             0.402896          0.018304
# 1832207          0.102698             0.410304          0.015422
# 2197382          0.106842             0.432331          0.016280

# %%
plt.plot(df_demo['year'],df_demo['male_percentage'], label = 'male percentage')
plt.plot(df_demo['year'],df_demo['female_percentage'], label = 'female percentage')
plt.legend()
plt.title('Traffic Stop Gender Composition')
# Out:
# Text(0.5, 1.0, 'Traffic Stop Gender Composition')

# %%
plt.plot(df_demo['year'],df_demo['white_percentage'], label = 'white')
plt.plot(df_demo['year'],df_demo['black_percentage'], label = 'black')
plt.plot(df_demo['year'],df_demo['hispanic_percentage'], label = 'hispanic')
plt.plot(df_demo['year'],df_demo['asian_percentage'], label = 'asian/pacific islander')
plt.legend()
plt.title('Traffic Stop Race Composition')
# Out:
# Text(0.5, 1.0, 'Traffic Stop Race Composition')

# %%
sns.lineplot(data = df_demo[['male_percentage','female_percentage']])
plt.title('Traffic Stop Gender Composition')
# Out:
# Text(0.5, 1.0, 'Traffic Stop Gender Composition')

# %%
sns.lineplot(data = df_demo[['white_percentage','black_percentage','hispanic_percentage','asian_percentage']])
plt.title('Race Composition')
# Out:
# Text(0.5, 1.0, 'Race Composition')

# %% [markdown]
# ### 7. COLLECT INFO: Create countyinfo.csv and push it to repository

# %% [markdown]
# ### 8. What is that 'perfect separation' when using search as y?
