# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import warnings
warnings.filterwarnings("ignore")

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Check countyinfo.csv

# %%
# Sanity test for countyinfo.csv
region_df = pd.read_excel(os.path.join('..', 'External Data', 'countyinfo.xlsx'))
region_df
# Out:
#         county       region
# 0     Atascosa        Alamo
# 1      Bandera        Alamo
# 2        Bexar        Alamo
# 3      Calhoun        Alamo
# 4        Comal        Alamo
# ..         ...          ...
# 249    Terrell  West Texas
# 250  Tom Green  West Texas
# 251      Upton  West Texas
# 252       Ward  West Texas
# 253    Winkler  West Texas
#
# [254 rows x 2 columns]

# %%
# Sanity test for mapping county name to economic region
filename = os.path.join('..', 'data', 'year_data', 'traffic_' + str(2007) + '.parquet')
df = pd.read_parquet(filename, engine = 'pyarrow')
df['county'] = [name[:-7] for name in df['county_name']]
df['county'] = df['county'].replace('Dewitt','DeWitt')
df.drop('region', axis = 1, inplace = True)
df = df.join(region_df.set_index('county'), on='county')
df.drop('county', axis = 1, inplace=True)
df.rename(columns={'region':'county_region'}, inplace=True)

df.head()
# Out:
#         raw_row_number        date      time                    location  lat  \
# 2693894        2766545  2007-01-01  00:00:00  route: 0059, milepost: 698  NaN
# 2693895        2766546  2007-01-01  00:00:00  route: 0105, milepost: 442  NaN
# 2693896        2766547  2007-01-01  00:00:00  route: 2221, milepost: 508  NaN
# 2693897        2766548  2007-01-01  00:00:00  route: 0035, milepost: 176  NaN
# 2693898        2766549  2007-01-01  00:00:00  route: 0191, milepost: 258  NaN
#
#          lng       county_name district precinct subject_race  ...  \
# 2693894  NaN        Bee County        A     None     hispanic  ...
# 2693895  NaN     Orange County        B     None        white  ...
# 2693896  NaN    Hidalgo County        A       31        white  ...
# 2693897  NaN  Guadalupe County        B       30        white  ...
# 2693898  NaN      Ector County        A     None        white  ...
#
#         vehicle_model vehicle_type vehicle_year raw_HA_RACE_SEX  \
# 2693894          None           PU          NaN              HM
# 2693895          None           PU          NaN              WM
# 2693896          None           PU          NaN              WM
# 2693897          None           PA          NaN              WF
# 2693898          None           PA          NaN              WF
#
#          raw_HA_SEARCH_PC_boolean  raw_HA_SEARCH_CONCENT_boolean  \
# 2693894                     False                          False
# 2693895                     False                          False
# 2693896                     False                          False
# 2693897                     False                          False
# 2693898                     False                          False
#
#         raw_HA_INCIDTO_ARREST_boolean raw_HA_VEHICLE_INVENT_boolean  year  \
# 2693894                         False                         False  2007
# 2693895                         False                         False  2007
# 2693896                         False                         False  2007
# 2693897                         False                         False  2007
# 2693898                         False                         False  2007
#
#         county_region
# 2693894  South Texas
# 2693895    Southeast
# 2693896  South Texas
# 2693897         Alamo
# 2693898   West Texas
#
# [5 rows x 35 columns]

# %%
# Check if mapping misses any county name to region
sum(df['county_region'].isna())
# Out:
# 0

# %%
list(region_df['region'].unique())
# Out:
# ['Alamo',
#  'Capital',
#  'Central Texas ',
#  'Gulf Coast ',
#  'High Plains ',
#  'Metroplex ',
#  'Northwest ',
#  'South Texas ',
#  'Southeast ',
#  ' Upper East ',
#  'UPPER RIO GRANDE',
#  'West Texas ']

# %% [markdown]
# ### Preprocessing Functions

# %%
def remove_duplicates(row):
  if row['speeding_only'] == 'speeding-repeated_entries':
    return row['all_violation'][0].strip()
  else:
    return row['violation']

def remove_white_spaces(vio_lst):
  vio_lst = [x.strip() for x in vio_lst]
  return vio_lst


def exclusive(vio_lst):
  count = 0
  for vio in vio_lst:
    # count number of violations containing 'speed'
    if 'speed' in vio:
      count += 1
  # if we have non-speeding violation
  if count < len(vio_lst):
    return 'speeding + others'
  # if we only have speeding violation
  elif count == len(vio_lst):
    # if one speeding vio type
    if count == 1:
      return 'speeding-1'
    # if we have more than one entries but only one type
    elif len(set(vio_lst)) == 1:
      return 'speeding-repeated_entries'
    # if we have more than one type
    else:
      return 'speeding-multiple'
  else:
    return 'undefined case'

# %%
def speeding_filter(df):
  print('Before speed filtering: ', len(df))
  df['violation'] = [s.lower() for s in df['violation']]
  # at least one violation is speeding-violated (could have other violations at the same time)
  df = df.loc[df['violation'].str.contains('speed', regex = False),:]
  df['violation'] = df['violation'].map(lambda x: x.replace('(#)',''))
  df['violation'] = df['violation'].map(lambda x: x.strip())

  # get a list of violations for each record, and apply self-defined func exclusive
  df['all_violation'] = df['violation'].str.split('|')
  df['all_violation'] = df['all_violation'].map(lambda x: remove_white_spaces(x))
  df['speeding_only'] = df['all_violation'].map(lambda x: exclusive(x))

  # filter out rows with violations other than speeding
  df = df.loc[df['speeding_only'].isin(['speeding-repeated_entries','speeding-1','speeding-multiple']),:]

  df['violation'] = df.apply(lambda row: remove_duplicates(row), axis = 1)

  df.drop(['all_violation','speeding_only'], axis = 1, inplace = True)
  print('Speeding only violation has records: ', len(df))
  return df

# %%
# this function is called by preprocess
def remove_empty_rows(df, colName):
	df = df[df[colName] != 'unknown']
	df = df[df[colName].notna()]
	return(df)

# %%
# columns we need in the analysis
keep_col = [
            'county_name',
            'subject_race',
            'subject_sex',
            'violation',
            'citation_issued',
            ]

# delete rows with missing value in these columns
rm_na_col = ['county_name','violation','subject_race','subject_sex']

# %%
### this function used in run_year_analysis()
def preprocess(year, rm_na_col, analysis_type,
               violation_types=None, border_counties=None, county_type=None, speeding_only=False, county_region=None):
  """
  with_vio: if include vioation type variables: True, if not include, False
  violation_types: violation types to be included in the analysis
  """
  # read dataframe
  # CHANGED 2023/07/12, why file_path: '/content/drive/MyDrive/traffic_stop/year_data_daylight/'???
  filename = os.path.join('..', 'data', 'year_data', 'traffic_' + str(year) + '.parquet')
  if violation_types:
    filename = os.path.join('..', 'data','year_data_speeding_only', 'traffic_' + str(year) + '.parquet')
  df = pd.read_parquet(filename, engine = 'pyarrow')
  print('# of all traffic stops in year ', year, ': ', len(df))

  # invalid value (IF NOT TEXAS STATE DATA, DELETE THIS INVALID VALUE BLOCK)
  if year == 2013:
    df.drop(df.index[df['lat'] == 74.052879], inplace=True)

  # based on analysis types, decide which columns to keep
  if analysis_type == 'citation':
    keep_col = [
            'county_name',
            'subject_race',
            'subject_sex',
            'violation',
            'citation_issued',
            ]
  elif analysis_type == 'search':
    keep_col = [
            'county_name',
            'subject_race',
            'subject_sex',
            'violation',
            'search_conducted'
            ]
  elif analysis_type == 'contraband':
    keep_col = [
            'county_name',
            'subject_race',
            'subject_sex',
            'violation',
            'search_conducted',
            'contraband_found',
            ]

  # drop unrelated columns
  col_drop = [col for col in df.columns if col not in keep_col]
  df.drop(col_drop, axis = 1, inplace = True)

  # remove rows with missing values in rm_na_col
  for col in rm_na_col:
    df = remove_empty_rows(df, col)
    # newly added 2023/07/12
    print('# of traffic stops after preprocessing step 0 - drop na/unknown in COL [',col,']: ',len(df))

  # if we want to only include certain violation types:
  if violation_types:
    print('Including only serious violations')
    #df['violation'] = df['violation'].map(lambda x: x.replace(' (#)', '').strip())
    df = df.loc[df['violation'].isin(violation_types),:]
    print(len(df))

  # filter rows if speeding_only
  if speeding_only:
    # filter: only speeding violation (no other violations)
    df = speeding_filter(df)

  ######### THIS WHOLE BLOACK NEEDS TO BE CHANGED, NEW METROPOLITAN FILES AND DIFFERENT DATA FORMAT #########

  # County names are converted to county type - metropolitan, micropolitan or non-core
  # For definitions, see US OMB website

  # read in county info csv
  county_df = pd.read_csv(os.path.join('..', 'data', '2014-2018.csv'))
  county_df = county_df[county_df['State']=='Texas']
  county_df = county_df.filter(items=['Metropolitan Status', 'County Name'])

  # transform column
  df['county'] = [name[:-7] for name in df['county_name']]
  df['county'] = df['county'].replace('Dewitt','DeWitt')

  # if we want to include only border counties:
  if border_counties:
    print('Including only border counties')
    df = df.loc[df['county'].isin(border_counties),:]

  df = df.join(county_df.set_index('County Name'), on='county')
  #df.drop('county', axis = 1, inplace=True)
  df.rename(columns={'Metropolitan Status':'county_type'}, inplace=True)

  if county_type:
    print('Including only a certain type of county')
    df = df.loc[df['county_type'] == county_type,:]
    df.drop(['county_type'], axis = 1, inplace = True)

  # newly added 2023/07/12
  print('# of traffic stops after preprocessing step 1(add county type): ', len(df))
  ###############################################################

  region_df = pd.read_excel(os.path.join('..', 'External Data', 'countyinfo.xlsx'))

  # transform column
  df = df.join(region_df.set_index('county'), on='county')
  df.rename(columns={'region':'county_region'}, inplace=True)

  # newly added 2023/07/12
  if county_region:
    print('Including only an economic region: ', county_region)
    df = df.loc[df['county_region'] == county_region,:]
    df.drop(['county_region'], axis = 1, inplace = True)

  df.drop('county', axis = 1, inplace=True)
  #print('# of traffic stops after preprocessing step 1(add county region): ', len(df))

  ######### Metropolitan block ends here #########

  # if race is other/unknown, we delete the rows!
  df = df.loc[(df['subject_race'] != 'unknown') & (df['subject_race'] != 'other'),:]
  df['subject_race'] = df.subject_race.cat.remove_unused_categories()

  df.drop(['county_name','violation'], axis = 1, inplace = True)

  # I delete the block for with_vio, we never used that

  # based on analysis type, decide y
  if analysis_type == 'citation':
    # Convert 'citation issued' to integer
    df = df.astype({'citation_issued': 'int64'})
    y = df['citation_issued']
    df.drop(['citation_issued'], axis = 1, inplace = True)

  elif analysis_type == 'search':
    df["search_conducted"].fillna(False, inplace = True)
    df = df.astype({'search_conducted': 'int64'})
    y = df['search_conducted']
    df.drop(['search_conducted'], axis = 1, inplace = True)

  elif analysis_type == 'contraband':
    df= df[(df['search_conducted']==1)]
    df = df.reset_index(drop = True)
    df = df.astype({'contraband_found': 'int64'})
    y = df['contraband_found']
    df.drop(['contraband_found', 'search_conducted'], axis = 1, inplace = True)


  # other x variables get dummies
  df = pd.get_dummies(df)
  if not county_type:
    df.drop(['subject_race_white', 'county_type_Metropolitan', 'subject_sex_male'], axis = 1, inplace = True)
  else:
    df.drop(['subject_race_white', 'subject_sex_male'], axis = 1, inplace = True)

  df.reset_index(drop=True, inplace=True)
  y.reset_index(drop=True, inplace=True)

  print('# of traffic stops after preprocessing in year ', year, ': ', len(df))
  return (y, df)

# %%
### this function used in generate_outputs()
def run_year_analysis(analysis_type, rm_na_col, df_years,
                      violation_types=None, border_counties=None, county_type=None, speeding_only=False, county_region=None):
  """
  param:
  violation_types: violation types to be included in the analysis

  Output:
  A result dataframe
  """
  years = list(range(year_start, year_end+1))

  for year in years:
    # read in the data
    print('***********************************')
    print(year)
    if county_region:
      print(county_region)

    # read in and preprocess data
    y, X = preprocess(year, rm_na_col, analysis_type, violation_types, border_counties, county_type, speeding_only, county_region)
    # added 2023/07/12
    print(X.columns)

    #adding constant to X
    X_with_constant = sm.add_constant(X)
    # building the model and fitting the data
    log_reg = sm.Logit(y, X_with_constant).fit()

    res_df = pd.DataFrame({'variable':list(log_reg.params.index), 'coef':list(log_reg.params.values),
                           'odds_ratio':list(np.exp(log_reg.params.values)),
                           'lower_CI':list(np.exp(log_reg.conf_int()[0].values)),
                           'upper_CI':list(np.exp(log_reg.conf_int()[1].values)),'pvalue':list(log_reg.pvalues)})

    df_years = df_years.merge(res_df, left_on = 'variable', right_on = 'variable', how = 'outer')
    df_years = df_years.rename(columns = {'coef': ('coef_' + str(year)),
                                          'odds_ratio': ('odds_ratio_' + str(year)),
                                          'lower_CI': ('OR_lower_CI_' + str(year)),
                                          'upper_CI': ('OR_upper_CI_' + str(year)),
                                          'pvalue': ('pvalue_' + str(year))})

    # append race coefs to result list for plotting
    black.append(np.exp(log_reg.params['subject_race_black']))
    hispanic.append(np.exp(log_reg.params['subject_race_hispanic']))
    asianpacific.append(np.exp(log_reg.params['subject_race_asian/pacific islander']))

    # lower CI
    black_low.append(np.exp(log_reg.conf_int()[0]['subject_race_black']))
    hispanic_low.append(np.exp(log_reg.conf_int()[0]['subject_race_hispanic']))
    asianpacific_low.append(np.exp(log_reg.conf_int()[0]['subject_race_asian/pacific islander']))

    # upper CI
    black_high.append(np.exp(log_reg.conf_int()[1]['subject_race_black']))
    hispanic_high.append(np.exp(log_reg.conf_int()[1]['subject_race_hispanic']))
    asianpacific_high.append(np.exp(log_reg.conf_int()[1]['subject_race_asian/pacific islander']))

  return df_years

# write result df to csv file

# %%
sns.set_theme()
sns.set_style("whitegrid")

# %%
def generate_outputs(folder_path, analysis_type, violation_types = None, border_counties=None, county_type=None, speeding_only = False, county_region=None):
  """
  function outputs a csv file, a jpg and an svg figure
  PARAMS:
  folder path: eg., '/gdrive/MyDrive/traffic_stop/output_0502/'
  """
  # columns to store
  var_lst_baseline = ['subject_race_black', 'subject_race_hispanic', 'subject_race_asian/pacific islander','subject_sex_female']

  df_years = pd.DataFrame({'variable':var_lst_baseline})


  res_df = run_year_analysis(analysis_type=analysis_type, rm_na_col=rm_na_col, df_years=df_years, violation_types=violation_types,
                    border_counties=border_counties, county_type=county_type, speeding_only=speeding_only, county_region=county_region)

  # save csv
  speeding = '_speeding' if speeding_only else ''
  violation = '_SeriousVio' if violation_types else ''
  border = '_non_border' if border_counties else ''
  county = '_' + county_type if county_type else ''
  region = '_' + county_region if county_region else ''

  file_name = analysis_type + speeding + violation + border + county + region + '.csv'

  # CHANGE THE PATH
  save_path = folder_path + file_name
  res_df.to_csv(save_path, index = False)

  years = list(range(year_start, year_end + 1))

  #sns.set_theme()
  #sns.set_style("white")
  sns.set(font_scale=1.25)
  plt.style.use('seaborn-v0_8-whitegrid')

  sns.lineplot(x = years, y = black, color = 'red', label="Black")
  sns.lineplot(x = years, y = hispanic, color = 'blue', label="Hispanic")
  sns.lineplot(x = years, y = asianpacific, color = 'green', label="Asian/Pacific Islander")

  sns.lineplot(x = years, y = black_low, color = 'red', linestyle='--')
  sns.lineplot(x = years, y = hispanic_low, color = 'blue', linestyle='--')
  sns.lineplot(x = years, y = asianpacific_low, color = 'green', linestyle='--')

  sns.lineplot(x = years, y = black_high, color = 'red', linestyle='--')
  sns.lineplot(x = years, y = hispanic_high, color = 'blue', linestyle='--')
  sns.lineplot(x = years, y = asianpacific_high, color = 'green', linestyle='--')

  # changed 08/04, same y axis scale
  plt.xlim(2006, 2017)
  plt.ylim(0.5, 3.5)

  plt.axhline(y=1, color='grey', alpha=0.8, linestyle='-')
  plt.xlabel('Year')
  plt.ylabel('Odds Ratio')
  plt.legend(bbox_to_anchor=(0.5, -0.36), loc='lower center', ncol = 3)



  # CHANGE THE PATH HERE
  #figure_name1 = file_name.replace('csv', 'svg')
  # figure_name2 = file_name.replace('csv', 'jpg')
  figure_name3 = file_name.replace('csv', 'pdf')
  #plt.savefig((folder_path+figure_name1), format = 'svg', bbox_inches="tight")
  # plt.savefig((folder_path+figure_name2), dpi = 200, bbox_inches="tight")
  plt.savefig((folder_path+figure_name3), format="pdf", bbox_inches="tight")

  plt.show()

# %%
region_lst = list(region_df['region'].unique())

# %% [markdown]
# ### Speeding-only, Citation

# %%
year_start = 2006
year_end = 2017

#folder_path ='/content/drive/MyDrive/traffic_stop/region_outputs/'
folder_path ='./'
#generate_outputs(folder_path = folder_path, with_vio = False, violation_types = None)
for region in region_lst:
  asianpacific = []
  black = []
  hispanic = []

  asianpacific_low = []
  black_low = []
  hispanic_low = []

  asianpacific_high = []
  black_high = []
  hispanic_high = []
  generate_outputs(folder_path=folder_path, analysis_type='citation', violation_types=None, border_counties=None, county_type=None, speeding_only=True, county_region=region)
# Out:
# ***********************************
# 2006
# Alamo
# # of all traffic stops in year  2006 :  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2673511
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2673511
# Before speed filtering:  2673511
# Speeding only violation has records:  1235103
# # of traffic stops after preprocessing step 1(add county type):  1235103
# Including only an economic region:  Alamo
# # of traffic stops after preprocessing in year  2006 :  98279
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.675607
#          Iterations 5
# ***********************************
# 2007
# Alamo
# # of all traffic stops in year  2007 :  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2405744
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2405744
# Before speed filtering:  2405744
# Speeding only violation has records:  1110868
# # of traffic stops after preprocessing step 1(add county type):  1110868
# Including only an economic region:  Alamo
# # of traffic stops after preprocessing in year  2007 :  83176
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.671011
#          Iterations 4
# ***********************************
# 2008
# Alamo
# # of all traffic stops in year  2008 :  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2434970
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2434970
# Before speed filtering:  2434970
# Speeding only violation has records:  1114925
# # of traffic stops after preprocessing step 1(add county type):  1114925
# Including only an economic region:  Alamo
# # of traffic stops after preprocessing in year  2008 :  79391
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.661756
#          Iterations 4
# ***********************************
# 2009
# Alamo
# # of all traffic stops in year  2009 :  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2370986
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2370986
# Before speed filtering:  2370986
# Speeding only violation has records:  1093968
# # of traffic stops after preprocessing step 1(add county type):  1093968
# Including only an economic region:  Alamo
# # of traffic stops after preprocessing in year  2009 :  84385
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.652658
#          Iterations 4
# ***********************************
# 2010
# Alamo
# # of all traffic stops in year  2010 :  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2452498
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2452498
# Before speed filtering:  2452498
# Speeding only violation has records:  1085945
# # of traffic stops after preprocessing step 1(add county type):  1085945
# Including only an economic region:  Alamo
# # of traffic stops after preprocessing in year  2010 :  86234
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.630750
#          Iterations 5
# ***********************************
# 2011
# Alamo
# # of all traffic stops in year  2011 :  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2511664
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2511664
# Before speed filtering:  2511664
# Speeding only violation has records:  1085781
# # of traffic stops after preprocessing step 1(add county type):  1085781
# Including only an economic region:  Alamo
# # of traffic stops after preprocessing in year  2011 :  89143
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.612897
#          Iterations 5
# ***********************************
# 2012
# Alamo
# # of all traffic stops in year  2012 :  2435812
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2368991
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2368990
# Before speed filtering:  2368990
# Speeding only violation has records:  1025815
# # of traffic stops after preprocessing step 1(add county type):  1025815
# Including only an economic region:  Alamo
# # of traffic stops after preprocessing in year  2012 :  84416
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.603574
#          Iterations 5
# ***********************************
# 2013
# Alamo
# # of all traffic stops in year  2013 :  2134936
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2076400
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2076396
# Before speed filtering:  2076396
# Speeding only violation has records:  905817
# # of traffic stops after preprocessing step 1(add county type):  905817
# Including only an economic region:  Alamo
# # of traffic stops after preprocessing in year  2013 :  75160
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.602642
#          Iterations 5
# ***********************************
# 2014
# Alamo
# # of all traffic stops in year  2014 :  1878488
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1820773
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1820763
# Before speed filtering:  1820763
# Speeding only violation has records:  779279
# # of traffic stops after preprocessing step 1(add county type):  779279
# Including only an economic region:  Alamo
# # of traffic stops after preprocessing in year  2014 :  64863
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.634165
#          Iterations 5
# ***********************************
# 2015
# Alamo
# # of all traffic stops in year  2015 :  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1683954
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1683940
# Before speed filtering:  1683940
# Speeding only violation has records:  730702
# # of traffic stops after preprocessing step 1(add county type):  730702
# Including only an economic region:  Alamo
# # of traffic stops after preprocessing in year  2015 :  63062
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.641246
#          Iterations 5
# ***********************************
# 2016
# Alamo
# # of all traffic stops in year  2016 :  1832207
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1832089
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1832072
# Before speed filtering:  1832072
# Speeding only violation has records:  797329
# # of traffic stops after preprocessing step 1(add county type):  797329
# Including only an economic region:  Alamo
# # of traffic stops after preprocessing in year  2016 :  56845
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.646638
#          Iterations 5
# ***********************************
# 2017
# Alamo
# # of all traffic stops in year  2017 :  2197382
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2197369
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2197369
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2197361
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2197356
# Before speed filtering:  2197356
# Speeding only violation has records:  895256
# # of traffic stops after preprocessing step 1(add county type):  895256
# Including only an economic region:  Alamo
# # of traffic stops after preprocessing in year  2017 :  57852
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.640758
#          Iterations 5
# ***********************************
# 2006
# Capital
# # of all traffic stops in year  2006 :  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2673511
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2673511
# Before speed filtering:  2673511
# Speeding only violation has records:  1235103
# # of traffic stops after preprocessing step 1(add county type):  1235103
# Including only an economic region:  Capital
# # of traffic stops after preprocessing in year  2006 :  68085
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.684995
#          Iterations 4
# ***********************************
# 2007
# Capital
# # of all traffic stops in year  2007 :  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2405744
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2405744
# Before speed filtering:  2405744
# Speeding only violation has records:  1110868
# # of traffic stops after preprocessing step 1(add county type):  1110868
# Including only an economic region:  Capital
# # of traffic stops after preprocessing in year  2007 :  62128
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.683731
#          Iterations 4
# ***********************************
# 2008
# Capital
# # of all traffic stops in year  2008 :  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2434970
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2434970
# Before speed filtering:  2434970
# Speeding only violation has records:  1114925
# # of traffic stops after preprocessing step 1(add county type):  1114925
# Including only an economic region:  Capital
# # of traffic stops after preprocessing in year  2008 :  60485
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.670603
#          Iterations 4
# ***********************************
# 2009
# Capital
# # of all traffic stops in year  2009 :  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2370986
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2370986
# Before speed filtering:  2370986
# Speeding only violation has records:  1093968
# # of traffic stops after preprocessing step 1(add county type):  1093968
# Including only an economic region:  Capital
# # of traffic stops after preprocessing in year  2009 :  61333
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.655827
#          Iterations 4
# ***********************************
# 2010
# Capital
# # of all traffic stops in year  2010 :  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2452498
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2452498
# Before speed filtering:  2452498
# Speeding only violation has records:  1085945
# # of traffic stops after preprocessing step 1(add county type):  1085945
# Including only an economic region:  Capital
# # of traffic stops after preprocessing in year  2010 :  59344
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.638318
#          Iterations 5
# ***********************************
# 2011
# Capital
# # of all traffic stops in year  2011 :  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2511664
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2511664
# Before speed filtering:  2511664
# Speeding only violation has records:  1085781
# # of traffic stops after preprocessing step 1(add county type):  1085781
# Including only an economic region:  Capital
# # of traffic stops after preprocessing in year  2011 :  62098
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.652982
#          Iterations 4
# ***********************************
# 2012
# Capital
# # of all traffic stops in year  2012 :  2435812
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2368991
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2368990
# Before speed filtering:  2368990
# Speeding only violation has records:  1025815
# # of traffic stops after preprocessing step 1(add county type):  1025815
# Including only an economic region:  Capital
# # of traffic stops after preprocessing in year  2012 :  56076
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.664553
#          Iterations 4
# ***********************************
# 2013
# Capital
# # of all traffic stops in year  2013 :  2134936
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2076400
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2076396
# Before speed filtering:  2076396
# Speeding only violation has records:  905817
# # of traffic stops after preprocessing step 1(add county type):  905817
# Including only an economic region:  Capital
# # of traffic stops after preprocessing in year  2013 :  57642
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.686854
#          Iterations 4
# ***********************************
# 2014
# Capital
# # of all traffic stops in year  2014 :  1878488
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1820773
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1820763
# Before speed filtering:  1820763
# Speeding only violation has records:  779279
# # of traffic stops after preprocessing step 1(add county type):  779279
# Including only an economic region:  Capital
# # of traffic stops after preprocessing in year  2014 :  47339
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.687412
#          Iterations 4
# ***********************************
# 2015
# Capital
# # of all traffic stops in year  2015 :  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1683954
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1683940
# Before speed filtering:  1683940
# Speeding only violation has records:  730702
# # of traffic stops after preprocessing step 1(add county type):  730702
# Including only an economic region:  Capital
# # of traffic stops after preprocessing in year  2015 :  34596
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.674796
#          Iterations 4
# ***********************************
# 2016
# Capital
# # of all traffic stops in year  2016 :  1832207
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1832089
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1832072
# Before speed filtering:  1832072
# Speeding only violation has records:  797329
# # of traffic stops after preprocessing step 1(add county type):  797329
# Including only an economic region:  Capital
# # of traffic stops after preprocessing in year  2016 :  31699
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.683650
#          Iterations 4
# ***********************************
# 2017
# Capital
# # of all traffic stops in year  2017 :  2197382
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2197369
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2197369
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2197361
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2197356
# Before speed filtering:  2197356
# Speeding only violation has records:  895256
# # of traffic stops after preprocessing step 1(add county type):  895256
# Including only an economic region:  Capital
# # of traffic stops after preprocessing in year  2017 :  38687
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.672945
#          Iterations 4
# ***********************************
# 2006
# Central Texas
# # of all traffic stops in year  2006 :  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2673511
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2673511
# Before speed filtering:  2673511
# Speeding only violation has records:  1235103
# # of traffic stops after preprocessing step 1(add county type):  1235103
# Including only an economic region:  Central Texas
# # of traffic stops after preprocessing in year  2006 :  92807
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.680906
#          Iterations 4
# ***********************************
# 2007
# Central Texas
# # of all traffic stops in year  2007 :  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2405744
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2405744
# Before speed filtering:  2405744
# Speeding only violation has records:  1110868
# # of traffic stops after preprocessing step 1(add county type):  1110868
# Including only an economic region:  Central Texas
# # of traffic stops after preprocessing in year  2007 :  83496
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.681474
#          Iterations 4
# ***********************************
# 2008
# Central Texas
# # of all traffic stops in year  2008 :  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2434970
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2434970
# Before speed filtering:  2434970
# Speeding only violation has records:  1114925
# # of traffic stops after preprocessing step 1(add county type):  1114925
# Including only an economic region:  Central Texas
# # of traffic stops after preprocessing in year  2008 :  80840
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.674708
#          Iterations 4
# ***********************************
# 2009
# Central Texas
# # of all traffic stops in year  2009 :  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2370986
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2370986
# Before speed filtering:  2370986
# Speeding only violation has records:  1093968
# # of traffic stops after preprocessing step 1(add county type):  1093968
# Including only an economic region:  Central Texas
# # of traffic stops after preprocessing in year  2009 :  74458
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.655128
#          Iterations 5
# ***********************************
# 2010
# Central Texas
# # of all traffic stops in year  2010 :  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2452498
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2452498
# Before speed filtering:  2452498
# Speeding only violation has records:  1085945
# # of traffic stops after preprocessing step 1(add county type):  1085945
# Including only an economic region:  Central Texas
# # of traffic stops after preprocessing in year  2010 :  85649
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.613573
#          Iterations 5
# ***********************************
# 2011
# Central Texas
# # of all traffic stops in year  2011 :  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2511664
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2511664
# Before speed filtering:  2511664
# Speeding only violation has records:  1085781
# # of traffic stops after preprocessing step 1(add county type):  1085781
# Including only an economic region:  Central Texas
# # of traffic stops after preprocessing in year  2011 :  77928
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.595281
#          Iterations 5
# ***********************************
# 2012
# Central Texas
# # of all traffic stops in year  2012 :  2435812
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2368991
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2368990
# Before speed filtering:  2368990
# Speeding only violation has records:  1025815
# # of traffic stops after preprocessing step 1(add county type):  1025815
# Including only an economic region:  Central Texas
# # of traffic stops after preprocessing in year  2012 :  69857
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.585840
#          Iterations 5
# ***********************************
# 2013
# Central Texas
# # of all traffic stops in year  2013 :  2134936
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2076400
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2076396
# Before speed filtering:  2076396
# Speeding only violation has records:  905817
# # of traffic stops after preprocessing step 1(add county type):  905817
# Including only an economic region:  Central Texas
# # of traffic stops after preprocessing in year  2013 :  63833
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.584450
#          Iterations 5
# ***********************************
# 2014
# Central Texas
# # of all traffic stops in year  2014 :  1878488
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1820773
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1820763
# Before speed filtering:  1820763
# Speeding only violation has records:  779279
# # of traffic stops after preprocessing step 1(add county type):  779279
# Including only an economic region:  Central Texas
# # of traffic stops after preprocessing in year  2014 :  52499
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.588861
#          Iterations 5
# ***********************************
# 2015
# Central Texas
# # of all traffic stops in year  2015 :  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1683954
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1683940
# Before speed filtering:  1683940
# Speeding only violation has records:  730702
# # of traffic stops after preprocessing step 1(add county type):  730702
# Including only an economic region:  Central Texas
# # of traffic stops after preprocessing in year  2015 :  44547
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.603237
#          Iterations 5
# ***********************************
# 2016
# Central Texas
# # of all traffic stops in year  2016 :  1832207
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1832089
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1832072
# Before speed filtering:  1832072
# Speeding only violation has records:  797329
# # of traffic stops after preprocessing step 1(add county type):  797329
# Including only an economic region:  Central Texas
# # of traffic stops after preprocessing in year  2016 :  50528
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.622292
#          Iterations 5
# ***********************************
# 2017
# Central Texas
# # of all traffic stops in year  2017 :  2197382
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2197369
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2197369
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2197361
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2197356
# Before speed filtering:  2197356
# Speeding only violation has records:  895256
# # of traffic stops after preprocessing step 1(add county type):  895256
# Including only an economic region:  Central Texas
# # of traffic stops after preprocessing in year  2017 :  53416
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.595982
#          Iterations 6
# ***********************************
# 2006
# Gulf Coast
# # of all traffic stops in year  2006 :  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2673511
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2673511
# Before speed filtering:  2673511
# Speeding only violation has records:  1235103
# # of traffic stops after preprocessing step 1(add county type):  1235103
# Including only an economic region:  Gulf Coast
# # of traffic stops after preprocessing in year  2006 :  114368
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.661886
#          Iterations 5
# ***********************************
# 2007
# Gulf Coast
# # of all traffic stops in year  2007 :  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2405744
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2405744
# Before speed filtering:  2405744
# Speeding only violation has records:  1110868
# # of traffic stops after preprocessing step 1(add county type):  1110868
# Including only an economic region:  Gulf Coast
# # of traffic stops after preprocessing in year  2007 :  116201
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.657863
#          Iterations 5
# ***********************************
# 2008
# Gulf Coast
# # of all traffic stops in year  2008 :  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2434970
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2434970
# Before speed filtering:  2434970
# Speeding only violation has records:  1114925
# # of traffic stops after preprocessing step 1(add county type):  1114925
# Including only an economic region:  Gulf Coast
# # of traffic stops after preprocessing in year  2008 :  108979
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.646748
#          Iterations 5
# ***********************************
# 2009
# Gulf Coast
# # of all traffic stops in year  2009 :  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2370986
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2370986
# Before speed filtering:  2370986
# Speeding only violation has records:  1093968
# # of traffic stops after preprocessing step 1(add county type):  1093968
# Including only an economic region:  Gulf Coast
# # of traffic stops after preprocessing in year  2009 :  117189
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.625131
#          Iterations 5
# ***********************************
# 2010
# Gulf Coast
# # of all traffic stops in year  2010 :  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2452498
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2452498
# Before speed filtering:  2452498
# Speeding only violation has records:  1085945
# # of traffic stops after preprocessing step 1(add county type):  1085945
# Including only an economic region:  Gulf Coast
# # of traffic stops after preprocessing in year  2010 :  118654
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.587601
#          Iterations 5
# ***********************************
# 2011
# Gulf Coast
# # of all traffic stops in year  2011 :  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2511664
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2511664
# Before speed filtering:  2511664
# Speeding only violation has records:  1085781
# # of traffic stops after preprocessing step 1(add county type):  1085781
# Including only an economic region:  Gulf Coast
# # of traffic stops after preprocessing in year  2011 :  127508
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.599534
#          Iterations 5
# ***********************************
# 2012
# Gulf Coast
# # of all traffic stops in year  2012 :  2435812
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2368991
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2368990
# Before speed filtering:  2368990
# Speeding only violation has records:  1025815
# # of traffic stops after preprocessing step 1(add county type):  1025815
# Including only an economic region:  Gulf Coast
# # of traffic stops after preprocessing in year  2012 :  115386
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.608141
#          Iterations 5
# ***********************************
# 2013
# Gulf Coast
# # of all traffic stops in year  2013 :  2134936
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2076400
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2076396
# Before speed filtering:  2076396
# Speeding only violation has records:  905817
# # of traffic stops after preprocessing step 1(add county type):  905817
# Including only an economic region:  Gulf Coast
# # of traffic stops after preprocessing in year  2013 :  102886
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.631672
#          Iterations 5
# ***********************************
# 2014
# Gulf Coast
# # of all traffic stops in year  2014 :  1878488
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1820773
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1820763
# Before speed filtering:  1820763
# Speeding only violation has records:  779279
# # of traffic stops after preprocessing step 1(add county type):  779279
# Including only an economic region:  Gulf Coast
# # of traffic stops after preprocessing in year  2014 :  86821
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.664335
#          Iterations 5
# ***********************************
# 2015
# Gulf Coast
# # of all traffic stops in year  2015 :  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1683954
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1683940
# Before speed filtering:  1683940
# Speeding only violation has records:  730702
# # of traffic stops after preprocessing step 1(add county type):  730702
# Including only an economic region:  Gulf Coast
# # of traffic stops after preprocessing in year  2015 :  81292
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.660727
#          Iterations 5
# ***********************************
# ...
#        'subject_race_hispanic', 'subject_sex_female', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.586328
#          Iterations 5
# ***********************************
# 2015
# UPPER RIO GRANDE
# # of all traffic stops in year  2015 :  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1683954
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1683940
# Before speed filtering:  1683940
# Speeding only violation has records:  730702
# # of traffic stops after preprocessing step 1(add county type):  730702
# Including only an economic region:  UPPER RIO GRANDE
# # of traffic stops after preprocessing in year  2015 :  28252
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.549655
#          Iterations 5
# ***********************************
# 2016
# UPPER RIO GRANDE
# # of all traffic stops in year  2016 :  1832207
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1832089
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1832072
# Before speed filtering:  1832072
# Speeding only violation has records:  797329
# # of traffic stops after preprocessing step 1(add county type):  797329
# Including only an economic region:  UPPER RIO GRANDE
# # of traffic stops after preprocessing in year  2016 :  37157
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.519192
#          Iterations 5
# ***********************************
# 2017
# UPPER RIO GRANDE
# # of all traffic stops in year  2017 :  2197382
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2197369
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2197369
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2197361
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2197356
# Before speed filtering:  2197356
# Speeding only violation has records:  895256
# # of traffic stops after preprocessing step 1(add county type):  895256
# Including only an economic region:  UPPER RIO GRANDE
# # of traffic stops after preprocessing in year  2017 :  37641
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.510705
#          Iterations 5
# ***********************************
# 2006
# West Texas
# # of all traffic stops in year  2006 :  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2673511
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2673511
# Before speed filtering:  2673511
# Speeding only violation has records:  1235103
# # of traffic stops after preprocessing step 1(add county type):  1235103
# Including only an economic region:  West Texas
# # of traffic stops after preprocessing in year  2006 :  93124
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.646617
#          Iterations 5
# ***********************************
# 2007
# West Texas
# # of all traffic stops in year  2007 :  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2405744
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2405744
# Before speed filtering:  2405744
# Speeding only violation has records:  1110868
# # of traffic stops after preprocessing step 1(add county type):  1110868
# Including only an economic region:  West Texas
# # of traffic stops after preprocessing in year  2007 :  79460
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.648190
#          Iterations 5
# ***********************************
# 2008
# West Texas
# # of all traffic stops in year  2008 :  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2434970
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2434970
# Before speed filtering:  2434970
# Speeding only violation has records:  1114925
# # of traffic stops after preprocessing step 1(add county type):  1114925
# Including only an economic region:  West Texas
# # of traffic stops after preprocessing in year  2008 :  86870
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.582351
#          Iterations 5
# ***********************************
# 2009
# West Texas
# # of all traffic stops in year  2009 :  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2370986
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2370986
# Before speed filtering:  2370986
# Speeding only violation has records:  1093968
# # of traffic stops after preprocessing step 1(add county type):  1093968
# Including only an economic region:  West Texas
# # of traffic stops after preprocessing in year  2009 :  68120
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.585944
#          Iterations 5
# ***********************************
# 2010
# West Texas
# # of all traffic stops in year  2010 :  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2452498
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2452498
# Before speed filtering:  2452498
# Speeding only violation has records:  1085945
# # of traffic stops after preprocessing step 1(add county type):  1085945
# Including only an economic region:  West Texas
# # of traffic stops after preprocessing in year  2010 :  62137
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.562405
#          Iterations 5
# ***********************************
# 2011
# West Texas
# # of all traffic stops in year  2011 :  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2511664
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2511664
# Before speed filtering:  2511664
# Speeding only violation has records:  1085781
# # of traffic stops after preprocessing step 1(add county type):  1085781
# Including only an economic region:  West Texas
# # of traffic stops after preprocessing in year  2011 :  62378
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.575650
#          Iterations 5
# ***********************************
# 2012
# West Texas
# # of all traffic stops in year  2012 :  2435812
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2368991
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2368990
# Before speed filtering:  2368990
# Speeding only violation has records:  1025815
# # of traffic stops after preprocessing step 1(add county type):  1025815
# Including only an economic region:  West Texas
# # of traffic stops after preprocessing in year  2012 :  54849
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.671119
#          Iterations 4
# ***********************************
# 2013
# West Texas
# # of all traffic stops in year  2013 :  2134936
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2076400
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2076396
# Before speed filtering:  2076396
# Speeding only violation has records:  905817
# # of traffic stops after preprocessing step 1(add county type):  905817
# Including only an economic region:  West Texas
# # of traffic stops after preprocessing in year  2013 :  40155
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.679316
#          Iterations 4
# ***********************************
# 2014
# West Texas
# # of all traffic stops in year  2014 :  1878488
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1820773
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1820763
# Before speed filtering:  1820763
# Speeding only violation has records:  779279
# # of traffic stops after preprocessing step 1(add county type):  779279
# Including only an economic region:  West Texas
# # of traffic stops after preprocessing in year  2014 :  38391
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.666380
#          Iterations 4
# ***********************************
# 2015
# West Texas
# # of all traffic stops in year  2015 :  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1683954
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1683940
# Before speed filtering:  1683940
# Speeding only violation has records:  730702
# # of traffic stops after preprocessing step 1(add county type):  730702
# Including only an economic region:  West Texas
# # of traffic stops after preprocessing in year  2015 :  47369
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.644360
#          Iterations 5
# ***********************************
# 2016
# West Texas
# # of all traffic stops in year  2016 :  1832207
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1832089
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1832072
# Before speed filtering:  1832072
# Speeding only violation has records:  797329
# # of traffic stops after preprocessing step 1(add county type):  797329
# Including only an economic region:  West Texas
# # of traffic stops after preprocessing in year  2016 :  54337
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.634684
#          Iterations 5
# ***********************************
# 2017
# West Texas
# # of all traffic stops in year  2017 :  2197382
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2197369
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2197369
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2197361
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2197356
# Before speed filtering:  2197356
# Speeding only violation has records:  895256
# # of traffic stops after preprocessing step 1(add county type):  895256
# Including only an economic region:  West Texas
# # of traffic stops after preprocessing in year  2017 :  53705
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.658741
#          Iterations 5

# %% [markdown]
# ### Speeding-only, Search

# %%
year_start = 2006
year_end = 2016

folder_path ='/content/drive/MyDrive/traffic_stop/region_outputs/'
#generate_outputs(folder_path = folder_path, with_vio = False, violation_types = None)
for region in region_lst:
  asianpacific = []
  black = []
  hispanic = []

  asianpacific_low = []
  black_low = []
  hispanic_low = []

  asianpacific_high = []
  black_high = []
  hispanic_high = []
  generate_outputs(folder_path=folder_path, analysis_type='search', violation_types=None, border_counties=None, county_type=None, speeding_only=True, county_region=region)
# Out:
# ***********************************
# 2006
# Alamo
# # of all traffic stops in year  2006 :  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2673511
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2673511
# Before speed filtering:  2673511
# Speeding only violation has records:  1235103
# # of traffic stops after preprocessing step 1(add county type):  1235103
# Including only an economic region:  Alamo
# # of traffic stops after preprocessing in year  2006 :  98279
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.055392
#          Iterations 10
# ***********************************
# 2007
# Alamo
# # of all traffic stops in year  2007 :  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2405744
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2405744
# Before speed filtering:  2405744
# Speeding only violation has records:  1110868
# # of traffic stops after preprocessing step 1(add county type):  1110868
# Including only an economic region:  Alamo
# # of traffic stops after preprocessing in year  2007 :  83176
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.065491
#          Iterations 9
# ***********************************
# 2008
# Alamo
# # of all traffic stops in year  2008 :  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2434970
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2434970
# Before speed filtering:  2434970
# Speeding only violation has records:  1114925
# # of traffic stops after preprocessing step 1(add county type):  1114925
# Including only an economic region:  Alamo
# # of traffic stops after preprocessing in year  2008 :  79391
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.047976
#          Iterations 10
# ***********************************
# 2009
# Alamo
# # of all traffic stops in year  2009 :  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2370986
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2370986
# Before speed filtering:  2370986
# Speeding only violation has records:  1093968
# # of traffic stops after preprocessing step 1(add county type):  1093968
# Including only an economic region:  Alamo
# # of traffic stops after preprocessing in year  2009 :  84385
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.032870
#          Iterations 10
# ***********************************
# 2010
# Alamo
# # of all traffic stops in year  2010 :  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2452498
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2452498
# Before speed filtering:  2452498
# Speeding only violation has records:  1085945
# # of traffic stops after preprocessing step 1(add county type):  1085945
# Including only an economic region:  Alamo
# # of traffic stops after preprocessing in year  2010 :  86234
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.036636
#          Iterations 10
# ***********************************
# 2011
# Alamo
# # of all traffic stops in year  2011 :  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2511664
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2511664
# Before speed filtering:  2511664
# Speeding only violation has records:  1085781
# # of traffic stops after preprocessing step 1(add county type):  1085781
# Including only an economic region:  Alamo
# # of traffic stops after preprocessing in year  2011 :  89143
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.030334
#          Iterations 11
# ***********************************
# 2012
# Alamo
# # of all traffic stops in year  2012 :  2435812
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2368991
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2368990
# Before speed filtering:  2368990
# Speeding only violation has records:  1025815
# # of traffic stops after preprocessing step 1(add county type):  1025815
# Including only an economic region:  Alamo
# # of traffic stops after preprocessing in year  2012 :  84416
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.022513
#          Iterations 10
# ***********************************
# 2013
# Alamo
# # of all traffic stops in year  2013 :  2134936
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2076400
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2076396
# Before speed filtering:  2076396
# Speeding only violation has records:  905817
# # of traffic stops after preprocessing step 1(add county type):  905817
# Including only an economic region:  Alamo
# # of traffic stops after preprocessing in year  2013 :  75160
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.018634
#          Iterations 10
# ***********************************
# 2014
# Alamo
# # of all traffic stops in year  2014 :  1878488
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1820773
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1820763
# Before speed filtering:  1820763
# Speeding only violation has records:  779279
# # of traffic stops after preprocessing step 1(add county type):  779279
# Including only an economic region:  Alamo
# # of traffic stops after preprocessing in year  2014 :  64863
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.019308
#          Iterations 10
# ***********************************
# 2015
# Alamo
# # of all traffic stops in year  2015 :  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1683954
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1683940
# Before speed filtering:  1683940
# Speeding only violation has records:  730702
# # of traffic stops after preprocessing step 1(add county type):  730702
# Including only an economic region:  Alamo
# # of traffic stops after preprocessing in year  2015 :  63062
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.020428
#          Iterations 10
# ***********************************
# 2016
# Alamo
# # of all traffic stops in year  2016 :  1832207
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1832089
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1832072
# Before speed filtering:  1832072
# Speeding only violation has records:  797329
# # of traffic stops after preprocessing step 1(add county type):  797329
# Including only an economic region:  Alamo
# # of traffic stops after preprocessing in year  2016 :  56845
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.022079
#          Iterations: 35
# ***********************************
# 2006
# Capital
# # of all traffic stops in year  2006 :  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2673511
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2673511
# Before speed filtering:  2673511
# Speeding only violation has records:  1235103
# # of traffic stops after preprocessing step 1(add county type):  1235103
# Including only an economic region:  Capital
# # of traffic stops after preprocessing in year  2006 :  68085
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.031365
#          Iterations 10
# ***********************************
# 2007
# Capital
# # of all traffic stops in year  2007 :  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2405744
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2405744
# Before speed filtering:  2405744
# Speeding only violation has records:  1110868
# # of traffic stops after preprocessing step 1(add county type):  1110868
# Including only an economic region:  Capital
# # of traffic stops after preprocessing in year  2007 :  62128
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.040364
#          Iterations 10
# ***********************************
# 2008
# Capital
# # of all traffic stops in year  2008 :  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2434970
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2434970
# Before speed filtering:  2434970
# Speeding only violation has records:  1114925
# # of traffic stops after preprocessing step 1(add county type):  1114925
# Including only an economic region:  Capital
# # of traffic stops after preprocessing in year  2008 :  60485
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.036102
#          Iterations 9
# ***********************************
# 2009
# Capital
# # of all traffic stops in year  2009 :  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2370986
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2370986
# Before speed filtering:  2370986
# Speeding only violation has records:  1093968
# # of traffic stops after preprocessing step 1(add county type):  1093968
# Including only an economic region:  Capital
# # of traffic stops after preprocessing in year  2009 :  61333
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.028340
#          Iterations 10
# ***********************************
# 2010
# Capital
# # of all traffic stops in year  2010 :  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2452498
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2452498
# Before speed filtering:  2452498
# Speeding only violation has records:  1085945
# # of traffic stops after preprocessing step 1(add county type):  1085945
# Including only an economic region:  Capital
# # of traffic stops after preprocessing in year  2010 :  59344
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.027678
#          Iterations 10
# ***********************************
# 2011
# Capital
# # of all traffic stops in year  2011 :  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2511664
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2511664
# Before speed filtering:  2511664
# Speeding only violation has records:  1085781
# # of traffic stops after preprocessing step 1(add county type):  1085781
# Including only an economic region:  Capital
# # of traffic stops after preprocessing in year  2011 :  62098
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.027453
#          Iterations 10
# ***********************************
# 2012
# Capital
# # of all traffic stops in year  2012 :  2435812
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2368991
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2368990
# Before speed filtering:  2368990
# Speeding only violation has records:  1025815
# # of traffic stops after preprocessing step 1(add county type):  1025815
# Including only an economic region:  Capital
# # of traffic stops after preprocessing in year  2012 :  56076
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.024578
#          Iterations 10
# ***********************************
# 2013
# Capital
# # of all traffic stops in year  2013 :  2134936
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2076400
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2076396
# Before speed filtering:  2076396
# Speeding only violation has records:  905817
# # of traffic stops after preprocessing step 1(add county type):  905817
# Including only an economic region:  Capital
# # of traffic stops after preprocessing in year  2013 :  57642
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.018575
#          Iterations 10
# ***********************************
# 2014
# Capital
# # of all traffic stops in year  2014 :  1878488
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1820773
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1820763
# Before speed filtering:  1820763
# Speeding only violation has records:  779279
# # of traffic stops after preprocessing step 1(add county type):  779279
# Including only an economic region:  Capital
# # of traffic stops after preprocessing in year  2014 :  47339
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.016407
#          Iterations 10
# ***********************************
# 2015
# Capital
# # of all traffic stops in year  2015 :  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1683954
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1683940
# Before speed filtering:  1683940
# Speeding only violation has records:  730702
# # of traffic stops after preprocessing step 1(add county type):  730702
# Including only an economic region:  Capital
# # of traffic stops after preprocessing in year  2015 :  34596
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.018150
#          Iterations 10
# ***********************************
# 2016
# Capital
# # of all traffic stops in year  2016 :  1832207
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1832089
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1832072
# Before speed filtering:  1832072
# Speeding only violation has records:  797329
# # of traffic stops after preprocessing step 1(add county type):  797329
# Including only an economic region:  Capital
# # of traffic stops after preprocessing in year  2016 :  31699
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female', 'county_type_Non core'],
#       dtype='object')
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.026315
#          Iterations: 35
# ***********************************
# 2006
# Central Texas
# # of all traffic stops in year  2006 :  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2673511
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2673511
# Before speed filtering:  2673511
# Speeding only violation has records:  1235103
# # of traffic stops after preprocessing step 1(add county type):  1235103
# Including only an economic region:  Central Texas
# # of traffic stops after preprocessing in year  2006 :  92807
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.037998
#          Iterations 10
# ***********************************
# 2007
# Central Texas
# # of all traffic stops in year  2007 :  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2405744
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2405744
# Before speed filtering:  2405744
# Speeding only violation has records:  1110868
# # of traffic stops after preprocessing step 1(add county type):  1110868
# Including only an economic region:  Central Texas
# # of traffic stops after preprocessing in year  2007 :  83496
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.037534
#          Iterations 10
# ***********************************
# 2008
# Central Texas
# # of all traffic stops in year  2008 :  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2434970
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2434970
# Before speed filtering:  2434970
# Speeding only violation has records:  1114925
# # of traffic stops after preprocessing step 1(add county type):  1114925
# Including only an economic region:  Central Texas
# # of traffic stops after preprocessing in year  2008 :  80840
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.039304
#          Iterations 10
# ***********************************
# 2009
# Central Texas
# # of all traffic stops in year  2009 :  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2370986
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2370986
# Before speed filtering:  2370986
# Speeding only violation has records:  1093968
# # of traffic stops after preprocessing step 1(add county type):  1093968
# Including only an economic region:  Central Texas
# # of traffic stops after preprocessing in year  2009 :  74458
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.034442
#          Iterations 10
# ***********************************
# 2010
# Central Texas
# # of all traffic stops in year  2010 :  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2452498
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2452498
# Before speed filtering:  2452498
# Speeding only violation has records:  1085945
# # of traffic stops after preprocessing step 1(add county type):  1085945
# Including only an economic region:  Central Texas
# # of traffic stops after preprocessing in year  2010 :  85649
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.035712
#          Iterations 10
# ***********************************
# 2011
# Central Texas
# # of all traffic stops in year  2011 :  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2511664
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2511664
# Before speed filtering:  2511664
# Speeding only violation has records:  1085781
# # of traffic stops after preprocessing step 1(add county type):  1085781
# Including only an economic region:  Central Texas
# # of traffic stops after preprocessing in year  2011 :  77928
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.037904
#          Iterations 10
# ***********************************
# 2012
# Central Texas
# # of all traffic stops in year  2012 :  2435812
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2368991
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2368990
# Before speed filtering:  2368990
# Speeding only violation has records:  1025815
# # of traffic stops after preprocessing step 1(add county type):  1025815
# Including only an economic region:  Central Texas
# # of traffic stops after preprocessing in year  2012 :  69857
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.034599
#          Iterations 10
# ***********************************
# 2013
# Central Texas
# # of all traffic stops in year  2013 :  2134936
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2076400
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2076396
# Before speed filtering:  2076396
# Speeding only violation has records:  905817
# # of traffic stops after preprocessing step 1(add county type):  905817
# Including only an economic region:  Central Texas
# # of traffic stops after preprocessing in year  2013 :  63833
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.027564
#          Iterations 10
# ***********************************
# 2014
# Central Texas
# # of all traffic stops in year  2014 :  1878488
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1820773
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1820763
# Before speed filtering:  1820763
# Speeding only violation has records:  779279
# # of traffic stops after preprocessing step 1(add county type):  779279
# Including only an economic region:  Central Texas
# # of traffic stops after preprocessing in year  2014 :  52499
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.032447
#          Iterations 10
# ***********************************
# 2015
# Central Texas
# # of all traffic stops in year  2015 :  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1683954
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1683940
# Before speed filtering:  1683940
# Speeding only violation has records:  730702
# # of traffic stops after preprocessing step 1(add county type):  730702
# Including only an economic region:  Central Texas
# # of traffic stops after preprocessing in year  2015 :  44547
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.027621
#          Iterations 10
# ***********************************
# 2016
# Central Texas
# # of all traffic stops in year  2016 :  1832207
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1832089
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1832072
# Before speed filtering:  1832072
# Speeding only violation has records:  797329
# # of traffic stops after preprocessing step 1(add county type):  797329
# Including only an economic region:  Central Texas
# # of traffic stops after preprocessing in year  2016 :  50528
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.038302
#          Iterations 11
# ***********************************
# 2006
# Gulf Coast
# # of all traffic stops in year  2006 :  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2673511
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2673511
# Before speed filtering:  2673511
# Speeding only violation has records:  1235103
# # of traffic stops after preprocessing step 1(add county type):  1235103
# Including only an economic region:  Gulf Coast
# # of traffic stops after preprocessing in year  2006 :  114368
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.054162
#          Iterations 10
# ***********************************
# 2007
# Gulf Coast
# # of all traffic stops in year  2007 :  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2405744
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2405744
# Before speed filtering:  2405744
# Speeding only violation has records:  1110868
# # of traffic stops after preprocessing step 1(add county type):  1110868
# Including only an economic region:  Gulf Coast
# # of traffic stops after preprocessing in year  2007 :  116201
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.048245
#          Iterations 10
# ***********************************
# 2008
# Gulf Coast
# # of all traffic stops in year  2008 :  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2434970
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2434970
# Before speed filtering:  2434970
# Speeding only violation has records:  1114925
# # of traffic stops after preprocessing step 1(add county type):  1114925
# Including only an economic region:  Gulf Coast
# # of traffic stops after preprocessing in year  2008 :  108979
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.048042
#          Iterations 9
# ***********************************
# 2009
# Gulf Coast
# # of all traffic stops in year  2009 :  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2370986
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2370986
# Before speed filtering:  2370986
# Speeding only violation has records:  1093968
# # of traffic stops after preprocessing step 1(add county type):  1093968
# Including only an economic region:  Gulf Coast
# # of traffic stops after preprocessing in year  2009 :  117189
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.042569
#          Iterations 10
# ***********************************
# 2010
# Gulf Coast
# # of all traffic stops in year  2010 :  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2452498
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2452498
# Before speed filtering:  2452498
# Speeding only violation has records:  1085945
# # of traffic stops after preprocessing step 1(add county type):  1085945
# Including only an economic region:  Gulf Coast
# # of traffic stops after preprocessing in year  2010 :  118654
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.039398
#          Iterations 10
# ***********************************
# 2011
# Gulf Coast
# # of all traffic stops in year  2011 :  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2511664
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2511664
# Before speed filtering:  2511664
# Speeding only violation has records:  1085781
# # of traffic stops after preprocessing step 1(add county type):  1085781
# Including only an economic region:  Gulf Coast
# # of traffic stops after preprocessing in year  2011 :  127508
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.039353
#          Iterations 10
# ***********************************
# 2012
# Gulf Coast
# # of all traffic stops in year  2012 :  2435812
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2368991
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2368990
# Before speed filtering:  2368990
# Speeding only violation has records:  1025815
# # of traffic stops after preprocessing step 1(add county type):  1025815
# Including only an economic region:  Gulf Coast
# # of traffic stops after preprocessing in year  2012 :  115386
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.036268
#          Iterations 10
# ***********************************
# 2013
# Gulf Coast
# # of all traffic stops in year  2013 :  2134936
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2076400
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2076396
# Before speed filtering:  2076396
# Speeding only violation has records:  905817
# # of traffic stops after preprocessing step 1(add county type):  905817
# Including only an economic region:  Gulf Coast
# # of traffic stops after preprocessing in year  2013 :  102886
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.030785
#          Iterations 10
# ***********************************
# 2014
# Gulf Coast
# # of all traffic stops in year  2014 :  1878488
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1820773
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1820763
# Before speed filtering:  1820763
# Speeding only violation has records:  779279
# # of traffic stops after preprocessing step 1(add county type):  779279
# Including only an economic region:  Gulf Coast
# # of traffic stops after preprocessing in year  2014 :  86821
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.027327
#          Iterations 11
# ***********************************
# 2015
# Gulf Coast
# # of all traffic stops in year  2015 :  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1683954
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1683940
# Before speed filtering:  1683940
# Speeding only violation has records:  730702
# # of traffic stops after preprocessing step 1(add county type):  730702
# Including only an economic region:  Gulf Coast
# # of traffic stops after preprocessing in year  2015 :  81292
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.023734
#          Iterations 11
# ***********************************
# 2016
# Gulf Coast
# # of all traffic stops in year  2016 :  1832207
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1832089
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1832072
# Before speed filtering:  1832072
# Speeding only violation has records:  797329
# # of traffic stops after preprocessing step 1(add county type):  797329
# Including only an economic region:  Gulf Coast
# # of traffic stops after preprocessing in year  2016 :  82344
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.022231
#          Iterations 12
# ***********************************
# 2006
# High Plains
# # of all traffic stops in year  2006 :  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2673511
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2673511
# Before speed filtering:  2673511
# Speeding only violation has records:  1235103
# # of traffic stops after preprocessing step 1(add county type):  1235103
# Including only an economic region:  High Plains
# # of traffic stops after preprocessing in year  2006 :  116377
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.070454
#          Iterations 9
# ***********************************
# 2007
# High Plains
# # of all traffic stops in year  2007 :  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2405744
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2405744
# Before speed filtering:  2405744
# Speeding only violation has records:  1110868
# # of traffic stops after preprocessing step 1(add county type):  1110868
# Including only an economic region:  High Plains
# # of traffic stops after preprocessing in year  2007 :  100809
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# ...
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.025109
#          Iterations 10
# ***********************************
# 2013
# UPPER RIO GRANDE
# # of all traffic stops in year  2013 :  2134936
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2076400
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2076396
# Before speed filtering:  2076396
# Speeding only violation has records:  905817
# # of traffic stops after preprocessing step 1(add county type):  905817
# Including only an economic region:  UPPER RIO GRANDE
# # of traffic stops after preprocessing in year  2013 :  21187
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.031439
#          Iterations 10
# ***********************************
# 2014
# UPPER RIO GRANDE
# # of all traffic stops in year  2014 :  1878488
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1820773
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1820763
# Before speed filtering:  1820763
# Speeding only violation has records:  779279
# # of traffic stops after preprocessing step 1(add county type):  779279
# Including only an economic region:  UPPER RIO GRANDE
# # of traffic stops after preprocessing in year  2014 :  19176
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female', 'county_type_Non core'],
#       dtype='object')
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.027920
#          Iterations: 35
# ***********************************
# 2015
# UPPER RIO GRANDE
# # of all traffic stops in year  2015 :  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1683954
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1683940
# Before speed filtering:  1683940
# Speeding only violation has records:  730702
# # of traffic stops after preprocessing step 1(add county type):  730702
# Including only an economic region:  UPPER RIO GRANDE
# # of traffic stops after preprocessing in year  2015 :  28252
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.039600
#          Iterations 10
# ***********************************
# 2016
# UPPER RIO GRANDE
# # of all traffic stops in year  2016 :  1832207
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1832089
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1832072
# Before speed filtering:  1832072
# Speeding only violation has records:  797329
# # of traffic stops after preprocessing step 1(add county type):  797329
# Including only an economic region:  UPPER RIO GRANDE
# # of traffic stops after preprocessing in year  2016 :  37157
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.031653
#          Iterations 10
# ***********************************
# 2006
# West Texas
# # of all traffic stops in year  2006 :  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2673511
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2673511
# Before speed filtering:  2673511
# Speeding only violation has records:  1235103
# # of traffic stops after preprocessing step 1(add county type):  1235103
# Including only an economic region:  West Texas
# # of traffic stops after preprocessing in year  2006 :  93124
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.043461
#          Iterations 10
# ***********************************
# 2007
# West Texas
# # of all traffic stops in year  2007 :  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2405744
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2405744
# Before speed filtering:  2405744
# Speeding only violation has records:  1110868
# # of traffic stops after preprocessing step 1(add county type):  1110868
# Including only an economic region:  West Texas
# # of traffic stops after preprocessing in year  2007 :  79460
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.033334
#          Iterations 10
# ***********************************
# 2008
# West Texas
# # of all traffic stops in year  2008 :  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2434970
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2434970
# Before speed filtering:  2434970
# Speeding only violation has records:  1114925
# # of traffic stops after preprocessing step 1(add county type):  1114925
# Including only an economic region:  West Texas
# # of traffic stops after preprocessing in year  2008 :  86870
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.028287
#          Iterations 10
# ***********************************
# 2009
# West Texas
# # of all traffic stops in year  2009 :  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2370986
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2370986
# Before speed filtering:  2370986
# Speeding only violation has records:  1093968
# # of traffic stops after preprocessing step 1(add county type):  1093968
# Including only an economic region:  West Texas
# # of traffic stops after preprocessing in year  2009 :  68120
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.028942
#          Iterations 10
# ***********************************
# 2010
# West Texas
# # of all traffic stops in year  2010 :  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2452498
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2452498
# Before speed filtering:  2452498
# Speeding only violation has records:  1085945
# # of traffic stops after preprocessing step 1(add county type):  1085945
# Including only an economic region:  West Texas
# # of traffic stops after preprocessing in year  2010 :  62137
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.038655
#          Iterations 10
# ***********************************
# 2011
# West Texas
# # of all traffic stops in year  2011 :  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2511664
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2511664
# Before speed filtering:  2511664
# Speeding only violation has records:  1085781
# # of traffic stops after preprocessing step 1(add county type):  1085781
# Including only an economic region:  West Texas
# # of traffic stops after preprocessing in year  2011 :  62378
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.033566
#          Iterations 10
# ***********************************
# 2012
# West Texas
# # of all traffic stops in year  2012 :  2435812
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2368991
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2368990
# Before speed filtering:  2368990
# Speeding only violation has records:  1025815
# # of traffic stops after preprocessing step 1(add county type):  1025815
# Including only an economic region:  West Texas
# # of traffic stops after preprocessing in year  2012 :  54849
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.025515
#          Iterations 32
# ***********************************
# 2013
# West Texas
# # of all traffic stops in year  2013 :  2134936
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2076400
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2076396
# Before speed filtering:  2076396
# Speeding only violation has records:  905817
# # of traffic stops after preprocessing step 1(add county type):  905817
# Including only an economic region:  West Texas
# # of traffic stops after preprocessing in year  2013 :  40155
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.027347
#          Iterations 10
# ***********************************
# 2014
# West Texas
# # of all traffic stops in year  2014 :  1878488
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1820773
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1820763
# Before speed filtering:  1820763
# Speeding only violation has records:  779279
# # of traffic stops after preprocessing step 1(add county type):  779279
# Including only an economic region:  West Texas
# # of traffic stops after preprocessing in year  2014 :  38391
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.018458
#          Iterations: 35
# ***********************************
# 2015
# West Texas
# # of all traffic stops in year  2015 :  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1683954
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1683940
# Before speed filtering:  1683940
# Speeding only violation has records:  730702
# # of traffic stops after preprocessing step 1(add county type):  730702
# Including only an economic region:  West Texas
# # of traffic stops after preprocessing in year  2015 :  47369
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.017026
#          Iterations: 35
# ***********************************
# 2016
# West Texas
# # of all traffic stops in year  2016 :  1832207
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1832089
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1832072
# Before speed filtering:  1832072
# Speeding only violation has records:  797329
# # of traffic stops after preprocessing step 1(add county type):  797329
# Including only an economic region:  West Texas
# # of traffic stops after preprocessing in year  2016 :  54337
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.020413
#          Iterations 10

# %% [markdown]
# ### Speeding-only, Contraband

# %%
year_start = 2006
year_end = 2016

folder_path ='/content/drive/MyDrive/traffic_stop/region_outputs/'
#generate_outputs(folder_path = folder_path, with_vio = False, violation_types = None)
for region in region_lst:
  asianpacific = []
  black = []
  hispanic = []

  asianpacific_low = []
  black_low = []
  hispanic_low = []

  asianpacific_high = []
  black_high = []
  hispanic_high = []
  generate_outputs(folder_path=folder_path, analysis_type='contraband', violation_types=None, border_counties=None, county_type=None, speeding_only=True, county_region=region)
# Out:
# ***********************************
# 2006
# Alamo
# # of all traffic stops in year  2006 :  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2673511
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2673511
# Before speed filtering:  2673511
# Speeding only violation has records:  1235103
# # of traffic stops after preprocessing step 1(add county type):  1235103
# Including only an economic region:  Alamo
# # of traffic stops after preprocessing in year  2006 :  1004
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.180632
#          Iterations 8
# ***********************************
# 2007
# Alamo
# # of all traffic stops in year  2007 :  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2405744
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2405744
# Before speed filtering:  2405744
# Speeding only violation has records:  1110868
# # of traffic stops after preprocessing step 1(add county type):  1110868
# Including only an economic region:  Alamo
# # of traffic stops after preprocessing in year  2007 :  1042
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.190002
#          Iterations: 35
# ***********************************
# 2008
# Alamo
# # of all traffic stops in year  2008 :  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2434970
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2434970
# Before speed filtering:  2434970
# Speeding only violation has records:  1114925
# # of traffic stops after preprocessing step 1(add county type):  1114925
# Including only an economic region:  Alamo
# # of traffic stops after preprocessing in year  2008 :  684
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.205443
#          Iterations: 35
# ***********************************
# 2009
# Alamo
# # of all traffic stops in year  2009 :  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2370986
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2370986
# Before speed filtering:  2370986
# Speeding only violation has records:  1093968
# # of traffic stops after preprocessing step 1(add county type):  1093968
# Including only an economic region:  Alamo
# # of traffic stops after preprocessing in year  2009 :  465
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.226030
#          Iterations: 35
# ***********************************
# 2010
# Alamo
# # of all traffic stops in year  2010 :  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2452498
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2452498
# Before speed filtering:  2452498
# Speeding only violation has records:  1085945
# # of traffic stops after preprocessing step 1(add county type):  1085945
# Including only an economic region:  Alamo
# # of traffic stops after preprocessing in year  2010 :  535
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.215854
#          Iterations 7
# ***********************************
# 2011
# Alamo
# # of all traffic stops in year  2011 :  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2511664
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2511664
# Before speed filtering:  2511664
# Speeding only violation has records:  1085781
# # of traffic stops after preprocessing step 1(add county type):  1085781
# Including only an economic region:  Alamo
# # of traffic stops after preprocessing in year  2011 :  442
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.274531
#          Iterations: 35
# ***********************************
# 2012
# Alamo
# # of all traffic stops in year  2012 :  2435812
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2368991
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2368990
# Before speed filtering:  2368990
# Speeding only violation has records:  1025815
# # of traffic stops after preprocessing step 1(add county type):  1025815
# Including only an economic region:  Alamo
# # of traffic stops after preprocessing in year  2012 :  293
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.156268
#          Iterations: 35
# ***********************************
# 2013
# Alamo
# # of all traffic stops in year  2013 :  2134936
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2076400
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2076396
# Before speed filtering:  2076396
# Speeding only violation has records:  905817
# # of traffic stops after preprocessing step 1(add county type):  905817
# Including only an economic region:  Alamo
# # of traffic stops after preprocessing in year  2013 :  208
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.207947
#          Iterations 8
# ***********************************
# 2014
# Alamo
# # of all traffic stops in year  2014 :  1878488
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1820773
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1820763
# Before speed filtering:  1820763
# Speeding only violation has records:  779279
# # of traffic stops after preprocessing step 1(add county type):  779279
# Including only an economic region:  Alamo
# # of traffic stops after preprocessing in year  2014 :  185
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.312421
#          Iterations: 35
# ***********************************
# 2015
# Alamo
# # of all traffic stops in year  2015 :  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1683954
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1683940
# Before speed filtering:  1683940
# Speeding only violation has records:  730702
# # of traffic stops after preprocessing step 1(add county type):  730702
# Including only an economic region:  Alamo
# # of traffic stops after preprocessing in year  2015 :  193
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.376929
#          Iterations: 35
# ***********************************
# 2016
# Alamo
# # of all traffic stops in year  2016 :  1832207
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1832089
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1832072
# Before speed filtering:  1832072
# Speeding only violation has records:  797329
# # of traffic stops after preprocessing step 1(add county type):  797329
# Including only an economic region:  Alamo
# # of traffic stops after preprocessing in year  2016 :  190
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female',
#        'county_type_Micropolitan', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.291033
#          Iterations 7
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-38-0bdf4ca305ad> in <cell line: 6>()
#      16   black_high = []
#      17   hispanic_high = []
# ---> 18   generate_outputs(folder_path=folder_path, analysis_type='contraband', violation_types=None, border_counties=None, county_type=None, speeding_only=True, county_region=region)
#
# <ipython-input-25-938f722d01fd> in generate_outputs(folder_path, analysis_type, violation_types, border_counties, county_type, speeding_only, county_region)
#      11
#      12
# ---> 13   res_df = run_year_analysis(analysis_type=analysis_type, rm_na_col=rm_na_col, df_years=df_years, violation_types=violation_types,
#      14                     border_counties=border_counties, county_type=county_type, speeding_only=speeding_only, county_region=county_region)
#      15
#
# <ipython-input-28-9fa5210de329> in run_year_analysis(analysis_type, rm_na_col, df_years, violation_types, border_counties, county_type, speeding_only, county_region)
#      26     X_with_constant = sm.add_constant(X)
#      27     # building the model and fitting the data
# ---> 28     log_reg = sm.Logit(y, X_with_constant).fit()
#      29
#      30     res_df = pd.DataFrame({'variable':list(log_reg.params.index), 'coef':list(log_reg.params.values),
#
# /usr/local/lib/python3.10/dist-packages/statsmodels/discrete/discrete_model.py in fit(self, start_params, method, maxiter, full_output, disp, callback, **kwargs)
#    1981     def fit(self, start_params=None, method='newton', maxiter=35,
#    1982             full_output=1, disp=1, callback=None, **kwargs):
# -> 1983         bnryfit = super().fit(start_params=start_params,
#    1984                               method=method,
#    1985                               maxiter=maxiter,
#
# /usr/local/lib/python3.10/dist-packages/statsmodels/discrete/discrete_model.py in fit(self, start_params, method, maxiter, full_output, disp, callback, **kwargs)
#     228             pass  # TODO: make a function factory to have multiple call-backs
#     229
# --> 230         mlefit = super().fit(start_params=start_params,
#     231                              method=method,
#     232                              maxiter=maxiter,
#
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py in fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     577             Hinv = cov_params_func(self, xopt, retvals)
#     578         elif method == 'newton' and full_output:
# --> 579             Hinv = np.linalg.inv(-retvals['Hessian']) / nobs
#     580         elif not skip_hessian:
#     581             H = -1 * self.hessian(xopt)
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/overrides.py in inv(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/numpy/linalg/linalg.py in inv(a)
#     543     signature = 'D->D' if isComplexType(t) else 'd->d'
#     544     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 545     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     546     return wrap(ainv.astype(result_t, copy=False))
#     547
#
# /usr/local/lib/python3.10/dist-packages/numpy/linalg/linalg.py in _raise_linalgerror_singular(err, flag)
#      86
#      87 def _raise_linalgerror_singular(err, flag):
# ---> 88     raise LinAlgError("Singular matrix")
#      89
#      90 def _raise_linalgerror_nonposdef(err, flag):
#
# LinAlgError: Singular matrix

# %%
region_df['region'].unique()
# Out:
# array(['Alamo', 'Capital', 'Central Texas ', 'Gulf Coast ',
#        'High Plains ', 'Metroplex ', 'Northwest ', 'South Texas ',
#        'Southeast ', ' Upper East ', 'UPPER RIO GRANDE', 'West Texas '],
#       dtype=object)

# %%
asianpacific = []
black = []
hispanic = []

asianpacific_low = []
black_low = []
hispanic_low = []

asianpacific_high = []
black_high = []
hispanic_high = []
generate_outputs(folder_path=folder_path, analysis_type='contraband', violation_types=None, border_counties=None, county_type=None, speeding_only=True, county_region='Capital')
# Out:
# ***********************************
# 2006
# Capital
# # of all traffic stops in year  2006 :  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2693894
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2673511
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2673511
# Before speed filtering:  2673511
# Speeding only violation has records:  1235103
# # of traffic stops after preprocessing step 1(add county type):  1235103
# Including only an economic region:  Capital
# # of traffic stops after preprocessing in year  2006 :  344
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female', 'county_type_Non core'],
#       dtype='object')
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.318744
#          Iterations: 35
# ***********************************
# 2007
# Capital
# # of all traffic stops in year  2007 :  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2427347
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2405744
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2405744
# Before speed filtering:  2405744
# Speeding only violation has records:  1110868
# # of traffic stops after preprocessing step 1(add county type):  1110868
# Including only an economic region:  Capital
# # of traffic stops after preprocessing in year  2007 :  425
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.294693
#          Iterations 7
# ***********************************
# 2008
# Capital
# # of all traffic stops in year  2008 :  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2526783
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2434970
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2434970
# Before speed filtering:  2434970
# Speeding only violation has records:  1114925
# # of traffic stops after preprocessing step 1(add county type):  1114925
# Including only an economic region:  Capital
# # of traffic stops after preprocessing in year  2008 :  358
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.277435
#          Iterations 7
# ***********************************
# 2009
# Capital
# # of all traffic stops in year  2009 :  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2441306
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2370986
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2370986
# Before speed filtering:  2370986
# Speeding only violation has records:  1093968
# # of traffic stops after preprocessing step 1(add county type):  1093968
# Including only an economic region:  Capital
# # of traffic stops after preprocessing in year  2009 :  275
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.287438
#          Iterations 7
# ***********************************
# 2010
# Capital
# # of all traffic stops in year  2010 :  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2525296
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2452498
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2452498
# Before speed filtering:  2452498
# Speeding only violation has records:  1085945
# # of traffic stops after preprocessing step 1(add county type):  1085945
# Including only an economic region:  Capital
# # of traffic stops after preprocessing in year  2010 :  263
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female', 'county_type_Non core'],
#       dtype='object')
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.321546
#          Iterations: 35
# ***********************************
# 2011
# Capital
# # of all traffic stops in year  2011 :  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2588004
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2511664
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2511664
# Before speed filtering:  2511664
# Speeding only violation has records:  1085781
# # of traffic stops after preprocessing step 1(add county type):  1085781
# Including only an economic region:  Capital
# # of traffic stops after preprocessing in year  2011 :  271
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female', 'county_type_Non core'],
#       dtype='object')
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.363891
#          Iterations: 35
# ***********************************
# 2012
# Capital
# # of all traffic stops in year  2012 :  2435812
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2435758
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2368991
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2368990
# Before speed filtering:  2368990
# Speeding only violation has records:  1025815
# # of traffic stops after preprocessing step 1(add county type):  1025815
# Including only an economic region:  Capital
# # of traffic stops after preprocessing in year  2012 :  212
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.310725
#          Iterations 6
# ***********************************
# 2013
# Capital
# # of all traffic stops in year  2013 :  2134936
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  2134890
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  2076400
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  2076396
# Before speed filtering:  2076396
# Speeding only violation has records:  905817
# # of traffic stops after preprocessing step 1(add county type):  905817
# Including only an economic region:  Capital
# # of traffic stops after preprocessing in year  2013 :  157
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.378354
#          Iterations 7
# ***********************************
# 2014
# Capital
# # of all traffic stops in year  2014 :  1878488
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1878487
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1820773
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1820763
# Before speed filtering:  1820763
# Speeding only violation has records:  779279
# # of traffic stops after preprocessing step 1(add county type):  779279
# Including only an economic region:  Capital
# # of traffic stops after preprocessing in year  2014 :  112
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.394546
#          Iterations 6
# ***********************************
# 2015
# Capital
# # of all traffic stops in year  2015 :  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1745385
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1683954
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1683940
# Before speed filtering:  1683940
# Speeding only violation has records:  730702
# # of traffic stops after preprocessing step 1(add county type):  730702
# Including only an economic region:  Capital
# # of traffic stops after preprocessing in year  2015 :  92
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female', 'county_type_Non core'],
#       dtype='object')
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.326694
#          Iterations: 35
# ***********************************
# 2016
# Capital
# # of all traffic stops in year  2016 :  1832207
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ county_name ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ violation ]:  1832108
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_race ]:  1832089
# # of traffic stops after preprocessing step 0 - drop na/unknown in COL [ subject_sex ]:  1832072
# Before speed filtering:  1832072
# Speeding only violation has records:  797329
# # of traffic stops after preprocessing step 1(add county type):  797329
# Including only an economic region:  Capital
# # of traffic stops after preprocessing in year  2016 :  132
# Index(['subject_race_asian/pacific islander', 'subject_race_black',
#        'subject_race_hispanic', 'subject_sex_female', 'county_type_Non core'],
#       dtype='object')
# Optimization terminated successfully.
#          Current function value: 0.436458
#          Iterations 6
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-40-e25b5b350199> in <cell line: 12>()
#      10 black_high = []
#      11 hispanic_high = []
# ---> 12 generate_outputs(folder_path=folder_path, analysis_type='contraband', violation_types=None, border_counties=None, county_type=None, speeding_only=True, county_region='Capital')
#
# <ipython-input-25-938f722d01fd> in generate_outputs(folder_path, analysis_type, violation_types, border_counties, county_type, speeding_only, county_region)
#      11
#      12
# ---> 13   res_df = run_year_analysis(analysis_type=analysis_type, rm_na_col=rm_na_col, df_years=df_years, violation_types=violation_types,
#      14                     border_counties=border_counties, county_type=county_type, speeding_only=speeding_only, county_region=county_region)
#      15
#
# <ipython-input-28-9fa5210de329> in run_year_analysis(analysis_type, rm_na_col, df_years, violation_types, border_counties, county_type, speeding_only, county_region)
#      26     X_with_constant = sm.add_constant(X)
#      27     # building the model and fitting the data
# ---> 28     log_reg = sm.Logit(y, X_with_constant).fit()
#      29
#      30     res_df = pd.DataFrame({'variable':list(log_reg.params.index), 'coef':list(log_reg.params.values),
#
# /usr/local/lib/python3.10/dist-packages/statsmodels/discrete/discrete_model.py in fit(self, start_params, method, maxiter, full_output, disp, callback, **kwargs)
#    1981     def fit(self, start_params=None, method='newton', maxiter=35,
#    1982             full_output=1, disp=1, callback=None, **kwargs):
# -> 1983         bnryfit = super().fit(start_params=start_params,
#    1984                               method=method,
#    1985                               maxiter=maxiter,
#
# /usr/local/lib/python3.10/dist-packages/statsmodels/discrete/discrete_model.py in fit(self, start_params, method, maxiter, full_output, disp, callback, **kwargs)
#     228             pass  # TODO: make a function factory to have multiple call-backs
#     229
# --> 230         mlefit = super().fit(start_params=start_params,
#     231                              method=method,
#     232                              maxiter=maxiter,
#
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py in fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     577             Hinv = cov_params_func(self, xopt, retvals)
#     578         elif method == 'newton' and full_output:
# --> 579             Hinv = np.linalg.inv(-retvals['Hessian']) / nobs
#     580         elif not skip_hessian:
#     581             H = -1 * self.hessian(xopt)
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/overrides.py in inv(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/numpy/linalg/linalg.py in inv(a)
#     543     signature = 'D->D' if isComplexType(t) else 'd->d'
#     544     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 545     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     546     return wrap(ainv.astype(result_t, copy=False))
#     547
#
# /usr/local/lib/python3.10/dist-packages/numpy/linalg/linalg.py in _raise_linalgerror_singular(err, flag)
#      86
#      87 def _raise_linalgerror_singular(err, flag):
# ---> 88     raise LinAlgError("Singular matrix")
#      89
#      90 def _raise_linalgerror_nonposdef(err, flag):
#
# LinAlgError: Singular matrix

# %%
year_end
# Out:
# 2016
